# %%
# %pip install spacy nltk numpy scikit-learn
import spacy
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import word_tokenize
nlp=spacy.load('ru_core_news_sm')
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk import SnowballStemmer
import math
import re
from collections import Counter as Count
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: spacy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (3.7.2)
# Requirement already satisfied: nltk in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (3.8.1)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.26.1)
# Requirement already satisfied: scikit-learn in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.3.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.10.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.3.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (23.0)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (8.2.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: setuptools in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (63.2.0)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: joblib in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: click in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy) (2.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
text='День угасал; лиловые облака, протягиваясь по западу, едва пропускали красные лучи, которые отражались на черепицах башен и ярких главах монастыря.'

# %%
doc=nlp(text)

# %%
words=word_tokenize(text)
words
# Out:
# ['День',
#  'угасал',
#  ';',
#  'лиловые',
#  'облака',
#  ',',
#  'протягиваясь',
#  'по',
#  'западу',
#  ',',
#  'едва',
#  'пропускали',
#  'красные',
#  'лучи',
#  ',',
#  'которые',
#  'отражались',
#  'на',
#  'черепицах',
#  'башен',
#  'и',
#  'ярких',
#  'главах',
#  'монастыря',
#  '.']

# %%
word_filtered=[token.text for token in doc if not token.is_punct and not token.is_stop]
word_filtered
# Out:
# ['День',
#  'угасал',
#  'лиловые',
#  'облака',
#  'протягиваясь',
#  'западу',
#  'пропускали',
#  'красные',
#  'лучи',
#  'отражались',
#  'черепицах',
#  'башен',
#  'ярких',
#  'главах',
#  'монастыря']

# %%
len(words)
# Out:
# 25

# %%
len(word_filtered)
# Out:
# 15

# %%
word_lemma=[token.lemma_ for token in doc if not token.is_punct and not token.is_stop]
word_lemma
# Out:
# ['день',
#  'угасал',
#  'лиловый',
#  'облако',
#  'протягиваться',
#  'запад',
#  'пропускать',
#  'красный',
#  'луч',
#  'отражались',
#  'черепицах',
#  'башня',
#  'яркий',
#  'глава',
#  'монастырь']

# %%
doc.vector
doc.similarity
# Out:
# <function Doc.similarity>

# %% [markdown]
# Д/З

# %%
with open("1. Вадим.txt") as file:
    text = file.read()

# %%
words=word_tokenize(text)
words
# Out:
# ['Часть',
#  '1-я',
#  'ГЛАВА',
#  '1',
#  'День',
#  'угасал',
#  ';',
#  'лиловые',
#  'облака',
#  ',',
#  'протягиваясь',
#  'по',
#  'западу',
#  ',',
#  'едва',
#  'пропускали',
#  'красные',
#  'лучи',
#  ',',
#  'которые',
#  'отражались',
#  'на',
#  'черепицах',
#  'башен',
#  'и',
#  'ярких',
#  'главах',
#  'монастыря',
#  '.',
#  'Звонили',
#  'к',
#  'вечерни',
#  ';',
#  'монахи',
#  'и',
#  'служки',
#  'ходили',
#  'взад',
#  'и',
#  'вперед',
#  'по',
#  'каменным',
#  'плитам',
#  ',',
#  'ведущим',
#  'от',
#  'кельи',
#  'архимандрита',
#  'в',
#  'храм',
#  ';',
#  'длинные',
#  ',',
#  'черные',
#  'мантии',
#  'с',
#  'шорохом',
#  'обметали',
#  'пыль',
#  'вслед',
#  'за',
#  'ними',
#  ';',
#  'и',
#  'они',
#  'толкали',
#  'богомольцев',
#  'с',
#  'таким',
#  'важным',
#  'видом',
#  ',',
#  'как',
#  'будто',
#  'бы',
#  'это',
#  'была',
#  'их',
#  'главная',
#  'должность',
#  '.',
#  'Под',
#  'дымной',
#  'пеленою',
#  'ладана',
#  'трепещущий',
#  'огонь',
#  'свечей',
#  'казался',
#  'тусклым',
#  'и',
#  'красным',
#  ';',
#  'богомольцы',
#  'теснились',
#  'вокруг',
#  'сырых',
#  'столбов',
#  ',',
#  'и',
#  'глухой',
#  ',',
#  'торжественный',
#  'шорох',
#  'толпы',
#  ',',
#  'повторяемый',
#  'сводами',
#  ',',
#  'показывал',
#  ',',
#  'что',
#  'служба',
#  'еще',
#  'не',
#  'началась',
#  '.',
#  'У',
#  'ворот',
#  'монастырских',
#  'была',
#  'другая',
#  'картина',
#  '.',
#  'Несколько',
#  'нищих',
#  'и',
#  'увечных',
#  'ожидали',
#  'милости',
#  'богомольцев',
#  ';',
#  'они',
#  'спорили',
#  ',',
#  'бранились',
#  ',',
#  'делили',
#  'медные',
#  'деньги',
#  ',',
#  'которые',
#  'звенели',
#  'в',
#  'больших',
#  'посконных',
#  'мешках',
#  ';',
#  'это',
#  'были',
#  'люди',
#  ',',
#  'отвергнутые',
#  'природой',
#  'и',
#  'обществом',
#  '(',
#  'только',
#  'в',
#  'этом',
#  'случае',
#  'общество',
#  'согласно',
#  'бывает',
#  'с',
#  'природой',
#  ')',
#  ';',
#  'это',
#  'были',
#  'люди',
#  ',',
#  'погибшие',
#  'от',
#  'недостатка',
#  'или',
#  'излишества',
#  'надежд',
#  ',',
#  'олицетворенные',
#  'упреки',
#  'провидению',
#  ';',
#  'создания',
#  ',',
#  'лишенные',
#  'права',
#  'требовать',
#  'сожаления',
#  ',',
#  'потому',
#  'что',
#  'они',
#  'не',
#  'имели',
#  'ни',
#  'одной',
#  'добродетели',
#  ',',
#  'и',
#  'не',
#  'имеющие',
#  'ни',
#  'одной',
#  'добродетели',
#  ',',
#  'потому',
#  'что',
#  'никогда',
#  'не',
#  'встречали',
#  'сожаления',
#  '.',
#  'Их',
#  'одежды',
#  'были',
#  'изображения',
#  'их',
#  'душ',
#  ':',
#  'черные',
#  ',',
#  'изорванные',
#  '.',
#  'Лучи',
#  'заката',
#  'останавливались',
#  'на',
#  'головах',
#  ',',
#  'плечах',
#  'и',
#  'согнутых',
#  'костистых',
#  'коленах',
#  ';',
#  'углубления',
#  'в',
#  'лицах',
#  'казались',
#  'чернее',
#  'обыкновенного',
#  ';',
#  'у',
#  'каждого',
#  'на',
#  'челе',
#  'было',
#  'написано',
#  'вечными',
#  'буквами',
#  'нищета',
#  '!',
#  '—',
#  'хотя',
#  'бы',
#  'малейший',
#  'знак',
#  ',',
#  'малейший',
#  'остаток',
#  'гордости',
#  'отделился',
#  'в',
#  'глазах',
#  'или',
#  'в',
#  'улыбке',
#  '!',
#  'В',
#  'толпе',
#  'нищих',
#  'был',
#  'один',
#  '—',
#  'он',
#  'не',
#  'вмешивался',
#  'в',
#  'разговор',
#  'их',
#  'и',
#  'неподвижно',
#  'смотрел',
#  'на',
#  'расписанные',
#  'святые',
#  'врата',
#  ';',
#  'он',
#  'был',
#  'горбат',
#  'и',
#  'кривоног',
#  ';',
#  'но',
#  'члены',
#  'его',
#  'казались',
#  'крепкими',
#  'и',
#  'привыкшими',
#  'к',
#  'трудам',
#  'этого',
#  'позорного',
#  'состояния',
#  ';',
#  'лицо',
#  'его',
#  'было',
#  'длинно',
#  ',',
#  'смугло',
#  ';',
#  'прямой',
#  'нос',
#  ',',
#  'курчавые',
#  'волосы',
#  ';',
#  'широкий',
#  'лоб',
#  'его',
#  'был',
#  'желт',
#  'как',
#  'лоб',
#  'ученого',
#  ',',
#  'мрачен',
#  'как',
#  'облако',
#  ',',
#  'покрывающее',
#  'солнце',
#  'в',
#  'день',
#  'бури',
#  ';',
#  'синяя',
#  'жила',
#  'пересекала',
#  'его',
#  'неправильные',
#  'морщины',
#  ';',
#  'губы',
#  ',',
#  'тонкие',
#  ',',
#  'бледные',
#  ',',
#  'были',
#  'растягиваемы',
#  'и',
#  'сжимаемы',
#  'каким-то',
#  'судорожным',
#  'движением',
#  ',',
#  'и',
#  'в',
#  'глазах',
#  'блистала',
#  'целая',
#  'будущность',
#  ';',
#  'его',
#  'товарищи',
#  'не',
#  'знали',
#  ',',
#  'кто',
#  'он',
#  'таков',
#  ';',
#  'но',
#  'сила',
#  'души',
#  'обнаруживается',
#  'везде',
#  ':',
#  'они',
#  'боялись',
#  'его',
#  'голоса',
#  'и',
#  'взгляда',
#  ';',
#  'они',
#  'уважали',
#  'в',
#  'нем',
#  'какой-то',
#  'величайший',
#  'порок',
#  ',',
#  'а',
#  'не',
#  'безграничное',
#  'несчастие',
#  ',',
#  'демона',
#  '—',
#  'но',
#  'не',
#  'человека',
#  ':',
#  '—',
#  'он',
#  'был',
#  'безобразен',
#  ',',
#  'отвратителен',
#  ',',
#  'но',
#  'не',
#  'это',
#  'пугало',
#  'их',
#  ';',
#  'в',
#  'его',
#  'глазах',
#  'было',
#  'столько',
#  'огня',
#  'и',
#  'ума',
#  ',',
#  'столько',
#  'неземного',
#  ',',
#  'что',
#  'они',
#  ',',
#  'не',
#  'смея',
#  'верить',
#  'их',
#  'выражению',
#  ',',
#  'уважали',
#  'в',
#  'незнакомце',
#  'чудесного',
#  'обманщика',
#  '.',
#  'Ему',
#  'казалось',
#  'не',
#  'больше',
#  '28',
#  'лет',
#  ';',
#  'на',
#  'лице',
#  'его',
#  'постоянно',
#  'отражалась',
#  'насмешка',
#  ',',
#  'горькая',
#  ',',
#  'бесконечная',
#  ';',
#  'волшебный',
#  'круг',
#  ',',
#  'заключавший',
#  'вселенную',
#  ';',
#  'его',
#  'душа',
#  'еще',
#  'не',
#  'жила',
#  'по-настоящему',
#  ',',
#  'но',
#  'собирала',
#  'все',
#  'свои',
#  'силы',
#  ',',
#  'чтобы',
#  'переполнить',
#  'жизнь',
#  'и',
#  'прежде',
#  'времени',
#  'вырваться',
#  'в',
#  'вечность',
#  ';',
#  '—',
#  'нищий',
#  'стоял',
#  'сложа',
#  'руки',
#  'и',
#  'рассматривал',
#  'дьявола',
#  ',',
#  'изображенного',
#  'поблекшими',
#  'красками',
#  'на',
#  'св',
#  '.',
#  'вратах',
#  ',',
#  'и',
#  'внутренно',
#  'сожалел',
#  'об',
#  'нем',
#  ';',
#  'он',
#  'думал',
#  ':',
#  'если',
#  'б',
#  'я',
#  'был',
#  'чорт',
#  ',',
#  'то',
#  'не',
#  'мучил',
#  'бы',
#  'людей',
#  ',',
#  'а',
#  'презирал',
#  'бы',
#  'их',
#  ';',
#  'стоят',
#  'ли',
#  'они',
#  ',',
#  'чтоб',
#  'их',
#  'соблазнял',
#  'изгнанник',
#  'рая',
#  ',',
#  'соперник',
#  'бога',
#  '!',
#  '..',
#  'другое',
#  'дело',
#  'человек',
#  ';',
#  'чтоб',
#  'кончить',
#  'презрением',
#  ',',
#  'он',
#  'должен',
#  'начать',
#  'с',
#  'ненависти',
#  '!',
#  'И',
#  'глаза',
#  'его',
#  'блистали',
#  'под',
#  'беспокойными',
#  'бровями',
#  ',',
#  'и',
#  'худые',
#  'щеки',
#  'покрывались',
#  'красными',
#  'пятнами',
#  ':',
#  'всё',
#  'было',
#  'согласно',
#  'в',
#  'чертах',
#  'нищего',
#  ':',
#  'одна',
#  'страсть',
#  'владела',
#  'его',
#  'сердцем',
#  'или',
#  'лучше',
#  'он',
#  'владел',
#  'одною',
#  'только',
#  'страстью',
#  ',',
#  '—',
#  'но',
#  'зато',
#  'совершенно',
#  '!',
#  '«',
#  'Христа',
#  'ради',
#  ',',
#  'барин',
#  ',',
#  '—',
#  'погорелым',
#  ',',
#  'калекам',
#  ',',
#  'слепому…',
#  'Христа',
#  'ради',
#  'копеечку',
#  '!',
#  '»',
#  '—',
#  'раздался',
#  'крик',
#  'его',
#  'товарищей',
#  ';',
#  'он',
#  'вздрогнул',
#  ',',
#  'обернулся',
#  '—',
#  'и',
#  'в',
#  'этот',
#  'миг',
#  'решилась',
#  'его',
#  'участь',
#  '.',
#  '—',
#  'Что',
#  'же',
#  'увидал',
#  'он',
#  '?',
#  'русского',
#  'дворянина',
#  ',',
#  'Бориса',
#  'Петровича',
#  'Палицына',
#  '.',
#  'Не',
#  'больше',
#  '.',
#  '[',
#  'ГЛАВА',
#  'II',
#  ']',
#  'Представьте',
#  'себе',
#  'мужчину',
#  'лет',
#  '50',
#  ',',
#  'высокого',
#  ',',
#  'еще',
#  'здорового',
#  ',',
#  'но',
#  'с',
#  'седыми',
#  'волосами',
#  'и',
#  'потухшим',
#  'взором',
#  ',',
#  'одетого',
#  'в',
#  'синее',
#  'полукафтанье',
#  'с',
#  'анненским',
#  'крестом',
#  'в',
#  'петлице',
#  ';',
#  'ноги',
#  'его',
#  ',',
#  'запрятанные',
#  'в',
#  'огромные',
#  'сапоги',
#  ',',
#  'производили',
#  'неприятный',
#  'звук',
#  ',',
#  'ступая',
#  'на',
#  'пыльные',
#  'камни',
#  ';',
#  'он',
#  'шел',
#  'с',
#  'важностью',
#  'размахивая',
#  'руками',
#  'и',
#  'наморщивал',
#  'высокий',
#  'лоб',
#  'всякий',
#  'раз',
#  ',',
#  'как',
#  'докучливые',
#  'нищие',
#  'обступали',
#  'его',
#  ';',
#  '—',
#  'двое',
#  'слуг',
#  'следовали',
#  'за',
#  'ним',
#  'с',
#  'подобострастием',
#  '.',
#  '—',
#  'Палицын',
#  'положил',
#  'серебряный',
#  'рубль',
#  'в',
#  'кружку',
#  'монастырскую',
#  'и',
#  ',',
#  'оттолкнув',
#  'нищих',
#  ',',
#  'воскликнул',
#  ':',
#  '«',
#  'Прочь',
#  ',',
#  'вы',
#  '!',
#  '—',
#  'лентяи',
#  '.',
#  '—',
#  'Экие',
#  'молодцы',
#  '—',
#  'а',
#  'просят',
#  'христа',
#  'ради',
#  ';',
#  'что',
#  'вы',
#  'не',
#  'работаете',
#  '?',
#  'дай',
#  'бог',
#  ',',
#  'чтоб',
#  'пришло',
#  'время',
#  ',',
#  'когда',
#  'этих',
#  'бродяг',
#  'без',
#  'стыда',
#  'будут',
#  'морить',
#  'с',
#  'голоду',
#  '.',
#  '—',
#  'Вот',
#  'вам',
#  'рубль',
#  'на',
#  'всю',
#  'братию',
#  '.',
#  '—',
#  'Только',
#  'чур',
#  'не',
#  'перекусайтесь',
#  'за',
#  'него',
#  '»',
#  '.',
#  'Между',
#  'тем',
#  'горбатый',
#  'нищий',
#  'молча',
#  'приблизился',
#  'и',
#  'устремил',
#  'яркие',
#  'черные',
#  'глаза',
#  'на',
#  'великодушного',
#  'господина',
#  ';',
#  'этот',
#  'взор',
#  'был',
#  'остановившаяся',
#  'молния',
#  ',',
#  'и',
#  'человек',
#  ',',
#  'подверженный',
#  'его',
#  'таинственному',
#  'влиянию',
#  ',',
#  'должен',
#  'был',
#  'содрогнуться',
#  'и',
#  'не',
#  'мог',
#  'отвечать',
#  'ему',
#  'тем',
#  'же',
#  ',',
#  'как',
#  'будто',
#  'свинцовая',
#  'печать',
#  'тяготела',
#  'на',
#  'его',
#  'веках',
#  ';',
#  'если',
#  'магнетизм',
#  'существует',
#  ',',
#  'то',
#  'взгляд',
#  'нищего',
#  'был',
#  'сильнейший',
#  'магнетизм',
#  '.',
#  'Когда',
#  'старый',
#  'господин',
#  'удалился',
#  'от',
#  'толпы',
#  ',',
#  'он',
#  'поспешил',
#  'догнать',
#  'его',
#  '.',
#  'Палицын',
#  'обернулся',
#  '.',
#  '—',
#  'Что',
#  'тебе',
#  'надобно',
#  '?',
#  '—',
#  'Очень',
#  'мало',
#  '!',
#  '—',
#  'я',
#  'хочу',
#  'работы…',
#  'С',
#  'язвительной',
#  'усмешкой',
#  'посмотрел',
#  'старик',
#  'на',
#  'нищего',
#  ',',
#  'на',
#  'его',
#  'горб',
#  'и',
#  'безобразные',
#  'ноги…',
#  'но',
#  'бедняк',
#  'нимало',
#  'не',
#  'смутился',
#  ',',
#  'и',
#  'остался',
#  'хладнокровен',
#  ',',
#  'как',
#  'Сократ',
#  ',',
#  'когда',
#  'жена',
#  'вылила',
#  'кувшин',
#  'воды',
#  'на',
#  'его',
#  'голову',
#  ',',
#  'но',
#  'это',
#  'не',
#  'было',
#  'хладнокровие',
#  'мудреца',
#  '—',
#  'нищий',
#  'был',
#  'скорее',
#  'похож',
#  'на',
#  'дуэлиста',
#  ',',
#  'который',
#  'уверен',
#  'в',
#  'меткости',
#  'руки',
#  'своей',
#  '.',
#  '—',
#  'Если',
#  'ты',
#  ',',
#  'барин',
#  ',',
#  'думаешь',
#  ',',
#  'что',
#  'я',
#  'не',
#  'могу',
#  'перенесть',
#  'труда',
#  ',',
#  'то',
#  'я',
#  'тебя',
#  'успокою',
#  'на',
#  'этот',
#  'счет',
#  '.',
#  '—',
#  'Он',
#  'поднял',
#  'большой',
#  'камень',
#  'и',
#  'начал',
#  'им',
#  'играть',
#  'как',
#  'мячиком',
#  ';',
#  'Палицын',
#  'изумился',
#  '.',
#  '—',
#  'Хочешь',
#  'ли',
#  'быть',
#  'моим',
#  'слугою',
#  '?',
#  'Нищий',
#  'в',
#  ...]

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['Часть',
#  '1-я',
#  'ГЛАВА',
#  '1',
#  'День',
#  'угасал',
#  ';',
#  'лиловые',
#  'облака',
#  ',',
#  'протягиваясь',
#  'западу',
#  ',',
#  'едва',
#  'пропускали',
#  'красные',
#  'лучи',
#  ',',
#  'которые',
#  'отражались',
#  'черепицах',
#  'башен',
#  'ярких',
#  'главах',
#  'монастыря',
#  '.',
#  'Звонили',
#  'вечерни',
#  ';',
#  'монахи',
#  'служки',
#  'ходили',
#  'взад',
#  'вперед',
#  'каменным',
#  'плитам',
#  ',',
#  'ведущим',
#  'кельи',
#  'архимандрита',
#  'храм',
#  ';',
#  'длинные',
#  ',',
#  'черные',
#  'мантии',
#  'шорохом',
#  'обметали',
#  'пыль',
#  'вслед',
#  'ними',
#  ';',
#  'толкали',
#  'богомольцев',
#  'таким',
#  'важным',
#  'видом',
#  ',',
#  'это',
#  'главная',
#  'должность',
#  '.',
#  'Под',
#  'дымной',
#  'пеленою',
#  'ладана',
#  'трепещущий',
#  'огонь',
#  'свечей',
#  'казался',
#  'тусклым',
#  'красным',
#  ';',
#  'богомольцы',
#  'теснились',
#  'вокруг',
#  'сырых',
#  'столбов',
#  ',',
#  'глухой',
#  ',',
#  'торжественный',
#  'шорох',
#  'толпы',
#  ',',
#  'повторяемый',
#  'сводами',
#  ',',
#  'показывал',
#  ',',
#  'служба',
#  'началась',
#  '.',
#  'У',
#  'ворот',
#  'монастырских',
#  'другая',
#  'картина',
#  '.',
#  'Несколько',
#  'нищих',
#  'увечных',
#  'ожидали',
#  'милости',
#  'богомольцев',
#  ';',
#  'спорили',
#  ',',
#  'бранились',
#  ',',
#  'делили',
#  'медные',
#  'деньги',
#  ',',
#  'которые',
#  'звенели',
#  'больших',
#  'посконных',
#  'мешках',
#  ';',
#  'это',
#  'люди',
#  ',',
#  'отвергнутые',
#  'природой',
#  'обществом',
#  '(',
#  'случае',
#  'общество',
#  'согласно',
#  'бывает',
#  'природой',
#  ')',
#  ';',
#  'это',
#  'люди',
#  ',',
#  'погибшие',
#  'недостатка',
#  'излишества',
#  'надежд',
#  ',',
#  'олицетворенные',
#  'упреки',
#  'провидению',
#  ';',
#  'создания',
#  ',',
#  'лишенные',
#  'права',
#  'требовать',
#  'сожаления',
#  ',',
#  'имели',
#  'одной',
#  'добродетели',
#  ',',
#  'имеющие',
#  'одной',
#  'добродетели',
#  ',',
#  'встречали',
#  'сожаления',
#  '.',
#  'Их',
#  'одежды',
#  'изображения',
#  'душ',
#  ':',
#  'черные',
#  ',',
#  'изорванные',
#  '.',
#  'Лучи',
#  'заката',
#  'останавливались',
#  'головах',
#  ',',
#  'плечах',
#  'согнутых',
#  'костистых',
#  'коленах',
#  ';',
#  'углубления',
#  'лицах',
#  'казались',
#  'чернее',
#  'обыкновенного',
#  ';',
#  'каждого',
#  'челе',
#  'написано',
#  'вечными',
#  'буквами',
#  'нищета',
#  '!',
#  '—',
#  'хотя',
#  'малейший',
#  'знак',
#  ',',
#  'малейший',
#  'остаток',
#  'гордости',
#  'отделился',
#  'глазах',
#  'улыбке',
#  '!',
#  'В',
#  'толпе',
#  'нищих',
#  '—',
#  'вмешивался',
#  'разговор',
#  'неподвижно',
#  'смотрел',
#  'расписанные',
#  'святые',
#  'врата',
#  ';',
#  'горбат',
#  'кривоног',
#  ';',
#  'члены',
#  'казались',
#  'крепкими',
#  'привыкшими',
#  'трудам',
#  'позорного',
#  'состояния',
#  ';',
#  'лицо',
#  'длинно',
#  ',',
#  'смугло',
#  ';',
#  'прямой',
#  'нос',
#  ',',
#  'курчавые',
#  'волосы',
#  ';',
#  'широкий',
#  'лоб',
#  'желт',
#  'лоб',
#  'ученого',
#  ',',
#  'мрачен',
#  'облако',
#  ',',
#  'покрывающее',
#  'солнце',
#  'день',
#  'бури',
#  ';',
#  'синяя',
#  'жила',
#  'пересекала',
#  'неправильные',
#  'морщины',
#  ';',
#  'губы',
#  ',',
#  'тонкие',
#  ',',
#  'бледные',
#  ',',
#  'растягиваемы',
#  'сжимаемы',
#  'каким-то',
#  'судорожным',
#  'движением',
#  ',',
#  'глазах',
#  'блистала',
#  'целая',
#  'будущность',
#  ';',
#  'товарищи',
#  'знали',
#  ',',
#  'таков',
#  ';',
#  'сила',
#  'души',
#  'обнаруживается',
#  'везде',
#  ':',
#  'боялись',
#  'голоса',
#  'взгляда',
#  ';',
#  'уважали',
#  'нем',
#  'какой-то',
#  'величайший',
#  'порок',
#  ',',
#  'безграничное',
#  'несчастие',
#  ',',
#  'демона',
#  '—',
#  'человека',
#  ':',
#  '—',
#  'безобразен',
#  ',',
#  'отвратителен',
#  ',',
#  'это',
#  'пугало',
#  ';',
#  'глазах',
#  'столько',
#  'огня',
#  'ума',
#  ',',
#  'столько',
#  'неземного',
#  ',',
#  ',',
#  'смея',
#  'верить',
#  'выражению',
#  ',',
#  'уважали',
#  'незнакомце',
#  'чудесного',
#  'обманщика',
#  '.',
#  'Ему',
#  'казалось',
#  '28',
#  'лет',
#  ';',
#  'лице',
#  'постоянно',
#  'отражалась',
#  'насмешка',
#  ',',
#  'горькая',
#  ',',
#  'бесконечная',
#  ';',
#  'волшебный',
#  'круг',
#  ',',
#  'заключавший',
#  'вселенную',
#  ';',
#  'душа',
#  'жила',
#  'по-настоящему',
#  ',',
#  'собирала',
#  'свои',
#  'силы',
#  ',',
#  'переполнить',
#  'жизнь',
#  'прежде',
#  'времени',
#  'вырваться',
#  'вечность',
#  ';',
#  '—',
#  'нищий',
#  'стоял',
#  'сложа',
#  'руки',
#  'рассматривал',
#  'дьявола',
#  ',',
#  'изображенного',
#  'поблекшими',
#  'красками',
#  'св',
#  '.',
#  'вратах',
#  ',',
#  'внутренно',
#  'сожалел',
#  'нем',
#  ';',
#  'думал',
#  ':',
#  'б',
#  'чорт',
#  ',',
#  'мучил',
#  'людей',
#  ',',
#  'презирал',
#  ';',
#  'стоят',
#  ',',
#  'соблазнял',
#  'изгнанник',
#  'рая',
#  ',',
#  'соперник',
#  'бога',
#  '!',
#  '..',
#  'другое',
#  'дело',
#  'человек',
#  ';',
#  'кончить',
#  'презрением',
#  ',',
#  'должен',
#  'начать',
#  'ненависти',
#  '!',
#  'И',
#  'глаза',
#  'блистали',
#  'беспокойными',
#  'бровями',
#  ',',
#  'худые',
#  'щеки',
#  'покрывались',
#  'красными',
#  'пятнами',
#  ':',
#  'всё',
#  'согласно',
#  'чертах',
#  'нищего',
#  ':',
#  'одна',
#  'страсть',
#  'владела',
#  'сердцем',
#  'владел',
#  'одною',
#  'страстью',
#  ',',
#  '—',
#  'зато',
#  'совершенно',
#  '!',
#  '«',
#  'Христа',
#  'ради',
#  ',',
#  'барин',
#  ',',
#  '—',
#  'погорелым',
#  ',',
#  'калекам',
#  ',',
#  'слепому…',
#  'Христа',
#  'ради',
#  'копеечку',
#  '!',
#  '»',
#  '—',
#  'раздался',
#  'крик',
#  'товарищей',
#  ';',
#  'вздрогнул',
#  ',',
#  'обернулся',
#  '—',
#  'миг',
#  'решилась',
#  'участь',
#  '.',
#  '—',
#  'Что',
#  'увидал',
#  '?',
#  'русского',
#  'дворянина',
#  ',',
#  'Бориса',
#  'Петровича',
#  'Палицына',
#  '.',
#  'Не',
#  '.',
#  '[',
#  'ГЛАВА',
#  'II',
#  ']',
#  'Представьте',
#  'мужчину',
#  'лет',
#  '50',
#  ',',
#  'высокого',
#  ',',
#  'здорового',
#  ',',
#  'седыми',
#  'волосами',
#  'потухшим',
#  'взором',
#  ',',
#  'одетого',
#  'синее',
#  'полукафтанье',
#  'анненским',
#  'крестом',
#  'петлице',
#  ';',
#  'ноги',
#  ',',
#  'запрятанные',
#  'огромные',
#  'сапоги',
#  ',',
#  'производили',
#  'неприятный',
#  'звук',
#  ',',
#  'ступая',
#  'пыльные',
#  'камни',
#  ';',
#  'шел',
#  'важностью',
#  'размахивая',
#  'руками',
#  'наморщивал',
#  'высокий',
#  'лоб',
#  'всякий',
#  ',',
#  'докучливые',
#  'нищие',
#  'обступали',
#  ';',
#  '—',
#  'двое',
#  'слуг',
#  'следовали',
#  'подобострастием',
#  '.',
#  '—',
#  'Палицын',
#  'положил',
#  'серебряный',
#  'рубль',
#  'кружку',
#  'монастырскую',
#  ',',
#  'оттолкнув',
#  'нищих',
#  ',',
#  'воскликнул',
#  ':',
#  '«',
#  'Прочь',
#  ',',
#  '!',
#  '—',
#  'лентяи',
#  '.',
#  '—',
#  'Экие',
#  'молодцы',
#  '—',
#  'просят',
#  'христа',
#  'ради',
#  ';',
#  'работаете',
#  '?',
#  'дай',
#  'бог',
#  ',',
#  'пришло',
#  'время',
#  ',',
#  'этих',
#  'бродяг',
#  'стыда',
#  'будут',
#  'морить',
#  'голоду',
#  '.',
#  '—',
#  'Вот',
#  'рубль',
#  'братию',
#  '.',
#  '—',
#  'Только',
#  'чур',
#  'перекусайтесь',
#  '»',
#  '.',
#  'Между',
#  'горбатый',
#  'нищий',
#  'молча',
#  'приблизился',
#  'устремил',
#  'яркие',
#  'черные',
#  'глаза',
#  'великодушного',
#  'господина',
#  ';',
#  'взор',
#  'остановившаяся',
#  'молния',
#  ',',
#  'человек',
#  ',',
#  'подверженный',
#  'таинственному',
#  'влиянию',
#  ',',
#  'должен',
#  'содрогнуться',
#  'мог',
#  'отвечать',
#  ',',
#  'свинцовая',
#  'печать',
#  'тяготела',
#  'веках',
#  ';',
#  'магнетизм',
#  'существует',
#  ',',
#  'взгляд',
#  'нищего',
#  'сильнейший',
#  'магнетизм',
#  '.',
#  'Когда',
#  'старый',
#  'господин',
#  'удалился',
#  'толпы',
#  ',',
#  'поспешил',
#  'догнать',
#  '.',
#  'Палицын',
#  'обернулся',
#  '.',
#  '—',
#  'Что',
#  'тебе',
#  'надобно',
#  '?',
#  '—',
#  'Очень',
#  'мало',
#  '!',
#  '—',
#  'хочу',
#  'работы…',
#  'С',
#  'язвительной',
#  'усмешкой',
#  'посмотрел',
#  'старик',
#  'нищего',
#  ',',
#  'горб',
#  'безобразные',
#  'ноги…',
#  'бедняк',
#  'нимало',
#  'смутился',
#  ',',
#  'остался',
#  'хладнокровен',
#  ',',
#  'Сократ',
#  ',',
#  'жена',
#  'вылила',
#  'кувшин',
#  'воды',
#  'голову',
#  ',',
#  'это',
#  'хладнокровие',
#  'мудреца',
#  '—',
#  'нищий',
#  'скорее',
#  'похож',
#  'дуэлиста',
#  ',',
#  'который',
#  'уверен',
#  'меткости',
#  'руки',
#  'своей',
#  '.',
#  '—',
#  'Если',
#  ',',
#  'барин',
#  ',',
#  'думаешь',
#  ',',
#  'могу',
#  'перенесть',
#  'труда',
#  ',',
#  'успокою',
#  'счет',
#  '.',
#  '—',
#  'Он',
#  'поднял',
#  'большой',
#  'камень',
#  'начал',
#  'играть',
#  'мячиком',
#  ';',
#  'Палицын',
#  'изумился',
#  '.',
#  '—',
#  'Хочешь',
#  'моим',
#  'слугою',
#  '?',
#  'Нищий',
#  'одну',
#  'минуту',
#  'принял',
#  'вид',
#  'смирения',
#  'жаром',
#  'поцеловал',
#  'руку',
#  'своего',
#  'нового',
#  'покровителя…',
#  'вольного',
#  'согласился',
#  'рабом',
#  '—',
#  'ужели',
#  'даром',
#  '?',
#  '—',
#  'странная',
#  'мысль',
#  'принять',
#  'имя',
#  'раба',
#  '2',
#  'месяца',
#  'Пугачева',
#  '.',
#  '—',
#  'Клянусь',
#  'головою',
#  'отца',
#  'моего',
#  ',',
#  'исполню',
#  'обязанность',
#  '!',
#  '—',
#  'воскликнул',
#  'нищий',
#  ',',
#  '—',
#  'адская',
#  'радость',
#  'вспыхнула',
#  'бледном',
#  'лице',
#  '.',
#  '—',
#  'Твое',
#  'имя',
#  '?',
#  '—',
#  '—',
#  'Вадим',
#  '!',
#  '—',
#  'Прелестное',
#  'имя',
#  'такого',
#  'урода',
#  '!',
#  'Слуги',
#  'подхватили',
#  'шутку',
#  'барина',
#  'захохотали',
#  ';',
#  'нищий',
#  'взглянул',
#  'презрением',
#  ',',
#  'неуместная',
#  'веселость',
#  'утихла',
#  ';',
#  'подлые',
#  'души',
#  'завидуют',
#  'всему',
#  ',',
#  'обидам',
#  ',',
#  'которые',
#  'показывают',
#  'некоторое',
#  'внимание',
#  'стороны',
#  'начальника',
#  '.',
#  '—',
#  'Следуй',
#  'мной',
#  '!',
#  '..',
#  'сказал',
#  'Палицын',
#  ',',
#  'оставили',
#  'монастырь',
#  '.',
#  'Часто',
#  'Вадим',
#  'оборачивался',
#  '!',
#  'полусветлом',
#  'небосклоне',
#  'рисовались',
#  'зубчатые',
#  'стены',
#  ',',
#  'башни',
#  'церковь',
#  ',',
#  'плоскими',
#  'черными',
#  'городами',
#  ',',
#  'всяких',
#  'оттенок',
#  ';',
#  'зрелище',
#  '<',
#  '-то',
#  '>',
#  'величественное',
#  ',',
#  'заставляющее',
#  'душу',
#  'погружаться',
#  'думать',
#  'вечности',
#  ',',
#  'думать',
#  'величии',
#  'земном',
#  'небесном',
#  ',',
#  'рождаются',
#  'мысли',
#  'мрачные',
#  'чудесные',
#  ',',
#  'одинокий',
#  'монастырь',
#  ',',
#  'неподвижный',
#  'памятник',
#  'слабости',
#  'некоторых',
#  'людей',
#  ',',
#  'которые',
#  'понимали',
#  ',',
#  'скрывается',
#  'добродетель',
#  ',',
#  'скрываться',
#  'преступление',
#  '.',
#  'ГЛАВА',
#  'III',
#  'Поздно',
#  ',',
#  'поздно',
#  'вечером',
#  'приехал',
#  'Борис',
#  'Петрович',
#  'домой',
#  ';',
#  'собаки',
#  'встретили',
#  'громким',
#  'лаем',
#  ',',
#  'светящимся',
#  'окнам',
#  'узнать',
#  'строение',
#  ';',
#  'ветер',
#  'шумя',
#  'качал',
#  'ветелки',
#  ',',
#  'насаженные',
#  'вокруг',
#  'господского',
#  'двора',
#  ',',
#  'топот',
#  'конский',
#  'раздался',
#  ',',
#  'слуги',
#  'вышли',
#  'фонарями',
#  'навстречу',
#  ',',
#  'улыбаясь',
#  'внутренне',
#  'проклиная',
#  'барина',
#  ',',
#  'которого',
#  'покинули',
#  'свои',
#  'теплые',
#  'постели',
#  ',',
#  ',',
#  'что-нибудь',
#  'получше',
#  '.',
#  'Палицын',
#  'взошел',
#  'дом',
#  ';',
#  '—',
#  'зале',
#  'темно',
#  ';',
#  'оконницы',
#  'дрожали',
#  'ветра',
#  'сильного',
#  'дождя',
#  ';',
#  'гостиной',
#  'стояла',
#  'свеча',
#  ';',
#  'эта',
#  'комната',
#  'совершенно',
#  'отделана',
#  'вкусе',
#  '18-го',
#  'века',
#  ':',
#  'разноцветные',
#  'обои',
#  ',',
#  'круглые',
#  'стола',
#  ';',
#  'каждым',
#  'небольшое',
#  'канапе',
#  ';',
#  'глухая',
#  'стена',
#  ',',
#  'находящаяся',
#  'двумя',
#  'высокими',
#  'печьми',
#  ',',
#  'которых',
#  'стояли',
#  'безобразные',
#  ...]

# %%
len(words)
# Out:
# 40909

# %%
len(tokenized_filtered)
# Out:
# 29921

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['част',
#  '1-я',
#  'глав',
#  '1',
#  'ден',
#  'угаса',
#  ';',
#  'лилов',
#  'облак',
#  ',',
#  'протягив',
#  'по',
#  'запад',
#  ',',
#  'едв',
#  'пропуска',
#  'красн',
#  'луч',
#  ',',
#  'котор',
#  'отража',
#  'на',
#  'черепиц',
#  'баш',
#  'и',
#  'ярк',
#  'глав',
#  'монастыр',
#  '.',
#  'звон',
#  'к',
#  'вечерн',
#  ';',
#  'монах',
#  'и',
#  'служк',
#  'ход',
#  'взад',
#  'и',
#  'вперед',
#  'по',
#  'камен',
#  'плит',
#  ',',
#  'ведущ',
#  'от',
#  'кел',
#  'архимандрит',
#  'в',
#  'храм',
#  ';',
#  'длин',
#  ',',
#  'черн',
#  'мант',
#  'с',
#  'шорох',
#  'обмета',
#  'пыл',
#  'вслед',
#  'за',
#  'ним',
#  ';',
#  'и',
#  'он',
#  'толка',
#  'богомольц',
#  'с',
#  'так',
#  'важн',
#  'вид',
#  ',',
#  'как',
#  'будт',
#  'бы',
#  'эт',
#  'был',
#  'их',
#  'главн',
#  'должност',
#  '.',
#  'под',
#  'дымн',
#  'пелен',
#  'лада',
#  'трепещущ',
#  'огон',
#  'свеч',
#  'каза',
#  'тускл',
#  'и',
#  'красн',
#  ';',
#  'богомольц',
#  'тесн',
#  'вокруг',
#  'сыр',
#  'столб',
#  ',',
#  'и',
#  'глух',
#  ',',
#  'торжествен',
#  'шорох',
#  'толп',
#  ',',
#  'повторя',
#  'свод',
#  ',',
#  'показыва',
#  ',',
#  'что',
#  'служб',
#  'ещ',
#  'не',
#  'нача',
#  '.',
#  'у',
#  'ворот',
#  'монастырск',
#  'был',
#  'друг',
#  'картин',
#  '.',
#  'нескольк',
#  'нищ',
#  'и',
#  'увечн',
#  'ожида',
#  'милост',
#  'богомольц',
#  ';',
#  'он',
#  'спор',
#  ',',
#  'бран',
#  ',',
#  'дел',
#  'медн',
#  'деньг',
#  ',',
#  'котор',
#  'звенел',
#  'в',
#  'больш',
#  'поскон',
#  'мешк',
#  ';',
#  'эт',
#  'был',
#  'люд',
#  ',',
#  'отвергнут',
#  'природ',
#  'и',
#  'обществ',
#  '(',
#  'тольк',
#  'в',
#  'эт',
#  'случа',
#  'обществ',
#  'согласн',
#  'быва',
#  'с',
#  'природ',
#  ')',
#  ';',
#  'эт',
#  'был',
#  'люд',
#  ',',
#  'погибш',
#  'от',
#  'недостатк',
#  'ил',
#  'излишеств',
#  'надежд',
#  ',',
#  'олицетворен',
#  'упрек',
#  'провиден',
#  ';',
#  'создан',
#  ',',
#  'лишен',
#  'прав',
#  'требова',
#  'сожален',
#  ',',
#  'пот',
#  'что',
#  'он',
#  'не',
#  'имел',
#  'ни',
#  'одн',
#  'добродетел',
#  ',',
#  'и',
#  'не',
#  'имеющ',
#  'ни',
#  'одн',
#  'добродетел',
#  ',',
#  'пот',
#  'что',
#  'никогд',
#  'не',
#  'встреча',
#  'сожален',
#  '.',
#  'их',
#  'одежд',
#  'был',
#  'изображен',
#  'их',
#  'душ',
#  ':',
#  'черн',
#  ',',
#  'изорва',
#  '.',
#  'луч',
#  'закат',
#  'останавлива',
#  'на',
#  'голов',
#  ',',
#  'плеч',
#  'и',
#  'согнут',
#  'костист',
#  'колен',
#  ';',
#  'углублен',
#  'в',
#  'лиц',
#  'каза',
#  'черн',
#  'обыкновен',
#  ';',
#  'у',
#  'кажд',
#  'на',
#  'чел',
#  'был',
#  'написа',
#  'вечн',
#  'букв',
#  'нищет',
#  '!',
#  '—',
#  'хот',
#  'бы',
#  'мал',
#  'знак',
#  ',',
#  'мал',
#  'остаток',
#  'гордост',
#  'отдел',
#  'в',
#  'глаз',
#  'ил',
#  'в',
#  'улыбк',
#  '!',
#  'в',
#  'толп',
#  'нищ',
#  'был',
#  'один',
#  '—',
#  'он',
#  'не',
#  'вмешива',
#  'в',
#  'разговор',
#  'их',
#  'и',
#  'неподвижн',
#  'смотрел',
#  'на',
#  'расписа',
#  'свят',
#  'врат',
#  ';',
#  'он',
#  'был',
#  'горбат',
#  'и',
#  'кривоног',
#  ';',
#  'но',
#  'член',
#  'ег',
#  'каза',
#  'крепк',
#  'и',
#  'привыкш',
#  'к',
#  'труд',
#  'эт',
#  'позорн',
#  'состоян',
#  ';',
#  'лиц',
#  'ег',
#  'был',
#  'длин',
#  ',',
#  'смугл',
#  ';',
#  'прям',
#  'нос',
#  ',',
#  'курчав',
#  'волос',
#  ';',
#  'широк',
#  'лоб',
#  'ег',
#  'был',
#  'желт',
#  'как',
#  'лоб',
#  'учен',
#  ',',
#  'мрач',
#  'как',
#  'облак',
#  ',',
#  'покрыва',
#  'солнц',
#  'в',
#  'ден',
#  'бур',
#  ';',
#  'син',
#  'жил',
#  'пересека',
#  'ег',
#  'неправильн',
#  'морщин',
#  ';',
#  'губ',
#  ',',
#  'тонк',
#  ',',
#  'бледн',
#  ',',
#  'был',
#  'растягиваем',
#  'и',
#  'сжимаем',
#  'каким-т',
#  'судорожн',
#  'движен',
#  ',',
#  'и',
#  'в',
#  'глаз',
#  'блиста',
#  'цел',
#  'будущн',
#  ';',
#  'ег',
#  'товарищ',
#  'не',
#  'знал',
#  ',',
#  'кто',
#  'он',
#  'так',
#  ';',
#  'но',
#  'сил',
#  'душ',
#  'обнаружива',
#  'везд',
#  ':',
#  'он',
#  'боя',
#  'ег',
#  'голос',
#  'и',
#  'взгляд',
#  ';',
#  'он',
#  'уважа',
#  'в',
#  'нем',
#  'какой-т',
#  'величайш',
#  'порок',
#  ',',
#  'а',
#  'не',
#  'безграничн',
#  'несчаст',
#  ',',
#  'демон',
#  '—',
#  'но',
#  'не',
#  'человек',
#  ':',
#  '—',
#  'он',
#  'был',
#  'безобраз',
#  ',',
#  'отвратител',
#  ',',
#  'но',
#  'не',
#  'эт',
#  'пуга',
#  'их',
#  ';',
#  'в',
#  'ег',
#  'глаз',
#  'был',
#  'стольк',
#  'огн',
#  'и',
#  'ум',
#  ',',
#  'стольк',
#  'неземн',
#  ',',
#  'что',
#  'он',
#  ',',
#  'не',
#  'сме',
#  'вер',
#  'их',
#  'выражен',
#  ',',
#  'уважа',
#  'в',
#  'незнакомц',
#  'чудесн',
#  'обманщик',
#  '.',
#  'ем',
#  'каза',
#  'не',
#  'больш',
#  '28',
#  'лет',
#  ';',
#  'на',
#  'лиц',
#  'ег',
#  'постоя',
#  'отража',
#  'насмешк',
#  ',',
#  'горьк',
#  ',',
#  'бесконечн',
#  ';',
#  'волшебн',
#  'круг',
#  ',',
#  'заключа',
#  'вселен',
#  ';',
#  'ег',
#  'душ',
#  'ещ',
#  'не',
#  'жил',
#  'по-настоя',
#  ',',
#  'но',
#  'собира',
#  'все',
#  'сво',
#  'сил',
#  ',',
#  'чтоб',
#  'переполн',
#  'жизн',
#  'и',
#  'прежд',
#  'времен',
#  'вырва',
#  'в',
#  'вечност',
#  ';',
#  '—',
#  'нищ',
#  'стоя',
#  'слож',
#  'рук',
#  'и',
#  'рассматрива',
#  'дьявол',
#  ',',
#  'изображен',
#  'поблекш',
#  'краск',
#  'на',
#  'св',
#  '.',
#  'врат',
#  ',',
#  'и',
#  'внутрен',
#  'сожалел',
#  'об',
#  'нем',
#  ';',
#  'он',
#  'дума',
#  ':',
#  'есл',
#  'б',
#  'я',
#  'был',
#  'чорт',
#  ',',
#  'то',
#  'не',
#  'муч',
#  'бы',
#  'люд',
#  ',',
#  'а',
#  'презира',
#  'бы',
#  'их',
#  ';',
#  'сто',
#  'ли',
#  'он',
#  ',',
#  'чтоб',
#  'их',
#  'соблазня',
#  'изгнанник',
#  'ра',
#  ',',
#  'соперник',
#  'бог',
#  '!',
#  '..',
#  'друг',
#  'дел',
#  'человек',
#  ';',
#  'чтоб',
#  'конч',
#  'презрен',
#  ',',
#  'он',
#  'долж',
#  'нача',
#  'с',
#  'ненавист',
#  '!',
#  'и',
#  'глаз',
#  'ег',
#  'блиста',
#  'под',
#  'беспокойн',
#  'бров',
#  ',',
#  'и',
#  'худ',
#  'щек',
#  'покрыва',
#  'красн',
#  'пятн',
#  ':',
#  'все',
#  'был',
#  'согласн',
#  'в',
#  'черт',
#  'нищ',
#  ':',
#  'одн',
#  'страст',
#  'владел',
#  'ег',
#  'сердц',
#  'ил',
#  'лучш',
#  'он',
#  'владел',
#  'одн',
#  'тольк',
#  'страст',
#  ',',
#  '—',
#  'но',
#  'зат',
#  'совершен',
#  '!',
#  '«',
#  'христ',
#  'рад',
#  ',',
#  'барин',
#  ',',
#  '—',
#  'погорел',
#  ',',
#  'калек',
#  ',',
#  'слепому…',
#  'христ',
#  'рад',
#  'копеечк',
#  '!',
#  '»',
#  '—',
#  'разда',
#  'крик',
#  'ег',
#  'товарищ',
#  ';',
#  'он',
#  'вздрогнул',
#  ',',
#  'обернул',
#  '—',
#  'и',
#  'в',
#  'этот',
#  'миг',
#  'реш',
#  'ег',
#  'участ',
#  '.',
#  '—',
#  'что',
#  'же',
#  'увида',
#  'он',
#  '?',
#  'русск',
#  'дворянин',
#  ',',
#  'борис',
#  'петрович',
#  'палицын',
#  '.',
#  'не',
#  'больш',
#  '.',
#  '[',
#  'глав',
#  'II',
#  ']',
#  'представьт',
#  'себ',
#  'мужчин',
#  'лет',
#  '50',
#  ',',
#  'высок',
#  ',',
#  'ещ',
#  'здоров',
#  ',',
#  'но',
#  'с',
#  'сед',
#  'волос',
#  'и',
#  'потухш',
#  'взор',
#  ',',
#  'одет',
#  'в',
#  'син',
#  'полукафтан',
#  'с',
#  'анненск',
#  'крест',
#  'в',
#  'петлиц',
#  ';',
#  'ног',
#  'ег',
#  ',',
#  'запрята',
#  'в',
#  'огромн',
#  'сапог',
#  ',',
#  'производ',
#  'неприятн',
#  'звук',
#  ',',
#  'ступ',
#  'на',
#  'пыльн',
#  'камн',
#  ';',
#  'он',
#  'шел',
#  'с',
#  'важност',
#  'размахив',
#  'рук',
#  'и',
#  'наморщива',
#  'высок',
#  'лоб',
#  'всяк',
#  'раз',
#  ',',
#  'как',
#  'докучлив',
#  'нищ',
#  'обступа',
#  'ег',
#  ';',
#  '—',
#  'дво',
#  'слуг',
#  'следова',
#  'за',
#  'ним',
#  'с',
#  'подобостраст',
#  '.',
#  '—',
#  'палицын',
#  'полож',
#  'серебрян',
#  'рубл',
#  'в',
#  'кружк',
#  'монастырск',
#  'и',
#  ',',
#  'оттолкнув',
#  'нищ',
#  ',',
#  'воскликнул',
#  ':',
#  '«',
#  'проч',
#  ',',
#  'вы',
#  '!',
#  '—',
#  'лентя',
#  '.',
#  '—',
#  'эк',
#  'молодц',
#  '—',
#  'а',
#  'прос',
#  'христ',
#  'рад',
#  ';',
#  'что',
#  'вы',
#  'не',
#  'работа',
#  '?',
#  'да',
#  'бог',
#  ',',
#  'чтоб',
#  'пришл',
#  'врем',
#  ',',
#  'когд',
#  'эт',
#  'бродяг',
#  'без',
#  'стыд',
#  'будут',
#  'мор',
#  'с',
#  'голод',
#  '.',
#  '—',
#  'вот',
#  'вам',
#  'рубл',
#  'на',
#  'всю',
#  'брат',
#  '.',
#  '—',
#  'тольк',
#  'чур',
#  'не',
#  'перекуса',
#  'за',
#  'нег',
#  '»',
#  '.',
#  'межд',
#  'тем',
#  'горбат',
#  'нищ',
#  'молч',
#  'приблиз',
#  'и',
#  'устрем',
#  'ярк',
#  'черн',
#  'глаз',
#  'на',
#  'великодушн',
#  'господин',
#  ';',
#  'этот',
#  'взор',
#  'был',
#  'останов',
#  'молн',
#  ',',
#  'и',
#  'человек',
#  ',',
#  'подвержен',
#  'ег',
#  'таинствен',
#  'влиян',
#  ',',
#  'долж',
#  'был',
#  'содрогнут',
#  'и',
#  'не',
#  'мог',
#  'отвеча',
#  'ем',
#  'тем',
#  'же',
#  ',',
#  'как',
#  'будт',
#  'свинцов',
#  'печа',
#  'тяготел',
#  'на',
#  'ег',
#  'век',
#  ';',
#  'есл',
#  'магнетизм',
#  'существ',
#  ',',
#  'то',
#  'взгляд',
#  'нищ',
#  'был',
#  'сильн',
#  'магнетизм',
#  '.',
#  'когд',
#  'стар',
#  'господин',
#  'удал',
#  'от',
#  'толп',
#  ',',
#  'он',
#  'поспеш',
#  'догна',
#  'ег',
#  '.',
#  'палицын',
#  'обернул',
#  '.',
#  '—',
#  'что',
#  'теб',
#  'надобн',
#  '?',
#  '—',
#  'очен',
#  'мал',
#  '!',
#  '—',
#  'я',
#  'хоч',
#  'работы…',
#  'с',
#  'язвительн',
#  'усмешк',
#  'посмотрел',
#  'старик',
#  'на',
#  'нищ',
#  ',',
#  'на',
#  'ег',
#  'горб',
#  'и',
#  'безобразн',
#  'ноги…',
#  'но',
#  'бедняк',
#  'нима',
#  'не',
#  'смут',
#  ',',
#  'и',
#  'оста',
#  'хладнокров',
#  ',',
#  'как',
#  'сократ',
#  ',',
#  'когд',
#  'жен',
#  'выл',
#  'кувшин',
#  'вод',
#  'на',
#  'ег',
#  'голов',
#  ',',
#  'но',
#  'эт',
#  'не',
#  'был',
#  'хладнокров',
#  'мудрец',
#  '—',
#  'нищ',
#  'был',
#  'скор',
#  'похож',
#  'на',
#  'дуэлист',
#  ',',
#  'котор',
#  'увер',
#  'в',
#  'меткост',
#  'рук',
#  'сво',
#  '.',
#  '—',
#  'есл',
#  'ты',
#  ',',
#  'барин',
#  ',',
#  'дума',
#  ',',
#  'что',
#  'я',
#  'не',
#  'мог',
#  'перенест',
#  'труд',
#  ',',
#  'то',
#  'я',
#  'теб',
#  'успок',
#  'на',
#  'этот',
#  'счет',
#  '.',
#  '—',
#  'он',
#  'подня',
#  'больш',
#  'камен',
#  'и',
#  'нача',
#  'им',
#  'игра',
#  'как',
#  'мячик',
#  ';',
#  'палицын',
#  'изум',
#  '.',
#  '—',
#  'хочеш',
#  'ли',
#  'быт',
#  'мо',
#  'слуг',
#  '?',
#  'нищ',
#  'в',
#  ...]

# %%
len(stemmed)
# Out:
# 40909

# %% [markdown]
# Forgive_us!

# %%
with open("2. Ашик-Кериб.txt") as file:
    text_1 = file.read()

# %%
words=word_tokenize(text_1)
words
# Out:
# ['Давно',
#  'тому',
#  'назад',
#  ',',
#  'в',
#  'городе',
#  'Тифлизе',
#  ',',
#  'жил',
#  'один',
#  'богатый',
#  'турок',
#  ';',
#  'много',
#  'аллах',
#  'дал',
#  'ему',
#  'золота',
#  ',',
#  'но',
#  'дороже',
#  'золота',
#  'была',
#  'ему',
#  'единственная',
#  'дочь',
#  'Магуль-Мегери',
#  ':',
#  'хороши',
#  'звезды',
#  'на',
#  'небеси',
#  ',',
#  'но',
#  'за',
#  'звездами',
#  'живут',
#  'ангелы',
#  ',',
#  'и',
#  'они',
#  'еще',
#  'лучше',
#  ',',
#  'так',
#  'и',
#  'Магуль-Мегери',
#  'была',
#  'лучше',
#  'всех',
#  'девушек',
#  'Тифлиза',
#  '.',
#  'Был',
#  'также',
#  'в',
#  'Тифлизе',
#  'бедный',
#  'Ашик-Кериб',
#  ';',
#  'пророк',
#  'не',
#  'дал',
#  'ему',
#  'ничего',
#  'кроме',
#  'высокого',
#  'сердца',
#  '–',
#  'и',
#  'дара',
#  'песен',
#  ';',
#  'играя',
#  'на',
#  'саазе',
#  '[',
#  'балалайка',
#  'турец',
#  '<',
#  'кая',
#  '>',
#  ']',
#  'и',
#  'прославляя',
#  'древних',
#  'витязей',
#  'Туркестана',
#  ',',
#  'ходил',
#  'он',
#  'по',
#  'свадьбам',
#  'увеселять',
#  'богатых',
#  'и',
#  'счастливых',
#  ';',
#  '–',
#  'на',
#  'одной',
#  'свадьбе',
#  'он',
#  'увидал',
#  'Магуль-Мегери',
#  ',',
#  'и',
#  'они',
#  'полюбили',
#  'друг',
#  'друга',
#  '.',
#  'Мало',
#  'было',
#  'надежды',
#  'у',
#  'бедного',
#  'Ашик-Кериба',
#  'получить',
#  'ее',
#  'руку',
#  '–',
#  'и',
#  'он',
#  'стал',
#  'грустен',
#  ',',
#  'как',
#  'зимнее',
#  'небо',
#  '.',
#  'Вот',
#  'раз',
#  'он',
#  'лежал',
#  'в',
#  'саду',
#  'под',
#  'виноградником',
#  'и',
#  'наконец',
#  'заснул',
#  ';',
#  'в',
#  'это',
#  'время',
#  'шла',
#  'мимо',
#  'Магуль-Мегери',
#  'с',
#  'своими',
#  'подругами',
#  ';',
#  'и',
#  'одна',
#  'из',
#  'них',
#  ',',
#  'увидав',
#  'спящего',
#  'ашика',
#  '[',
#  'балалаечник',
#  ']',
#  ',',
#  'отстала',
#  'и',
#  'подошла',
#  'к',
#  'нему',
#  ':',
#  '«',
#  'Что',
#  'ты',
#  'спишь',
#  'под',
#  'виноградником',
#  ',',
#  '–',
#  'запела',
#  'она',
#  ',',
#  '–',
#  'вставай',
#  ',',
#  'безумный',
#  ',',
#  'твоя',
#  'газель',
#  'идет',
#  'мимо',
#  '»',
#  ';',
#  'он',
#  'проснулся',
#  '–',
#  'девушка',
#  'порхнула',
#  'прочь',
#  ',',
#  'как',
#  'птичка',
#  ';',
#  'Магуль-Мегери',
#  'слышала',
#  'ее',
#  'песню',
#  'и',
#  'стала',
#  'ее',
#  'бранить',
#  ':',
#  '«',
#  'Если',
#  'б',
#  'ты',
#  'знала',
#  ',',
#  '–',
#  'отвечала',
#  'та',
#  ',',
#  '–',
#  'кому',
#  'я',
#  'пела',
#  'эту',
#  'песню',
#  ',',
#  'ты',
#  'бы',
#  'меня',
#  'поблагодарила',
#  ':',
#  'это',
#  'твой',
#  'Ашик-Кериб',
#  '»',
#  ';',
#  '–',
#  '«',
#  'Веди',
#  'меня',
#  'к',
#  'нему',
#  '»',
#  ',',
#  '–',
#  'сказала',
#  'Магуль-Мегери',
#  ';',
#  'и',
#  'они',
#  'пошли',
#  '.',
#  'Увидав',
#  'его',
#  'печальное',
#  'лицо',
#  ',',
#  'Магуль-Мегери',
#  'стала',
#  'его',
#  'спрашивать',
#  'и',
#  'утешать',
#  ';',
#  '«',
#  'Как',
#  'мне',
#  'не',
#  'грустить',
#  ',',
#  '–',
#  'отвечал',
#  'Ашик-Кериб',
#  ',',
#  '–',
#  'я',
#  'тебя',
#  'люблю',
#  ',',
#  'и',
#  'ты',
#  'никогда',
#  'не',
#  'будешь',
#  'моею',
#  '»',
#  '.',
#  '–',
#  '«',
#  'Проси',
#  'мою',
#  'руку',
#  'у',
#  'отца',
#  'моего',
#  ',',
#  '–',
#  'говорила',
#  'она',
#  ',',
#  '–',
#  'и',
#  'отец',
#  'мой',
#  'сыграет',
#  'нашу',
#  'свадьбу',
#  'на',
#  'свои',
#  'деньги',
#  'и',
#  'наградит',
#  'меня',
#  'столько',
#  ',',
#  'что',
#  'нам',
#  'вдвоем',
#  'достанет',
#  '»',
#  '.',
#  '–',
#  '«',
#  'Хорошо',
#  ',',
#  '–',
#  'отвечал',
#  'он',
#  ',',
#  '–',
#  'положим',
#  ',',
#  'Аян-Ага',
#  'ничего',
#  'не',
#  'пожалеет',
#  'для',
#  'своей',
#  'доч',
#  '<',
#  'ер',
#  '>',
#  'и',
#  ';',
#  'но',
#  'кто',
#  'знает',
#  ',',
#  'что',
#  'после',
#  'ты',
#  'не',
#  'будешь',
#  'меня',
#  'упрекать',
#  'в',
#  'том',
#  ',',
#  'что',
#  'я',
#  'ничего',
#  'не',
#  'имел',
#  'и',
#  'тебе',
#  'всем',
#  'обязан',
#  ';',
#  '–',
#  'нет',
#  ',',
#  'милая',
#  'Магуль-Мегери',
#  ';',
#  'я',
#  'положил',
#  'зарок',
#  'на',
#  'свою',
#  'душу',
#  ';',
#  'обещаюсь',
#  '7',
#  'лет',
#  'странствовать',
#  'по',
#  'свету',
#  'и',
#  'нажить',
#  'себе',
#  'богатство',
#  ',',
#  'либо',
#  'погибнуть',
#  'в',
#  'дальних',
#  'пустынях',
#  ';',
#  'если',
#  'ты',
#  'согласна',
#  'на',
#  'это',
#  ',',
#  'то',
#  'по',
#  'истечении',
#  'срока',
#  'будешь',
#  'моею',
#  '»',
#  '.',
#  '–',
#  'Она',
#  'согласилась',
#  ',',
#  'но',
#  'прибавила',
#  ',',
#  'что',
#  'если',
#  'в',
#  'назначенный',
#  'день',
#  'он',
#  'не',
#  'вернется',
#  ',',
#  'она',
#  'сделается',
#  'женою',
#  'Куршуд-бека',
#  ',',
#  'который',
#  'давно',
#  'уж',
#  'за',
#  'нее',
#  'сватается',
#  '.',
#  'Пришел',
#  'Ашик-Кериб',
#  'к',
#  'своей',
#  'матери',
#  ';',
#  'взял',
#  'на',
#  'дорогу',
#  'ее',
#  'благословение',
#  ',',
#  'поцеловал',
#  'маленькую',
#  'сестру',
#  ',',
#  'повесил',
#  'через',
#  'плечо',
#  'и',
#  'сумку',
#  ',',
#  'оперся',
#  'на',
#  'посох',
#  'странничий',
#  'и',
#  'вышел',
#  'из',
#  'города',
#  'Тифлиза',
#  '.',
#  'И',
#  'вот',
#  'догоняет',
#  'его',
#  'всадник',
#  ',',
#  '–',
#  'он',
#  'смотрит',
#  '–',
#  'это',
#  'Куршуд-бек',
#  '.',
#  '«',
#  'Добрый',
#  'путь',
#  ',',
#  '–',
#  'кричал',
#  'ему',
#  'бек',
#  ',',
#  '–',
#  'куда',
#  'бы',
#  'ты',
#  'ни',
#  'шел',
#  ',',
#  'странник',
#  ',',
#  'я',
#  'твой',
#  'товарищ',
#  '»',
#  ';',
#  'не',
#  'рад',
#  'был',
#  'Ашик',
#  'своему',
#  'товарищу',
#  '–',
#  'но',
#  'нечего',
#  'делать',
#  ';',
#  'долго',
#  'они',
#  'шли',
#  'вместе',
#  ',',
#  'наконец',
#  'завидели',
#  'перед',
#  'собою',
#  'реку',
#  '.',
#  'Ни',
#  'моста',
#  ',',
#  'ни',
#  'броду',
#  ';',
#  '–',
#  '«',
#  'Плыви',
#  'вперед',
#  ',',
#  '–',
#  'сказал',
#  'Куршуд-бек',
#  ',',
#  '–',
#  'я',
#  'за',
#  'тобою',
#  'последую',
#  '»',
#  '.',
#  'Ашик',
#  'сбросил',
#  'верхнее',
#  'платье',
#  'и',
#  'поплыл',
#  ';',
#  'переправившись',
#  ',',
#  'глядь',
#  'назад',
#  '–',
#  'о',
#  'горе',
#  '!',
#  'о',
#  'всемогущий',
#  'аллах',
#  '!',
#  'Куршуд-бек',
#  ',',
#  'взяв',
#  'его',
#  'одежды',
#  ',',
#  'ускакал',
#  'обратно',
#  'в',
#  'Тифлиз',
#  ',',
#  'только',
#  'пыль',
#  'вилась',
#  'за',
#  'ним',
#  'змеею',
#  'по',
#  'гладкому',
#  'полю',
#  '.',
#  'Прискакав',
#  'в',
#  'Тифлиз',
#  ',',
#  'несет',
#  'бек',
#  'платье',
#  'Ашик-Кериба',
#  'к',
#  'его',
#  'старой',
#  'матери',
#  ':',
#  '«',
#  'Твой',
#  'сын',
#  'утонул',
#  'в',
#  'глубокой',
#  'реке',
#  ',',
#  '–',
#  'говорит',
#  'он',
#  ',',
#  '–',
#  'вот',
#  'его',
#  'одежда',
#  '»',
#  ';',
#  'в',
#  'невыразимой',
#  'тоске',
#  'упала',
#  'мать',
#  'на',
#  'одежды',
#  'любимого',
#  'сына',
#  'и',
#  'стала',
#  'обливать',
#  'их',
#  'жаркими',
#  'слезами',
#  ';',
#  'потом',
#  'взяла',
#  'их',
#  'и',
#  'понесла',
#  'к',
#  'нареченной',
#  'невестке',
#  'своей',
#  ',',
#  'Магуль-Мегери',
#  '.',
#  '«',
#  'Мой',
#  'сын',
#  'утонул',
#  ',',
#  '–',
#  'сказала',
#  'она',
#  'ей',
#  ',',
#  '–',
#  'Куршуд-бек',
#  'привез',
#  'его',
#  'одежды',
#  ';',
#  'ты',
#  'свободна',
#  '»',
#  '.',
#  'Магуль-Мегери',
#  'улыбнулась',
#  'и',
#  'отвечала',
#  ':',
#  '«',
#  'Не',
#  'верь',
#  ',',
#  'это',
#  'всё',
#  'выдумки',
#  'Куршуд-бека',
#  ';',
#  'прежде',
#  'истечения',
#  '7',
#  'лет',
#  'никто',
#  'не',
#  'будет',
#  'моим',
#  'мужем',
#  '»',
#  ';',
#  'она',
#  'взяла',
#  'со',
#  'стены',
#  'свою',
#  'сааз',
#  'и',
#  'спокойно',
#  'начала',
#  'петь',
#  'любимую',
#  'песню',
#  'бедного',
#  'Ашик-Кериба',
#  '.',
#  'Между',
#  'тем',
#  'странник',
#  'пришел',
#  'бос',
#  'и',
#  'наг',
#  'в',
#  'одну',
#  'деревню',
#  ';',
#  'добрые',
#  'люди',
#  'одели',
#  'его',
#  'и',
#  'накормили',
#  ';',
#  'он',
#  'за',
#  'то',
#  'пел',
#  'им',
#  'чудные',
#  'песни',
#  ';',
#  'таким',
#  'образом',
#  'переходил',
#  'он',
#  'из',
#  'деревни',
#  'в',
#  'деревню',
#  ',',
#  'из',
#  'города',
#  'в',
#  'город',
#  ':',
#  'и',
#  'слава',
#  'его',
#  'разнеслась',
#  'повсюду',
#  '.',
#  'Прибыл',
#  'он',
#  'наконец',
#  'в',
#  'Халаф',
#  ';',
#  'по',
#  'обыкновению',
#  'взошел',
#  'в',
#  'кофейный',
#  'дом',
#  ',',
#  'спросил',
#  'сааз',
#  'и',
#  'стал',
#  'петь',
#  '.',
#  'В',
#  'это',
#  'время',
#  'жил',
#  'в',
#  'Халафе',
#  'паша',
#  ',',
#  'большой',
#  'охотник',
#  'до',
#  'песельников',
#  ':',
#  'многих',
#  'к',
#  'нему',
#  'приводили',
#  '–',
#  'ни',
#  'один',
#  'ему',
#  'не',
#  'понравился',
#  ';',
#  'его',
#  'чауши',
#  'измучились',
#  ',',
#  'бегая',
#  'по',
#  'городу',
#  ':',
#  'вдруг',
#  ',',
#  'проходя',
#  'мимо',
#  'кофейного',
#  'дома',
#  ',',
#  'слышат',
#  'удивительный',
#  'голос',
#  ';',
#  'они',
#  'туда',
#  ':',
#  '«',
#  'Иди',
#  'с',
#  'нами',
#  'к',
#  'великому',
#  'паше',
#  ',',
#  '–',
#  'закричали',
#  'они',
#  ',',
#  '–',
#  'или',
#  'ты',
#  'отвечаешь',
#  'нам',
#  'головою',
#  '»',
#  '.',
#  '«',
#  'Я',
#  'человек',
#  'вольный',
#  ',',
#  'странник',
#  'из',
#  'города',
#  'Тифлиза',
#  ',',
#  '–',
#  'говорит',
#  'Ашик-Кериб',
#  ';',
#  '–',
#  'хочу',
#  'пойду',
#  ',',
#  'хочу',
#  'нет',
#  ';',
#  'пою',
#  ',',
#  'когда',
#  'придется',
#  ',',
#  'и',
#  'ваш',
#  'паша',
#  'мне',
#  'не',
#  'начальник',
#  '»',
#  ';',
#  'однако',
#  ',',
#  'несмотря',
#  'на',
#  'то',
#  ',',
#  'его',
#  'схватили',
#  'и',
#  'привели',
#  'к',
#  'паше',
#  '.',
#  '«',
#  'Пой',
#  '»',
#  ',',
#  'сказал',
#  'паша',
#  ',',
#  'и',
#  'он',
#  'запел',
#  '.',
#  'И',
#  'в',
#  'этой',
#  'песни',
#  'он',
#  'славил',
#  'свою',
#  'дорогую',
#  'Магуль-Мегери',
#  ';',
#  'и',
#  'эта',
#  'песня',
#  'так',
#  'понравилась',
#  'гордому',
#  'паше',
#  ',',
#  'что',
#  'он',
#  'оставил',
#  'у',
#  'себя',
#  'бедного',
#  'Ашик-Кериба',
#  '.',
#  'Посыпалось',
#  'к',
#  'нему',
#  'серебро',
#  'и',
#  'золото',
#  ',',
#  'заблистали',
#  'на',
#  'нем',
#  'богатые',
#  'одежды',
#  ';',
#  'счастливо',
#  'и',
#  'весело',
#  'стал',
#  'жить',
#  'Ашик-Кериб',
#  'и',
#  'сделался',
#  'очень',
#  'богат',
#  ';',
#  'забыл',
#  'он',
#  'свою',
#  'Магуль-Мегери',
#  'или',
#  'нет',
#  ',',
#  'не',
#  'знаю',
#  ',',
#  'толь',
#  '<',
#  'ко',
#  '>',
#  'срок',
#  'истекал',
#  ',',
#  'последний',
#  'год',
#  'скоро',
#  'должен',
#  'был',
#  'кончиться',
#  ',',
#  'а',
#  'он',
#  'и',
#  'не',
#  'готовился',
#  'к',
#  'отъезду',
#  '.',
#  'Прекрасная',
#  'Магуль-Мегери',
#  'стала',
#  'отчаиваться',
#  ':',
#  'в',
#  'это',
#  'время',
#  'отправлялся',
#  'один',
#  'купец',
#  'с',
#  'керваном',
#  'из',
#  'Тифлиза',
#  ...]

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['Давно',
#  'тому',
#  'назад',
#  ',',
#  'городе',
#  'Тифлизе',
#  ',',
#  'жил',
#  'богатый',
#  'турок',
#  ';',
#  'аллах',
#  'дал',
#  'золота',
#  ',',
#  'дороже',
#  'золота',
#  'единственная',
#  'дочь',
#  'Магуль-Мегери',
#  ':',
#  'хороши',
#  'звезды',
#  'небеси',
#  ',',
#  'звездами',
#  'живут',
#  'ангелы',
#  ',',
#  ',',
#  'Магуль-Мегери',
#  'девушек',
#  'Тифлиза',
#  '.',
#  'Был',
#  'также',
#  'Тифлизе',
#  'бедный',
#  'Ашик-Кериб',
#  ';',
#  'пророк',
#  'дал',
#  'кроме',
#  'высокого',
#  'сердца',
#  '–',
#  'дара',
#  'песен',
#  ';',
#  'играя',
#  'саазе',
#  '[',
#  'балалайка',
#  'турец',
#  '<',
#  'кая',
#  '>',
#  ']',
#  'прославляя',
#  'древних',
#  'витязей',
#  'Туркестана',
#  ',',
#  'ходил',
#  'свадьбам',
#  'увеселять',
#  'богатых',
#  'счастливых',
#  ';',
#  '–',
#  'одной',
#  'свадьбе',
#  'увидал',
#  'Магуль-Мегери',
#  ',',
#  'полюбили',
#  'друг',
#  'друга',
#  '.',
#  'Мало',
#  'надежды',
#  'бедного',
#  'Ашик-Кериба',
#  'получить',
#  'руку',
#  '–',
#  'стал',
#  'грустен',
#  ',',
#  'зимнее',
#  'небо',
#  '.',
#  'Вот',
#  'лежал',
#  'саду',
#  'виноградником',
#  'заснул',
#  ';',
#  'это',
#  'время',
#  'шла',
#  'мимо',
#  'Магуль-Мегери',
#  'своими',
#  'подругами',
#  ';',
#  'одна',
#  ',',
#  'увидав',
#  'спящего',
#  'ашика',
#  '[',
#  'балалаечник',
#  ']',
#  ',',
#  'отстала',
#  'подошла',
#  'нему',
#  ':',
#  '«',
#  'Что',
#  'спишь',
#  'виноградником',
#  ',',
#  '–',
#  'запела',
#  ',',
#  '–',
#  'вставай',
#  ',',
#  'безумный',
#  ',',
#  'твоя',
#  'газель',
#  'идет',
#  'мимо',
#  '»',
#  ';',
#  'проснулся',
#  '–',
#  'девушка',
#  'порхнула',
#  'прочь',
#  ',',
#  'птичка',
#  ';',
#  'Магуль-Мегери',
#  'слышала',
#  'песню',
#  'стала',
#  'бранить',
#  ':',
#  '«',
#  'Если',
#  'б',
#  'знала',
#  ',',
#  '–',
#  'отвечала',
#  'та',
#  ',',
#  '–',
#  'кому',
#  'пела',
#  'песню',
#  ',',
#  'поблагодарила',
#  ':',
#  'это',
#  'твой',
#  'Ашик-Кериб',
#  '»',
#  ';',
#  '–',
#  '«',
#  'Веди',
#  'нему',
#  '»',
#  ',',
#  '–',
#  'сказала',
#  'Магуль-Мегери',
#  ';',
#  'пошли',
#  '.',
#  'Увидав',
#  'печальное',
#  'лицо',
#  ',',
#  'Магуль-Мегери',
#  'стала',
#  'спрашивать',
#  'утешать',
#  ';',
#  '«',
#  'Как',
#  'грустить',
#  ',',
#  '–',
#  'отвечал',
#  'Ашик-Кериб',
#  ',',
#  '–',
#  'люблю',
#  ',',
#  'будешь',
#  'моею',
#  '»',
#  '.',
#  '–',
#  '«',
#  'Проси',
#  'мою',
#  'руку',
#  'отца',
#  'моего',
#  ',',
#  '–',
#  'говорила',
#  ',',
#  '–',
#  'отец',
#  'сыграет',
#  'нашу',
#  'свадьбу',
#  'свои',
#  'деньги',
#  'наградит',
#  'столько',
#  ',',
#  'нам',
#  'вдвоем',
#  'достанет',
#  '»',
#  '.',
#  '–',
#  '«',
#  'Хорошо',
#  ',',
#  '–',
#  'отвечал',
#  ',',
#  '–',
#  'положим',
#  ',',
#  'Аян-Ага',
#  'пожалеет',
#  'своей',
#  'доч',
#  '<',
#  'ер',
#  '>',
#  ';',
#  'знает',
#  ',',
#  'будешь',
#  'упрекать',
#  ',',
#  'имел',
#  'тебе',
#  'всем',
#  'обязан',
#  ';',
#  '–',
#  ',',
#  'милая',
#  'Магуль-Мегери',
#  ';',
#  'положил',
#  'зарок',
#  'душу',
#  ';',
#  'обещаюсь',
#  '7',
#  'лет',
#  'странствовать',
#  'свету',
#  'нажить',
#  'богатство',
#  ',',
#  'либо',
#  'погибнуть',
#  'дальних',
#  'пустынях',
#  ';',
#  'согласна',
#  'это',
#  ',',
#  'истечении',
#  'срока',
#  'будешь',
#  'моею',
#  '»',
#  '.',
#  '–',
#  'Она',
#  'согласилась',
#  ',',
#  'прибавила',
#  ',',
#  'назначенный',
#  'день',
#  'вернется',
#  ',',
#  'сделается',
#  'женою',
#  'Куршуд-бека',
#  ',',
#  'который',
#  'давно',
#  'сватается',
#  '.',
#  'Пришел',
#  'Ашик-Кериб',
#  'своей',
#  'матери',
#  ';',
#  'взял',
#  'дорогу',
#  'благословение',
#  ',',
#  'поцеловал',
#  'маленькую',
#  'сестру',
#  ',',
#  'повесил',
#  'плечо',
#  'сумку',
#  ',',
#  'оперся',
#  'посох',
#  'странничий',
#  'вышел',
#  'города',
#  'Тифлиза',
#  '.',
#  'И',
#  'догоняет',
#  'всадник',
#  ',',
#  '–',
#  'смотрит',
#  '–',
#  'это',
#  'Куршуд-бек',
#  '.',
#  '«',
#  'Добрый',
#  'путь',
#  ',',
#  '–',
#  'кричал',
#  'бек',
#  ',',
#  '–',
#  'шел',
#  ',',
#  'странник',
#  ',',
#  'твой',
#  'товарищ',
#  '»',
#  ';',
#  'рад',
#  'Ашик',
#  'своему',
#  'товарищу',
#  '–',
#  'нечего',
#  'делать',
#  ';',
#  'долго',
#  'шли',
#  'вместе',
#  ',',
#  'завидели',
#  'собою',
#  'реку',
#  '.',
#  'Ни',
#  'моста',
#  ',',
#  'броду',
#  ';',
#  '–',
#  '«',
#  'Плыви',
#  'вперед',
#  ',',
#  '–',
#  'сказал',
#  'Куршуд-бек',
#  ',',
#  '–',
#  'тобою',
#  'последую',
#  '»',
#  '.',
#  'Ашик',
#  'сбросил',
#  'верхнее',
#  'платье',
#  'поплыл',
#  ';',
#  'переправившись',
#  ',',
#  'глядь',
#  'назад',
#  '–',
#  'горе',
#  '!',
#  'всемогущий',
#  'аллах',
#  '!',
#  'Куршуд-бек',
#  ',',
#  'взяв',
#  'одежды',
#  ',',
#  'ускакал',
#  'обратно',
#  'Тифлиз',
#  ',',
#  'пыль',
#  'вилась',
#  'змеею',
#  'гладкому',
#  'полю',
#  '.',
#  'Прискакав',
#  'Тифлиз',
#  ',',
#  'несет',
#  'бек',
#  'платье',
#  'Ашик-Кериба',
#  'старой',
#  'матери',
#  ':',
#  '«',
#  'Твой',
#  'сын',
#  'утонул',
#  'глубокой',
#  'реке',
#  ',',
#  '–',
#  'говорит',
#  ',',
#  '–',
#  'одежда',
#  '»',
#  ';',
#  'невыразимой',
#  'тоске',
#  'упала',
#  'мать',
#  'одежды',
#  'любимого',
#  'сына',
#  'стала',
#  'обливать',
#  'жаркими',
#  'слезами',
#  ';',
#  'взяла',
#  'понесла',
#  'нареченной',
#  'невестке',
#  'своей',
#  ',',
#  'Магуль-Мегери',
#  '.',
#  '«',
#  'Мой',
#  'сын',
#  'утонул',
#  ',',
#  '–',
#  'сказала',
#  ',',
#  '–',
#  'Куршуд-бек',
#  'привез',
#  'одежды',
#  ';',
#  'свободна',
#  '»',
#  '.',
#  'Магуль-Мегери',
#  'улыбнулась',
#  'отвечала',
#  ':',
#  '«',
#  'Не',
#  'верь',
#  ',',
#  'это',
#  'всё',
#  'выдумки',
#  'Куршуд-бека',
#  ';',
#  'прежде',
#  'истечения',
#  '7',
#  'лет',
#  'никто',
#  'моим',
#  'мужем',
#  '»',
#  ';',
#  'взяла',
#  'стены',
#  'сааз',
#  'спокойно',
#  'начала',
#  'петь',
#  'любимую',
#  'песню',
#  'бедного',
#  'Ашик-Кериба',
#  '.',
#  'Между',
#  'странник',
#  'пришел',
#  'бос',
#  'наг',
#  'одну',
#  'деревню',
#  ';',
#  'добрые',
#  'люди',
#  'одели',
#  'накормили',
#  ';',
#  'пел',
#  'чудные',
#  'песни',
#  ';',
#  'таким',
#  'образом',
#  'переходил',
#  'деревни',
#  'деревню',
#  ',',
#  'города',
#  'город',
#  ':',
#  'слава',
#  'разнеслась',
#  'повсюду',
#  '.',
#  'Прибыл',
#  'Халаф',
#  ';',
#  'обыкновению',
#  'взошел',
#  'кофейный',
#  'дом',
#  ',',
#  'спросил',
#  'сааз',
#  'стал',
#  'петь',
#  '.',
#  'В',
#  'это',
#  'время',
#  'жил',
#  'Халафе',
#  'паша',
#  ',',
#  'большой',
#  'охотник',
#  'песельников',
#  ':',
#  'многих',
#  'нему',
#  'приводили',
#  '–',
#  'понравился',
#  ';',
#  'чауши',
#  'измучились',
#  ',',
#  'бегая',
#  'городу',
#  ':',
#  ',',
#  'проходя',
#  'мимо',
#  'кофейного',
#  'дома',
#  ',',
#  'слышат',
#  'удивительный',
#  'голос',
#  ';',
#  'туда',
#  ':',
#  '«',
#  'Иди',
#  'нами',
#  'великому',
#  'паше',
#  ',',
#  '–',
#  'закричали',
#  ',',
#  '–',
#  'отвечаешь',
#  'нам',
#  'головою',
#  '»',
#  '.',
#  '«',
#  'Я',
#  'человек',
#  'вольный',
#  ',',
#  'странник',
#  'города',
#  'Тифлиза',
#  ',',
#  '–',
#  'говорит',
#  'Ашик-Кериб',
#  ';',
#  '–',
#  'хочу',
#  'пойду',
#  ',',
#  'хочу',
#  ';',
#  'пою',
#  ',',
#  'придется',
#  ',',
#  'ваш',
#  'паша',
#  'начальник',
#  '»',
#  ';',
#  'однако',
#  ',',
#  'несмотря',
#  ',',
#  'схватили',
#  'привели',
#  'паше',
#  '.',
#  '«',
#  'Пой',
#  '»',
#  ',',
#  'сказал',
#  'паша',
#  ',',
#  'запел',
#  '.',
#  'И',
#  'песни',
#  'славил',
#  'дорогую',
#  'Магуль-Мегери',
#  ';',
#  'эта',
#  'песня',
#  'понравилась',
#  'гордому',
#  'паше',
#  ',',
#  'оставил',
#  'бедного',
#  'Ашик-Кериба',
#  '.',
#  'Посыпалось',
#  'нему',
#  'серебро',
#  'золото',
#  ',',
#  'заблистали',
#  'нем',
#  'богатые',
#  'одежды',
#  ';',
#  'счастливо',
#  'весело',
#  'стал',
#  'жить',
#  'Ашик-Кериб',
#  'сделался',
#  'очень',
#  'богат',
#  ';',
#  'забыл',
#  'Магуль-Мегери',
#  ',',
#  'знаю',
#  ',',
#  'толь',
#  '<',
#  'ко',
#  '>',
#  'срок',
#  'истекал',
#  ',',
#  'последний',
#  'год',
#  'скоро',
#  'должен',
#  'кончиться',
#  ',',
#  'готовился',
#  'отъезду',
#  '.',
#  'Прекрасная',
#  'Магуль-Мегери',
#  'стала',
#  'отчаиваться',
#  ':',
#  'это',
#  'время',
#  'отправлялся',
#  'купец',
#  'керваном',
#  'Тифлиза',
#  'сорока',
#  'верблюдами',
#  '80-ю',
#  'невольниками',
#  ':',
#  'призывает',
#  'купца',
#  'дает',
#  'золотое',
#  'блюдо',
#  ':',
#  '«',
#  'Возьми',
#  'это',
#  'блюдо',
#  ',',
#  '–',
#  'говорит',
#  ',',
#  '–',
#  'город',
#  'приехал',
#  ',',
#  'выставь',
#  'это',
#  'блюдо',
#  'своей',
#  'лавке',
#  'объяви',
#  'везде',
#  ',',
#  ',',
#  'признается',
#  'моему',
#  'блюду',
#  'хозяином',
#  'докажет',
#  'это',
#  ',',
#  'получит',
#  'вдобавок',
#  'вес',
#  'золотом',
#  '»',
#  '.',
#  'Отправился',
#  'купец',
#  ',',
#  'везде',
#  'исполнял',
#  'поручение',
#  'Магуль-Мегери',
#  ',',
#  'никто',
#  'признался',
#  'хозяином',
#  'золотому',
#  'блюду',
#  '.',
#  'Уж',
#  'продал',
#  'свои',
#  'товары',
#  'приехал',
#  'остальными',
#  'Халаф',
#  ':',
#  'объявил',
#  'везде',
#  'поручение',
#  'Магуль-Мегери',
#  '.',
#  'Услыхав',
#  'это',
#  ',',
#  'Ашик-Кериб',
#  'прибегает',
#  'караван-сарай',
#  ':',
#  'видит',
#  'золотое',
#  'блюдо',
#  'лавке',
#  'тифлизского',
#  'купца',
#  '.',
#  '«',
#  'Это',
#  'мое',
#  '»',
#  ',',
#  '–',
#  'сказал',
#  ',',
#  'схватив',
#  'рукою',
#  '.',
#  '«',
#  'Точно',
#  ',',
#  'твое',
#  ',',
#  '–',
#  'сказал',
#  'купец',
#  ':',
#  '–',
#  'узнал',
#  ',',
#  'Ашик-Кериб',
#  ':',
#  'ступай',
#  'скорее',
#  'Тифлиз',
#  ',',
#  'твоя',
#  'Магуль-Мегери',
#  'велела',
#  'тебе',
#  'сказать',
#  ',',
#  'срок',
#  'истекает',
#  ',',
#  'будешь',
#  'назначенный',
#  'день',
#  ',',
#  'выдет',
#  'другого',
#  '»',
#  ';',
#  '–',
#  'отчаянии',
#  'Ашик-Кериб',
#  'схватил',
#  'голову',
#  ':',
#  'оставалось',
#  '3',
#  'дни',
#  'рокового',
#  'часа',
#  '.',
#  'Однако',
#  'сел',
#  'коня',
#  ',',
#  'взял',
#  'собою',
#  'суму',
#  'золотыми',
#  'монетами',
#  '–',
#  'поскакал',
#  ',',
#  'жалея',
#  'коня',
#  ';',
#  'измученный',
#  'бегун',
#  'упал',
#  'бездыханный',
#  'Арзинган',
#  'горе',
#  ',',
#  'Арзиньяном',
#  'Арзерумом',
#  '.',
#  'Что',
#  'делать',
#  ':',
#  'Арзиньяна',
#  'Тифлиза',
#  'месяца',
#  'езды',
#  ',',
#  'оставалось',
#  'дни',
#  '.',
#  '«',
#  'Аллах',
#  'всемогущий',
#  ',',
#  '–',
#  'воскликнул',
#  ',',
#  '–',
#  'помогаешь',
#  ',',
#  'нечего',
#  'земле',
#  'делать',
#  '»',
#  ';',
#  'хочет',
#  'броситься',
#  'высокого',
#  'утеса',
#  ';',
#  'видит',
#  'внизу',
#  'человека',
#  'белом',
#  'коне',
#  ';',
#  'слышит',
#  'громкий',
#  'голос',
#  ':',
#  '«',
#  'Оглан',
#  ',',
#  'хочешь',
#  'делать',
#  '?',
#  '»',
#  '«',
#  'Хочу',
#  'умереть',
#  '»',
#  ',',
#  '–',
#  'отвечал',
#  'Ашик',
#  '.',
#  '«',
#  'Слезай',
#  'сюда',
#  ',',
#  ',',
#  'убью',
#  '»',
#  '.',
#  'Ашик',
#  'спустился',
#  'кое-как',
#  'утеса',
#  '.',
#  '«',
#  'Ступай',
#  'мною',
#  '»',
#  ',',
#  '–',
#  'сказал',
#  'грозно',
#  'всадник',
#  ';',
#  '«',
#  'Как',
#  'могу',
#  'тобою',
#  'следовать',
#  ',',
#  '–',
#  'отвечал',
#  'Ашик',
#  ',',
#  '–',
#  'твой',
#  'конь',
#  'летит',
#  ',',
#  'ветер',
#  ',',
#  'отягощен',
#  'сумою',
#  '»',
#  ';',
#  '–',
#  '«',
#  'Правда',
#  ...]

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_1)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['давн',
#  'том',
#  'назад',
#  ',',
#  'в',
#  'город',
#  'тифлиз',
#  ',',
#  'жил',
#  'один',
#  'богат',
#  'турок',
#  ';',
#  'мног',
#  'алл',
#  'дал',
#  'ем',
#  'золот',
#  ',',
#  'но',
#  'дорож',
#  'золот',
#  'был',
#  'ем',
#  'единствен',
#  'доч',
#  'магуль-мегер',
#  ':',
#  'хорош',
#  'звезд',
#  'на',
#  'небес',
#  ',',
#  'но',
#  'за',
#  'звезд',
#  'живут',
#  'ангел',
#  ',',
#  'и',
#  'он',
#  'ещ',
#  'лучш',
#  ',',
#  'так',
#  'и',
#  'магуль-мегер',
#  'был',
#  'лучш',
#  'всех',
#  'девушек',
#  'тифлиз',
#  '.',
#  'был',
#  'такж',
#  'в',
#  'тифлиз',
#  'бедн',
#  'ашик-кериб',
#  ';',
#  'пророк',
#  'не',
#  'дал',
#  'ем',
#  'нич',
#  'кром',
#  'высок',
#  'сердц',
#  '–',
#  'и',
#  'дар',
#  'пес',
#  ';',
#  'игр',
#  'на',
#  'сааз',
#  '[',
#  'балалайк',
#  'турец',
#  '<',
#  'ка',
#  '>',
#  ']',
#  'и',
#  'прославл',
#  'древн',
#  'витяз',
#  'туркеста',
#  ',',
#  'ход',
#  'он',
#  'по',
#  'свадьб',
#  'увеселя',
#  'богат',
#  'и',
#  'счастлив',
#  ';',
#  '–',
#  'на',
#  'одн',
#  'свадьб',
#  'он',
#  'увида',
#  'магуль-мегер',
#  ',',
#  'и',
#  'он',
#  'полюб',
#  'друг',
#  'друг',
#  '.',
#  'мал',
#  'был',
#  'надежд',
#  'у',
#  'бедн',
#  'ашик-кериб',
#  'получ',
#  'е',
#  'рук',
#  '–',
#  'и',
#  'он',
#  'стал',
#  'груст',
#  ',',
#  'как',
#  'зимн',
#  'неб',
#  '.',
#  'вот',
#  'раз',
#  'он',
#  'лежа',
#  'в',
#  'сад',
#  'под',
#  'виноградник',
#  'и',
#  'наконец',
#  'заснул',
#  ';',
#  'в',
#  'эт',
#  'врем',
#  'шла',
#  'мим',
#  'магуль-мегер',
#  'с',
#  'сво',
#  'подруг',
#  ';',
#  'и',
#  'одн',
#  'из',
#  'них',
#  ',',
#  'увида',
#  'спящ',
#  'ашик',
#  '[',
#  'балалаечник',
#  ']',
#  ',',
#  'отста',
#  'и',
#  'подошл',
#  'к',
#  'нем',
#  ':',
#  '«',
#  'что',
#  'ты',
#  'спиш',
#  'под',
#  'виноградник',
#  ',',
#  '–',
#  'запел',
#  'он',
#  ',',
#  '–',
#  'встава',
#  ',',
#  'безумн',
#  ',',
#  'тво',
#  'газел',
#  'идет',
#  'мим',
#  '»',
#  ';',
#  'он',
#  'проснул',
#  '–',
#  'девушк',
#  'порхнул',
#  'проч',
#  ',',
#  'как',
#  'птичк',
#  ';',
#  'магуль-мегер',
#  'слыша',
#  'е',
#  'песн',
#  'и',
#  'стал',
#  'е',
#  'бран',
#  ':',
#  '«',
#  'есл',
#  'б',
#  'ты',
#  'знал',
#  ',',
#  '–',
#  'отвеча',
#  'та',
#  ',',
#  '–',
#  'ком',
#  'я',
#  'пел',
#  'эт',
#  'песн',
#  ',',
#  'ты',
#  'бы',
#  'мен',
#  'поблагодар',
#  ':',
#  'эт',
#  'тво',
#  'ашик-кериб',
#  '»',
#  ';',
#  '–',
#  '«',
#  'вед',
#  'мен',
#  'к',
#  'нем',
#  '»',
#  ',',
#  '–',
#  'сказа',
#  'магуль-мегер',
#  ';',
#  'и',
#  'он',
#  'пошл',
#  '.',
#  'увида',
#  'ег',
#  'печальн',
#  'лиц',
#  ',',
#  'магуль-мегер',
#  'стал',
#  'ег',
#  'спрашива',
#  'и',
#  'утеша',
#  ';',
#  '«',
#  'как',
#  'мне',
#  'не',
#  'груст',
#  ',',
#  '–',
#  'отвеча',
#  'ашик-кериб',
#  ',',
#  '–',
#  'я',
#  'теб',
#  'любл',
#  ',',
#  'и',
#  'ты',
#  'никогд',
#  'не',
#  'будеш',
#  'мо',
#  '»',
#  '.',
#  '–',
#  '«',
#  'прос',
#  'мо',
#  'рук',
#  'у',
#  'отц',
#  'мо',
#  ',',
#  '–',
#  'говор',
#  'он',
#  ',',
#  '–',
#  'и',
#  'отец',
#  'мо',
#  'сыгра',
#  'наш',
#  'свадьб',
#  'на',
#  'сво',
#  'деньг',
#  'и',
#  'наград',
#  'мен',
#  'стольк',
#  ',',
#  'что',
#  'нам',
#  'вдво',
#  'достанет',
#  '»',
#  '.',
#  '–',
#  '«',
#  'хорош',
#  ',',
#  '–',
#  'отвеча',
#  'он',
#  ',',
#  '–',
#  'полож',
#  ',',
#  'аян-аг',
#  'нич',
#  'не',
#  'пожалеет',
#  'для',
#  'сво',
#  'доч',
#  '<',
#  'ер',
#  '>',
#  'и',
#  ';',
#  'но',
#  'кто',
#  'знает',
#  ',',
#  'что',
#  'посл',
#  'ты',
#  'не',
#  'будеш',
#  'мен',
#  'упрека',
#  'в',
#  'том',
#  ',',
#  'что',
#  'я',
#  'нич',
#  'не',
#  'имел',
#  'и',
#  'теб',
#  'всем',
#  'обяза',
#  ';',
#  '–',
#  'нет',
#  ',',
#  'мил',
#  'магуль-мегер',
#  ';',
#  'я',
#  'полож',
#  'зарок',
#  'на',
#  'сво',
#  'душ',
#  ';',
#  'обеща',
#  '7',
#  'лет',
#  'странствова',
#  'по',
#  'свет',
#  'и',
#  'наж',
#  'себ',
#  'богатств',
#  ',',
#  'либ',
#  'погибнут',
#  'в',
#  'дальн',
#  'пустын',
#  ';',
#  'есл',
#  'ты',
#  'согласн',
#  'на',
#  'эт',
#  ',',
#  'то',
#  'по',
#  'истечен',
#  'срок',
#  'будеш',
#  'мо',
#  '»',
#  '.',
#  '–',
#  'он',
#  'соглас',
#  ',',
#  'но',
#  'прибав',
#  ',',
#  'что',
#  'есл',
#  'в',
#  'назначен',
#  'ден',
#  'он',
#  'не',
#  'вернет',
#  ',',
#  'он',
#  'сдела',
#  'жен',
#  'куршуд-бек',
#  ',',
#  'котор',
#  'давн',
#  'уж',
#  'за',
#  'не',
#  'свата',
#  '.',
#  'пришел',
#  'ашик-кериб',
#  'к',
#  'сво',
#  'матер',
#  ';',
#  'взял',
#  'на',
#  'дорог',
#  'е',
#  'благословен',
#  ',',
#  'поцелова',
#  'маленьк',
#  'сестр',
#  ',',
#  'повес',
#  'через',
#  'плеч',
#  'и',
#  'сумк',
#  ',',
#  'опер',
#  'на',
#  'посох',
#  'страннич',
#  'и',
#  'вышел',
#  'из',
#  'город',
#  'тифлиз',
#  '.',
#  'и',
#  'вот',
#  'догоня',
#  'ег',
#  'всадник',
#  ',',
#  '–',
#  'он',
#  'смотр',
#  '–',
#  'эт',
#  'куршуд-бек',
#  '.',
#  '«',
#  'добр',
#  'пут',
#  ',',
#  '–',
#  'крича',
#  'ем',
#  'бек',
#  ',',
#  '–',
#  'куд',
#  'бы',
#  'ты',
#  'ни',
#  'шел',
#  ',',
#  'странник',
#  ',',
#  'я',
#  'тво',
#  'товарищ',
#  '»',
#  ';',
#  'не',
#  'рад',
#  'был',
#  'ашик',
#  'сво',
#  'товарищ',
#  '–',
#  'но',
#  'неч',
#  'дела',
#  ';',
#  'долг',
#  'он',
#  'шли',
#  'вмест',
#  ',',
#  'наконец',
#  'завидел',
#  'перед',
#  'соб',
#  'рек',
#  '.',
#  'ни',
#  'мост',
#  ',',
#  'ни',
#  'брод',
#  ';',
#  '–',
#  '«',
#  'плыв',
#  'вперед',
#  ',',
#  '–',
#  'сказа',
#  'куршуд-бек',
#  ',',
#  '–',
#  'я',
#  'за',
#  'тоб',
#  'послед',
#  '»',
#  '.',
#  'ашик',
#  'сброс',
#  'верхн',
#  'плат',
#  'и',
#  'попл',
#  ';',
#  'переправ',
#  ',',
#  'гляд',
#  'назад',
#  '–',
#  'о',
#  'гор',
#  '!',
#  'о',
#  'всемогущ',
#  'алл',
#  '!',
#  'куршуд-бек',
#  ',',
#  'взяв',
#  'ег',
#  'одежд',
#  ',',
#  'ускака',
#  'обратн',
#  'в',
#  'тифлиз',
#  ',',
#  'тольк',
#  'пыл',
#  'вил',
#  'за',
#  'ним',
#  'зме',
#  'по',
#  'гладк',
#  'пол',
#  '.',
#  'прискака',
#  'в',
#  'тифлиз',
#  ',',
#  'несет',
#  'бек',
#  'плат',
#  'ашик-кериб',
#  'к',
#  'ег',
#  'стар',
#  'матер',
#  ':',
#  '«',
#  'тво',
#  'сын',
#  'утонул',
#  'в',
#  'глубок',
#  'рек',
#  ',',
#  '–',
#  'говор',
#  'он',
#  ',',
#  '–',
#  'вот',
#  'ег',
#  'одежд',
#  '»',
#  ';',
#  'в',
#  'невыразим',
#  'тоск',
#  'упа',
#  'мат',
#  'на',
#  'одежд',
#  'любим',
#  'сын',
#  'и',
#  'стал',
#  'облива',
#  'их',
#  'жарк',
#  'слез',
#  ';',
#  'пот',
#  'взял',
#  'их',
#  'и',
#  'понесл',
#  'к',
#  'наречен',
#  'невестк',
#  'сво',
#  ',',
#  'магуль-мегер',
#  '.',
#  '«',
#  'мо',
#  'сын',
#  'утонул',
#  ',',
#  '–',
#  'сказа',
#  'он',
#  'е',
#  ',',
#  '–',
#  'куршуд-бек',
#  'привез',
#  'ег',
#  'одежд',
#  ';',
#  'ты',
#  'свободн',
#  '»',
#  '.',
#  'магуль-мегер',
#  'улыбнул',
#  'и',
#  'отвеча',
#  ':',
#  '«',
#  'не',
#  'вер',
#  ',',
#  'эт',
#  'все',
#  'выдумк',
#  'куршуд-бек',
#  ';',
#  'прежд',
#  'истечен',
#  '7',
#  'лет',
#  'никт',
#  'не',
#  'будет',
#  'мо',
#  'муж',
#  '»',
#  ';',
#  'он',
#  'взял',
#  'со',
#  'стен',
#  'сво',
#  'сааз',
#  'и',
#  'спокойн',
#  'нача',
#  'пет',
#  'любим',
#  'песн',
#  'бедн',
#  'ашик-кериб',
#  '.',
#  'межд',
#  'тем',
#  'странник',
#  'пришел',
#  'бос',
#  'и',
#  'наг',
#  'в',
#  'одн',
#  'деревн',
#  ';',
#  'добр',
#  'люд',
#  'одел',
#  'ег',
#  'и',
#  'накорм',
#  ';',
#  'он',
#  'за',
#  'то',
#  'пел',
#  'им',
#  'чудн',
#  'песн',
#  ';',
#  'так',
#  'образ',
#  'переход',
#  'он',
#  'из',
#  'деревн',
#  'в',
#  'деревн',
#  ',',
#  'из',
#  'город',
#  'в',
#  'город',
#  ':',
#  'и',
#  'слав',
#  'ег',
#  'разнесл',
#  'повсюд',
#  '.',
#  'приб',
#  'он',
#  'наконец',
#  'в',
#  'халаф',
#  ';',
#  'по',
#  'обыкновен',
#  'взошел',
#  'в',
#  'кофейн',
#  'дом',
#  ',',
#  'спрос',
#  'сааз',
#  'и',
#  'стал',
#  'пет',
#  '.',
#  'в',
#  'эт',
#  'врем',
#  'жил',
#  'в',
#  'халаф',
#  'паш',
#  ',',
#  'больш',
#  'охотник',
#  'до',
#  'песельник',
#  ':',
#  'мног',
#  'к',
#  'нем',
#  'привод',
#  '–',
#  'ни',
#  'один',
#  'ем',
#  'не',
#  'понрав',
#  ';',
#  'ег',
#  'чауш',
#  'измуч',
#  ',',
#  'бег',
#  'по',
#  'город',
#  ':',
#  'вдруг',
#  ',',
#  'проход',
#  'мим',
#  'кофейн',
#  'дом',
#  ',',
#  'слышат',
#  'удивительн',
#  'голос',
#  ';',
#  'он',
#  'туд',
#  ':',
#  '«',
#  'ид',
#  'с',
#  'нам',
#  'к',
#  'велик',
#  'паш',
#  ',',
#  '–',
#  'закрича',
#  'он',
#  ',',
#  '–',
#  'ил',
#  'ты',
#  'отвеча',
#  'нам',
#  'голов',
#  '»',
#  '.',
#  '«',
#  'я',
#  'человек',
#  'вольн',
#  ',',
#  'странник',
#  'из',
#  'город',
#  'тифлиз',
#  ',',
#  '–',
#  'говор',
#  'ашик-кериб',
#  ';',
#  '–',
#  'хоч',
#  'пойд',
#  ',',
#  'хоч',
#  'нет',
#  ';',
#  'по',
#  ',',
#  'когд',
#  'придет',
#  ',',
#  'и',
#  'ваш',
#  'паш',
#  'мне',
#  'не',
#  'начальник',
#  '»',
#  ';',
#  'однак',
#  ',',
#  'несмотр',
#  'на',
#  'то',
#  ',',
#  'ег',
#  'схват',
#  'и',
#  'привел',
#  'к',
#  'паш',
#  '.',
#  '«',
#  'по',
#  '»',
#  ',',
#  'сказа',
#  'паш',
#  ',',
#  'и',
#  'он',
#  'запел',
#  '.',
#  'и',
#  'в',
#  'эт',
#  'песн',
#  'он',
#  'слав',
#  'сво',
#  'дорог',
#  'магуль-мегер',
#  ';',
#  'и',
#  'эт',
#  'песн',
#  'так',
#  'понрав',
#  'горд',
#  'паш',
#  ',',
#  'что',
#  'он',
#  'остав',
#  'у',
#  'себ',
#  'бедн',
#  'ашик-кериб',
#  '.',
#  'посыпа',
#  'к',
#  'нем',
#  'серебр',
#  'и',
#  'золот',
#  ',',
#  'заблиста',
#  'на',
#  'нем',
#  'богат',
#  'одежд',
#  ';',
#  'счастлив',
#  'и',
#  'весел',
#  'стал',
#  'жит',
#  'ашик-кериб',
#  'и',
#  'сдела',
#  'очен',
#  'богат',
#  ';',
#  'заб',
#  'он',
#  'сво',
#  'магуль-мегер',
#  'ил',
#  'нет',
#  ',',
#  'не',
#  'зна',
#  ',',
#  'тол',
#  '<',
#  'ко',
#  '>',
#  'срок',
#  'истека',
#  ',',
#  'последн',
#  'год',
#  'скор',
#  'долж',
#  'был',
#  'конч',
#  ',',
#  'а',
#  'он',
#  'и',
#  'не',
#  'готов',
#  'к',
#  'отъезд',
#  '.',
#  'прекрасн',
#  'магуль-мегер',
#  'стал',
#  'отчаива',
#  ':',
#  'в',
#  'эт',
#  'врем',
#  'отправля',
#  'один',
#  'купец',
#  'с',
#  'керван',
#  'из',
#  'тифлиз',
#  ...]

# %%
len(stemmed)
# Out:
# 4789

# %%
len(words)
# Out:
# 4789

# %%
len(tokenized_filtered)
# Out:
# 3655

# %% [markdown]
# Neprotivlenie

# %%
with open("3. Княгиня Лиговская.txt", encoding="utf-8") as file:
    text_2 = file.read()

# %%
words=word_tokenize(text_2)
words
# Out:
# ['ГЛАВА',
#  'I',
#  'Поди',
#  '!',
#  '—',
#  'поди',
#  '!',
#  'раздался',
#  'крик',
#  '!',
#  'Пушкин',
#  'В',
#  '1833',
#  'году',
#  ',',
#  'декабря',
#  '21-го',
#  'дня',
#  'в',
#  '4',
#  'часа',
#  'пополудни',
#  'по',
#  'Вознесенской',
#  'улице',
#  ',',
#  'как',
#  'обыкновенно',
#  ',',
#  'валила',
#  'толпа',
#  'народу',
#  ',',
#  'и',
#  'между',
#  'прочим',
#  'шел',
#  'один',
#  'молодой',
#  'чиновник',
#  ';',
#  'заметьте',
#  'день',
#  'и',
#  'час',
#  ',',
#  'потому',
#  'что',
#  'в',
#  'этот',
#  'день',
#  'и',
#  'в',
#  'этот',
#  'час',
#  'случилось',
#  'событие',
#  ',',
#  'от',
#  'которого',
#  'тянется',
#  'цепь',
#  'различных',
#  'приключений',
#  ',',
#  'постигших',
#  'всех',
#  'моих',
#  'героев',
#  'и',
#  'героинь',
#  ',',
#  'историю',
#  'которых',
#  'я',
#  'обещался',
#  'передать',
#  'потомству',
#  ',',
#  'если',
#  'потомство',
#  'станет',
#  'читать',
#  'романы',
#  '.',
#  '—',
#  'Итак',
#  ',',
#  'по',
#  'Вознесенской',
#  'шел',
#  'один',
#  'молодой',
#  'чиновник',
#  ',',
#  'и',
#  'шел',
#  'он',
#  'из',
#  'департамента',
#  ',',
#  'утомленный',
#  'однообразной',
#  'работой',
#  ',',
#  'и',
#  'мечтая',
#  'о',
#  'награде',
#  'и',
#  'вкусном',
#  'обеде',
#  '—',
#  'ибо',
#  'все',
#  'чиновники',
#  'мечтают',
#  '!',
#  '—',
#  'На',
#  'нем',
#  'был',
#  'картуз',
#  'неопределенной',
#  'формы',
#  'и',
#  'синяя',
#  'ваточная',
#  'шинель',
#  'с',
#  'старым',
#  'бобровым',
#  'воротником',
#  ';',
#  'черты',
#  'лица',
#  'его',
#  'различить',
#  'было',
#  'трудно',
#  ':',
#  'причиною',
#  'тому',
#  'козырек',
#  ',',
#  'воротник',
#  '—',
#  'и',
#  'сумерки',
#  ';',
#  '—',
#  'казалось',
#  ',',
#  'он',
#  'не',
#  'торопился',
#  'домой',
#  ',',
#  'а',
#  'наслаждался',
#  'чистым',
#  'воздухом',
#  'морозного',
#  'вечера',
#  ',',
#  'разливавшего',
#  'сквозь',
#  'зимнюю',
#  'мглу',
#  'розовые',
#  'лучи',
#  'свои',
#  'по',
#  'кровлям',
#  'домов',
#  ',',
#  'соблазнительным',
#  'блистаньем',
#  'магазинов',
#  'и',
#  'кондитерских',
#  ';',
#  'порою',
#  'подняв',
#  'глаза',
#  'кверху',
#  'с',
#  'истинно',
#  'поэтическим',
#  'умиленьем',
#  ',',
#  'сталкивался',
#  'он',
#  'с',
#  'какой-нибудь',
#  'розовой',
#  'шляпкой',
#  'и',
#  'смутившись',
#  'извинялся',
#  ';',
#  'коварная',
#  'розовая',
#  'шляпка',
#  'сердилась',
#  ',',
#  '—',
#  'потом',
#  'заглядывала',
#  'ему',
#  'под',
#  'картуз',
#  'и',
#  ',',
#  'пройдя',
#  'несколько',
#  'шагов',
#  ',',
#  'оборачивалась',
#  ',',
#  'как',
#  'будто',
#  'ожидая',
#  'вторичного',
#  'извинения',
#  ';',
#  'напрасно',
#  '!',
#  'молодой',
#  'чиновник',
#  'был',
#  'совершенно',
#  'недогадлив',
#  '!',
#  '..',
#  'но',
#  'еще',
#  'чаще',
#  'он',
#  'останавливался',
#  ',',
#  'чтоб',
#  'поглазеть',
#  'сквозь',
#  'цельные',
#  'окна',
#  'магазина',
#  'или',
#  'кондитерской',
#  ',',
#  'блистающей',
#  'чудными',
#  'огнями',
#  'и',
#  'великолепной',
#  'позолотою',
#  '.',
#  'Долго',
#  ',',
#  'пристально',
#  ',',
#  'с',
#  'завистью',
#  'разглядывал',
#  'различные',
#  'предметы',
#  ',',
#  '—',
#  'и',
#  ',',
#  'опомнившись',
#  ',',
#  'с',
#  'глубоким',
#  'вздохом',
#  'и',
#  'стоическою',
#  'твердостью',
#  'продолжал',
#  'свой',
#  'путь',
#  ';',
#  '—',
#  'самые',
#  'же',
#  'ужасные',
#  'мучители',
#  'его',
#  'были',
#  'извозчики',
#  ',',
#  '—',
#  'и',
#  'он',
#  'ненавидел',
#  'извозчиков',
#  ';',
#  '«',
#  'барин',
#  '!',
#  'куда',
#  'изволите',
#  '?',
#  '—',
#  'прикажете',
#  'подавать',
#  '?',
#  '—',
#  'подавать-с',
#  '!',
#  '»',
#  'Это',
#  'была',
#  'пытка',
#  'Тантала',
#  ',',
#  'и',
#  'он',
#  'в',
#  'душе',
#  'глубоко',
#  'ненавидел',
#  'извозчиков',
#  '.',
#  'Спустясь',
#  'с',
#  'Вознесенского',
#  'моста',
#  'и',
#  'собираясь',
#  'поворотить',
#  'направо',
#  'по',
#  'канаве',
#  ',',
#  'вдруг',
#  'слышит',
#  'он',
#  'крик',
#  ':',
#  '«',
#  'берегись',
#  ',',
#  'поди',
#  '!',
#  '..',
#  '»',
#  'Прямо',
#  'на',
#  'него',
#  'летел',
#  'гнедой',
#  'рысак',
#  ';',
#  'из-за',
#  'кучера',
#  'мелькал',
#  'белый',
#  'султан',
#  ',',
#  'и',
#  'развевался',
#  'воротник',
#  'серой',
#  'шинели',
#  '.',
#  '—',
#  'Едва',
#  'он',
#  'успел',
#  'поднять',
#  'глаза',
#  ',',
#  'уж',
#  'одна',
#  'оглобля',
#  'была',
#  'против',
#  'его',
#  'груди',
#  ',',
#  'и',
#  'пар',
#  ',',
#  'вылетавший',
#  'клубами',
#  'из',
#  'ноздрей',
#  'бегуна',
#  ',',
#  'обдал',
#  'ему',
#  'лицо',
#  ';',
#  'машинально',
#  'он',
#  'ухватился',
#  'руками',
#  'за',
#  'оглоблю',
#  'и',
#  'в',
#  'тот',
#  'же',
#  'миг',
#  'сильным',
#  'порывом',
#  'лошади',
#  'был',
#  'отброшен',
#  'несколько',
#  'шагов',
#  'в',
#  'сторону',
#  'на',
#  'тротуар…',
#  'раздалось',
#  'кругом',
#  ':',
#  '«',
#  'задавил',
#  ',',
#  'задавил',
#  '»',
#  ',',
#  'извозчики',
#  'погнались',
#  'за',
#  'нарушителем',
#  'порядка',
#  ',',
#  '—',
#  'но',
#  'белый',
#  'султан',
#  'только',
#  'мелькнул',
#  'у',
#  'них',
#  'перед',
#  'глазами',
#  'и',
#  'был',
#  'таков',
#  '.',
#  'Когда',
#  'чиновник',
#  'очнулся',
#  ',',
#  'боли',
#  'он',
#  'нигде',
#  'не',
#  'чувствовал',
#  ',',
#  'но',
#  'колена',
#  'у',
#  'него',
#  'тряслись',
#  'еще',
#  'от',
#  'страха',
#  ';',
#  'он',
#  'встал',
#  ',',
#  'облокотился',
#  'на',
#  'перилы',
#  'канавы',
#  ',',
#  'стараясь',
#  'придти',
#  'в',
#  'себя',
#  ';',
#  'горькие',
#  'думы',
#  'овладели',
#  'его',
#  'сердцем',
#  ',',
#  'и',
#  'с',
#  'этой',
#  'минуты',
#  'перенес',
#  'он',
#  'всю',
#  'ненависть',
#  ',',
#  'к',
#  'какой',
#  'его',
#  'душа',
#  'только',
#  'была',
#  'способна',
#  ',',
#  'с',
#  'извозчиков',
#  'на',
#  'гнедых',
#  'рысаков',
#  'и',
#  'белые',
#  'султаны',
#  '.',
#  'Между',
#  'тем',
#  'белый',
#  'султан',
#  'и',
#  'гнедой',
#  'рысак',
#  'пронеслись',
#  'вдоль',
#  'до',
#  'по',
#  'каналу',
#  ',',
#  'поворотили',
#  'на',
#  'Невский',
#  ',',
#  'с',
#  'Невского',
#  'на',
#  'Караванную',
#  ',',
#  'оттуда',
#  'на',
#  'Симионовский',
#  'мост',
#  ',',
#  'потом',
#  'направо',
#  'по',
#  'Фонтанке',
#  '—',
#  'и',
#  'тут',
#  'остановились',
#  'у',
#  'богатого',
#  'подъезда',
#  ',',
#  'с',
#  'навесом',
#  'и',
#  'стеклянными',
#  'дверьми',
#  ',',
#  'с',
#  'медной',
#  'блестящею',
#  'обделкой',
#  '.',
#  'Ну',
#  ',',
#  'сударь',
#  ',',
#  '—',
#  'сказал',
#  'кучер',
#  ',',
#  'широкоплечий',
#  'мужик',
#  'с',
#  'окладистой',
#  'рыжей',
#  'бородой',
#  ',',
#  '—',
#  'Васька',
#  'нынче',
#  'показал',
#  'себя',
#  '!',
#  'Надобно',
#  'заметить',
#  ',',
#  'что',
#  'у',
#  'кучеров',
#  'любимая',
#  'их',
#  'лошадь',
#  'называется',
#  'всегда',
#  'Ваською',
#  ',',
#  'даже',
#  'вопреки',
#  'желанию',
#  'господ',
#  ',',
#  'наделяющих',
#  'ее',
#  'громкими',
#  'именами',
#  'Ахилла',
#  ',',
#  'Гектора…',
#  'она',
#  'всё-таки',
#  'будет',
#  'для',
#  'кучера',
#  'не',
#  'Ахел',
#  'и',
#  'не',
#  'Нектор',
#  ',',
#  'а',
#  'Васька',
#  '.',
#  'Офицер',
#  'слез',
#  ',',
#  'потрепал',
#  'дымящегося',
#  'рысака',
#  'по',
#  'крутой',
#  'шее',
#  ',',
#  'улыбнулся',
#  'ему',
#  'признательно',
#  'и',
#  'взошел',
#  'на',
#  'блестящую',
#  'лестницу',
#  ';',
#  '—',
#  'об',
#  'раздавленном',
#  'чиновнике',
#  'не',
#  'было',
#  'и',
#  'помину…',
#  'Теперь',
#  ',',
#  'когда',
#  'он',
#  'снял',
#  'шинель',
#  ',',
#  'закиданную',
#  'снегом',
#  ',',
#  'и',
#  'взошел',
#  'в',
#  'свой',
#  'кабинет',
#  ',',
#  'мы',
#  'свободно',
#  'можем',
#  'пойти',
#  'за',
#  'ним',
#  'и',
#  'описать',
#  'его',
#  'наружность',
#  '—',
#  'к',
#  'несчастию',
#  ',',
#  'вовсе',
#  'не',
#  'привлекательную',
#  ';',
#  'он',
#  'был',
#  'небольшого',
#  'роста',
#  ',',
#  'широк',
#  'в',
#  'плечах',
#  'и',
#  'вообще',
#  'нескладен',
#  ';',
#  'казался',
#  'сильного',
#  'сложения',
#  ',',
#  'неспособного',
#  'к',
#  'чувствительности',
#  'и',
#  'раздражению',
#  ';',
#  'походка',
#  'его',
#  'была',
#  'несколько',
#  'осторожна',
#  'для',
#  'кавалериста',
#  ',',
#  'жесты',
#  'его',
#  'были',
#  'отрывисты',
#  ',',
#  'хотя',
#  'часто',
#  'они',
#  'выказывали',
#  'лень',
#  'и',
#  'беззаботное',
#  'равнодушие',
#  ',',
#  'которое',
#  'теперь',
#  'в',
#  'моде',
#  'и',
#  'в',
#  'духе',
#  'века',
#  ',',
#  '—',
#  'если',
#  'это',
#  'не',
#  'плеоназм',
#  '.',
#  '—',
#  'Но',
#  'сквозь',
#  'эту',
#  'холодную',
#  'кору',
#  'прорывалась',
#  'часто',
#  'настоящая',
#  'природа',
#  'человека',
#  ';',
#  'видно',
#  'было',
#  ',',
#  'что',
#  'он',
#  'следовал',
#  'не',
#  'всеобщей',
#  'моде',
#  ',',
#  'а',
#  'сжимал',
#  'свои',
#  'чувства',
#  'и',
#  'мысли',
#  'из',
#  'недоверчивости',
#  'или',
#  'из',
#  'гордости',
#  '.',
#  'Звуки',
#  'его',
#  'голоса',
#  'были',
#  'то',
#  'густы',
#  ',',
#  'то',
#  'резки',
#  ',',
#  'смотря',
#  'по',
#  'влиянию',
#  'текущей',
#  'минуты',
#  ':',
#  'когда',
#  'он',
#  'хотел',
#  'говорить',
#  'приятно',
#  ',',
#  'то',
#  'начинал',
#  'запинаться',
#  ',',
#  'и',
#  'вдруг',
#  'оканчивал',
#  'едкой',
#  'шуткой',
#  ',',
#  'чтоб',
#  'скрыть',
#  'собственное',
#  'смущение',
#  ',',
#  '—',
#  'и',
#  'в',
#  'свете',
#  'утверждали',
#  ',',
#  'что',
#  'язык',
#  'его',
#  'зол',
#  'и',
#  'опасен…',
#  'ибо',
#  'свет',
#  'не',
#  'терпит',
#  'в',
#  'кругу',
#  'своем',
#  'ничего',
#  'сильного',
#  ',',
#  'потрясающего',
#  ',',
#  'ничего',
#  ',',
#  'что',
#  'бы',
#  'могло',
#  'обличить',
#  'характер',
#  'и',
#  'волю',
#  ':',
#  '—',
#  'свету',
#  'нужны',
#  'французские',
#  'водевили',
#  'и',
#  'русская',
#  'покорность',
#  'чуждому',
#  'мнению',
#  '.',
#  'Лицо',
#  'его',
#  'смуглое',
#  ',',
#  'неправильное',
#  ',',
#  'но',
#  'полное',
#  'выразительности',
#  ',',
#  'было',
#  'бы',
#  'любопытно',
#  'для',
#  'Лафатера',
#  'и',
#  'его',
#  'последователей',
#  ':',
#  'они',
#  'прочли',
#  'бы',
#  'на',
#  'нем',
#  'глубокие',
#  'следы',
#  'прошедшего',
#  'и',
#  'чудные',
#  'обещания',
#  'будущности…',
#  'толпа',
#  'же',
#  'говорила',
#  ',',
#  'что',
#  'в',
#  'его',
#  'улыбке',
#  ',',
#  'в',
#  'его',
#  'странно',
#  'блестящих',
#  'глазах',
#  'есть',
#  'что-то…',
#  'В',
#  'заключение',
#  'портрета',
#  'скажу',
#  ',',
#  'что',
#  'он',
#  'назывался',
#  'Григорий',
#  'Александрович',
#  'Печорин',
#  ',',
#  'а',
#  'между',
#  'родными',
#  'просто',
#  'Жорж',
#  ',',
#  'на',
#  'французский',
#  'лад',
#  ',',
#  'и',
#  'что',
#  'притом',
#  'ему',
#  'было',
#  '23',
#  'года',
#  ',',
#  '—',
#  'и',
#  'что',
#  'у',
#  'родителей',
#  'его',
#  'было',
#  '3',
#  'тысячи',
#  'душ',
#  'в',
#  'Саратовской',
#  ',',
#  'Воронежской',
#  'и',
#  'Калужской',
#  'губернии',
#  ',',
#  '—',
#  'последнее',
#  'я',
#  'прибавляю',
#  ',',
#  'чтоб',
#  'немного',
#  'скрасить',
#  'его',
#  'наружность',
#  'во',
#  'мнении',
#  'строгих',
#  'читателей',
#  '!',
#  '—',
#  'виноват',
#  ',',
#  'забыл',
#  'включить',
#  ',',
#  'что',
#  'Жорж',
#  'был',
#  'единственный',
#  'сын',
#  ',',
#  'не',
#  'считая',
#  'сестры',
#  ',',
#  '16-летней',
#  'девочки',
#  ',',
#  'которая',
#  'была',
#  'очень',
#  'недурна',
#  'собою',
#  'и',
#  ',',
#  'по',
#  'словам',
#  'маменьки',
#  '(',
#  'папеньки',
#  'уж',
#  'не',
#  'было',
#  'на',
#  ...]

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['ГЛАВА',
#  'I',
#  'Поди',
#  '!',
#  '—',
#  'поди',
#  '!',
#  'раздался',
#  'крик',
#  '!',
#  'Пушкин',
#  'В',
#  '1833',
#  'году',
#  ',',
#  'декабря',
#  '21-го',
#  'дня',
#  '4',
#  'часа',
#  'пополудни',
#  'Вознесенской',
#  'улице',
#  ',',
#  'обыкновенно',
#  ',',
#  'валила',
#  'толпа',
#  'народу',
#  ',',
#  'прочим',
#  'шел',
#  'молодой',
#  'чиновник',
#  ';',
#  'заметьте',
#  'день',
#  'час',
#  ',',
#  'день',
#  'час',
#  'случилось',
#  'событие',
#  ',',
#  'которого',
#  'тянется',
#  'цепь',
#  'различных',
#  'приключений',
#  ',',
#  'постигших',
#  'моих',
#  'героев',
#  'героинь',
#  ',',
#  'историю',
#  'которых',
#  'обещался',
#  'передать',
#  'потомству',
#  ',',
#  'потомство',
#  'станет',
#  'читать',
#  'романы',
#  '.',
#  '—',
#  'Итак',
#  ',',
#  'Вознесенской',
#  'шел',
#  'молодой',
#  'чиновник',
#  ',',
#  'шел',
#  'департамента',
#  ',',
#  'утомленный',
#  'однообразной',
#  'работой',
#  ',',
#  'мечтая',
#  'награде',
#  'вкусном',
#  'обеде',
#  '—',
#  'ибо',
#  'чиновники',
#  'мечтают',
#  '!',
#  '—',
#  'На',
#  'нем',
#  'картуз',
#  'неопределенной',
#  'формы',
#  'синяя',
#  'ваточная',
#  'шинель',
#  'старым',
#  'бобровым',
#  'воротником',
#  ';',
#  'черты',
#  'лица',
#  'различить',
#  'трудно',
#  ':',
#  'причиною',
#  'тому',
#  'козырек',
#  ',',
#  'воротник',
#  '—',
#  'сумерки',
#  ';',
#  '—',
#  'казалось',
#  ',',
#  'торопился',
#  'домой',
#  ',',
#  'наслаждался',
#  'чистым',
#  'воздухом',
#  'морозного',
#  'вечера',
#  ',',
#  'разливавшего',
#  'сквозь',
#  'зимнюю',
#  'мглу',
#  'розовые',
#  'лучи',
#  'свои',
#  'кровлям',
#  'домов',
#  ',',
#  'соблазнительным',
#  'блистаньем',
#  'магазинов',
#  'кондитерских',
#  ';',
#  'порою',
#  'подняв',
#  'глаза',
#  'кверху',
#  'истинно',
#  'поэтическим',
#  'умиленьем',
#  ',',
#  'сталкивался',
#  'какой-нибудь',
#  'розовой',
#  'шляпкой',
#  'смутившись',
#  'извинялся',
#  ';',
#  'коварная',
#  'розовая',
#  'шляпка',
#  'сердилась',
#  ',',
#  '—',
#  'заглядывала',
#  'картуз',
#  ',',
#  'пройдя',
#  'несколько',
#  'шагов',
#  ',',
#  'оборачивалась',
#  ',',
#  'ожидая',
#  'вторичного',
#  'извинения',
#  ';',
#  'напрасно',
#  '!',
#  'молодой',
#  'чиновник',
#  'совершенно',
#  'недогадлив',
#  '!',
#  '..',
#  'чаще',
#  'останавливался',
#  ',',
#  'поглазеть',
#  'сквозь',
#  'цельные',
#  'окна',
#  'магазина',
#  'кондитерской',
#  ',',
#  'блистающей',
#  'чудными',
#  'огнями',
#  'великолепной',
#  'позолотою',
#  '.',
#  'Долго',
#  ',',
#  'пристально',
#  ',',
#  'завистью',
#  'разглядывал',
#  'различные',
#  'предметы',
#  ',',
#  '—',
#  ',',
#  'опомнившись',
#  ',',
#  'глубоким',
#  'вздохом',
#  'стоическою',
#  'твердостью',
#  'продолжал',
#  'свой',
#  'путь',
#  ';',
#  '—',
#  'самые',
#  'ужасные',
#  'мучители',
#  'извозчики',
#  ',',
#  '—',
#  'ненавидел',
#  'извозчиков',
#  ';',
#  '«',
#  'барин',
#  '!',
#  'изволите',
#  '?',
#  '—',
#  'прикажете',
#  'подавать',
#  '?',
#  '—',
#  'подавать-с',
#  '!',
#  '»',
#  'Это',
#  'пытка',
#  'Тантала',
#  ',',
#  'душе',
#  'глубоко',
#  'ненавидел',
#  'извозчиков',
#  '.',
#  'Спустясь',
#  'Вознесенского',
#  'моста',
#  'собираясь',
#  'поворотить',
#  'направо',
#  'канаве',
#  ',',
#  'слышит',
#  'крик',
#  ':',
#  '«',
#  'берегись',
#  ',',
#  'поди',
#  '!',
#  '..',
#  '»',
#  'Прямо',
#  'летел',
#  'гнедой',
#  'рысак',
#  ';',
#  'из-за',
#  'кучера',
#  'мелькал',
#  'белый',
#  'султан',
#  ',',
#  'развевался',
#  'воротник',
#  'серой',
#  'шинели',
#  '.',
#  '—',
#  'Едва',
#  'успел',
#  'поднять',
#  'глаза',
#  ',',
#  'одна',
#  'оглобля',
#  'против',
#  'груди',
#  ',',
#  'пар',
#  ',',
#  'вылетавший',
#  'клубами',
#  'ноздрей',
#  'бегуна',
#  ',',
#  'обдал',
#  'лицо',
#  ';',
#  'машинально',
#  'ухватился',
#  'руками',
#  'оглоблю',
#  'миг',
#  'сильным',
#  'порывом',
#  'лошади',
#  'отброшен',
#  'несколько',
#  'шагов',
#  'сторону',
#  'тротуар…',
#  'раздалось',
#  'кругом',
#  ':',
#  '«',
#  'задавил',
#  ',',
#  'задавил',
#  '»',
#  ',',
#  'извозчики',
#  'погнались',
#  'нарушителем',
#  'порядка',
#  ',',
#  '—',
#  'белый',
#  'султан',
#  'мелькнул',
#  'глазами',
#  'таков',
#  '.',
#  'Когда',
#  'чиновник',
#  'очнулся',
#  ',',
#  'боли',
#  'нигде',
#  'чувствовал',
#  ',',
#  'колена',
#  'тряслись',
#  'страха',
#  ';',
#  'встал',
#  ',',
#  'облокотился',
#  'перилы',
#  'канавы',
#  ',',
#  'стараясь',
#  'придти',
#  ';',
#  'горькие',
#  'думы',
#  'овладели',
#  'сердцем',
#  ',',
#  'минуты',
#  'перенес',
#  'ненависть',
#  ',',
#  'душа',
#  'способна',
#  ',',
#  'извозчиков',
#  'гнедых',
#  'рысаков',
#  'белые',
#  'султаны',
#  '.',
#  'Между',
#  'белый',
#  'султан',
#  'гнедой',
#  'рысак',
#  'пронеслись',
#  'вдоль',
#  'каналу',
#  ',',
#  'поворотили',
#  'Невский',
#  ',',
#  'Невского',
#  'Караванную',
#  ',',
#  'оттуда',
#  'Симионовский',
#  'мост',
#  ',',
#  'направо',
#  'Фонтанке',
#  '—',
#  'остановились',
#  'богатого',
#  'подъезда',
#  ',',
#  'навесом',
#  'стеклянными',
#  'дверьми',
#  ',',
#  'медной',
#  'блестящею',
#  'обделкой',
#  '.',
#  'Ну',
#  ',',
#  'сударь',
#  ',',
#  '—',
#  'сказал',
#  'кучер',
#  ',',
#  'широкоплечий',
#  'мужик',
#  'окладистой',
#  'рыжей',
#  'бородой',
#  ',',
#  '—',
#  'Васька',
#  'нынче',
#  'показал',
#  '!',
#  'Надобно',
#  'заметить',
#  ',',
#  'кучеров',
#  'любимая',
#  'лошадь',
#  'называется',
#  'Ваською',
#  ',',
#  'вопреки',
#  'желанию',
#  'господ',
#  ',',
#  'наделяющих',
#  'громкими',
#  'именами',
#  'Ахилла',
#  ',',
#  'Гектора…',
#  'всё-таки',
#  'кучера',
#  'Ахел',
#  'Нектор',
#  ',',
#  'Васька',
#  '.',
#  'Офицер',
#  'слез',
#  ',',
#  'потрепал',
#  'дымящегося',
#  'рысака',
#  'крутой',
#  'шее',
#  ',',
#  'улыбнулся',
#  'признательно',
#  'взошел',
#  'блестящую',
#  'лестницу',
#  ';',
#  '—',
#  'раздавленном',
#  'чиновнике',
#  'помину…',
#  'Теперь',
#  ',',
#  'снял',
#  'шинель',
#  ',',
#  'закиданную',
#  'снегом',
#  ',',
#  'взошел',
#  'свой',
#  'кабинет',
#  ',',
#  'свободно',
#  'можем',
#  'пойти',
#  'описать',
#  'наружность',
#  '—',
#  'несчастию',
#  ',',
#  'вовсе',
#  'привлекательную',
#  ';',
#  'небольшого',
#  'роста',
#  ',',
#  'широк',
#  'плечах',
#  'вообще',
#  'нескладен',
#  ';',
#  'казался',
#  'сильного',
#  'сложения',
#  ',',
#  'неспособного',
#  'чувствительности',
#  'раздражению',
#  ';',
#  'походка',
#  'несколько',
#  'осторожна',
#  'кавалериста',
#  ',',
#  'жесты',
#  'отрывисты',
#  ',',
#  'хотя',
#  'часто',
#  'выказывали',
#  'лень',
#  'беззаботное',
#  'равнодушие',
#  ',',
#  'которое',
#  'моде',
#  'духе',
#  'века',
#  ',',
#  '—',
#  'это',
#  'плеоназм',
#  '.',
#  '—',
#  'Но',
#  'сквозь',
#  'холодную',
#  'кору',
#  'прорывалась',
#  'часто',
#  'настоящая',
#  'природа',
#  'человека',
#  ';',
#  'видно',
#  ',',
#  'следовал',
#  'всеобщей',
#  'моде',
#  ',',
#  'сжимал',
#  'свои',
#  'чувства',
#  'мысли',
#  'недоверчивости',
#  'гордости',
#  '.',
#  'Звуки',
#  'голоса',
#  'густы',
#  ',',
#  'резки',
#  ',',
#  'смотря',
#  'влиянию',
#  'текущей',
#  'минуты',
#  ':',
#  'хотел',
#  'говорить',
#  'приятно',
#  ',',
#  'начинал',
#  'запинаться',
#  ',',
#  'оканчивал',
#  'едкой',
#  'шуткой',
#  ',',
#  'скрыть',
#  'собственное',
#  'смущение',
#  ',',
#  '—',
#  'свете',
#  'утверждали',
#  ',',
#  'язык',
#  'зол',
#  'опасен…',
#  'ибо',
#  'свет',
#  'терпит',
#  'кругу',
#  'своем',
#  'сильного',
#  ',',
#  'потрясающего',
#  ',',
#  ',',
#  'могло',
#  'обличить',
#  'характер',
#  'волю',
#  ':',
#  '—',
#  'свету',
#  'нужны',
#  'французские',
#  'водевили',
#  'русская',
#  'покорность',
#  'чуждому',
#  'мнению',
#  '.',
#  'Лицо',
#  'смуглое',
#  ',',
#  'неправильное',
#  ',',
#  'полное',
#  'выразительности',
#  ',',
#  'любопытно',
#  'Лафатера',
#  'последователей',
#  ':',
#  'прочли',
#  'нем',
#  'глубокие',
#  'следы',
#  'прошедшего',
#  'чудные',
#  'обещания',
#  'будущности…',
#  'толпа',
#  'говорила',
#  ',',
#  'улыбке',
#  ',',
#  'странно',
#  'блестящих',
#  'глазах',
#  'что-то…',
#  'В',
#  'заключение',
#  'портрета',
#  'скажу',
#  ',',
#  'назывался',
#  'Григорий',
#  'Александрович',
#  'Печорин',
#  ',',
#  'родными',
#  'просто',
#  'Жорж',
#  ',',
#  'французский',
#  'лад',
#  ',',
#  'притом',
#  '23',
#  'года',
#  ',',
#  '—',
#  'родителей',
#  '3',
#  'тысячи',
#  'душ',
#  'Саратовской',
#  ',',
#  'Воронежской',
#  'Калужской',
#  'губернии',
#  ',',
#  '—',
#  'последнее',
#  'прибавляю',
#  ',',
#  'немного',
#  'скрасить',
#  'наружность',
#  'мнении',
#  'строгих',
#  'читателей',
#  '!',
#  '—',
#  'виноват',
#  ',',
#  'забыл',
#  'включить',
#  ',',
#  'Жорж',
#  'единственный',
#  'сын',
#  ',',
#  'считая',
#  'сестры',
#  ',',
#  '16-летней',
#  'девочки',
#  ',',
#  'которая',
#  'очень',
#  'недурна',
#  'собою',
#  ',',
#  'словам',
#  'маменьки',
#  '(',
#  'папеньки',
#  'свете',
#  ')',
#  ',',
#  'нуждалась',
#  'приданом',
#  'могла',
#  'занять',
#  'высокую',
#  'степень',
#  'обществе',
#  ',',
#  'помощию',
#  'божией',
#  'хорошенького',
#  'личика',
#  'блестящего',
#  'воспитания',
#  '.',
#  'Григорий',
#  'Александрович',
#  ',',
#  'войдя',
#  'свой',
#  'кабинет',
#  ',',
#  'повалился',
#  'широкие',
#  'кресла',
#  ';',
#  'лакей',
#  'взошел',
#  'доложил',
#  ',',
#  ',',
#  'дескать',
#  ',',
#  'барыня',
#  'изволила',
#  'уехать',
#  'обедать',
#  'гости',
#  ',',
#  'сестра',
#  'изволила',
#  'откушать…',
#  '«',
#  'Я',
#  'обедать',
#  'буду',
#  ',',
#  '—',
#  'ответ',
#  ':',
#  'завтракал',
#  '!',
#  '..',
#  '»',
#  'Потом',
#  'взошел',
#  'мальчик',
#  'лет',
#  'тринадцати',
#  'красной',
#  'казачьей',
#  'куртке',
#  ',',
#  'быстроглазый',
#  ',',
#  'беленький',
#  ',',
#  'виду',
#  'большой',
#  'плут',
#  ',',
#  '—',
#  'подал',
#  ',',
#  'говоря',
#  'слова',
#  ',',
#  'визитную',
#  'карточку',
#  ':',
#  'Печорин',
#  'небрежно',
#  'положил',
#  'стол',
#  'спросил',
#  ',',
#  'принес',
#  '.',
#  '—',
#  'Сюда',
#  'нынче',
#  'приезжали',
#  'молодая',
#  'барыня',
#  'мужем',
#  ',',
#  '—',
#  'отвечал',
#  'Федька',
#  ',',
#  '—',
#  'велели',
#  'карточку',
#  'подать',
#  'Татьяне',
#  'Петровне',
#  '(',
#  'называлась',
#  'мать',
#  'Печорина',
#  ')',
#  '.',
#  '—',
#  'Что',
#  'принес',
#  'ко',
#  '?',
#  '—',
#  'Да',
#  'думал',
#  ',',
#  'всё',
#  'равно-c',
#  '!',
#  '..',
#  ',',
#  'угодно',
#  'прочесть',
#  '?',
#  '—',
#  'То-есть',
#  ',',
#  'тебе',
#  'хочется',
#  'узнать',
#  ',',
#  'написано',
#  '.',
#  '—',
#  'Да-с',
#  ',',
#  '—',
#  'господа',
#  '.',
#  '—',
#  'Я',
#  'слишком',
#  'избаловал',
#  ',',
#  '—',
#  'сказал',
#  'Печорин',
#  'строгим',
#  'голосом',
#  ',',
#  '—',
#  'набей',
#  'трубку',
#  '.',
#  'Но',
#  'эта',
#  'визитная',
#  'карточка',
#  ',',
#  'видно',
#  ',',
#  'имела',
#  'свойство',
#  'возбуждать',
#  'любопытство…',
#  'Долго',
#  'Жорж',
#  'решался',
#  'переменить',
#  'удобного',
#  'положения',
#  'широких',
#  'креслах',
#  'протянуть',
#  'руку',
#  'столу…',
#  'притом',
#  'комнате',
#  'свеч',
#  '—',
#  'озарялась',
#  'красноватым',
#  'пламенем',
#  'камина',
#  ',',
#  'велеть',
#  'подать',
#  'огню',
#  'расстроить',
#  'очаровательный',
#  'эффект',
#  'каминного',
#  'освещения',
#  'также',
#  'хотелось',
#  '.',
#  '—',
#  'Но',
#  'любопытство',
#  'превозмогло',
#  ',',
#  '—',
#  'встал',
#  ',',
#  'взял',
#  'карточку',
#  'каким-то',
#  'непонятным',
#  'волнением',
#  'ожидания',
#  'поднес',
#  'решетке',
#  'камина…',
#  'напечатано',
#  'готическими',
#  'буквами',
#  ':',
#  'князь',
#  'Степан',
#  'Степаныч',
#  'Лиговский',
#  ',',
#  'княгиней',
#  '.',
#  '—',
#  'Он',
#  'побледнел',
#  ',',
#  'вздрогнул',
#  ',',
#  'глаза',
#  'сверкнули',
#  ',',
#  'карточка',
#  'полетела',
#  'камин',
#  '.',
#  'Минуты',
#  'ходил',
#  'взад',
#  'вперед',
#  'комнате',
#  ',',
#  'делая',
#  'разные',
#  'странные',
#  'движения',
#  'рукою',
#  ',',
#  'разные',
#  'восклицания',
#  ',',
#  '—',
#  'улыбаясь',
#  ',',
#  'хмуря',
#  'брови',
#  ';',
#  'остановился',
#  ',',
#  'схватил',
#  'щипцы',
#  'бросился',
#  'вытаскивать',
#  'карточку',
#  'огня',
#  ':',
#  '—',
#  'увы',
#  '!',
#  ...]

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_2)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['глав',
#  'I',
#  'под',
#  '!',
#  '—',
#  'под',
#  '!',
#  'разда',
#  'крик',
#  '!',
#  'пушкин',
#  'в',
#  '1833',
#  'год',
#  ',',
#  'декабр',
#  '21-го',
#  'дня',
#  'в',
#  '4',
#  'час',
#  'пополудн',
#  'по',
#  'вознесенск',
#  'улиц',
#  ',',
#  'как',
#  'обыкновен',
#  ',',
#  'вал',
#  'толп',
#  'народ',
#  ',',
#  'и',
#  'межд',
#  'проч',
#  'шел',
#  'один',
#  'молод',
#  'чиновник',
#  ';',
#  'заметьт',
#  'ден',
#  'и',
#  'час',
#  ',',
#  'пот',
#  'что',
#  'в',
#  'этот',
#  'ден',
#  'и',
#  'в',
#  'этот',
#  'час',
#  'случ',
#  'событ',
#  ',',
#  'от',
#  'котор',
#  'тянет',
#  'цеп',
#  'различн',
#  'приключен',
#  ',',
#  'постигш',
#  'всех',
#  'мо',
#  'геро',
#  'и',
#  'героин',
#  ',',
#  'истор',
#  'котор',
#  'я',
#  'обеща',
#  'переда',
#  'потомств',
#  ',',
#  'есл',
#  'потомств',
#  'станет',
#  'чита',
#  'рома',
#  '.',
#  '—',
#  'итак',
#  ',',
#  'по',
#  'вознесенск',
#  'шел',
#  'один',
#  'молод',
#  'чиновник',
#  ',',
#  'и',
#  'шел',
#  'он',
#  'из',
#  'департамент',
#  ',',
#  'утомлен',
#  'однообразн',
#  'работ',
#  ',',
#  'и',
#  'мечт',
#  'о',
#  'наград',
#  'и',
#  'вкусн',
#  'обед',
#  '—',
#  'иб',
#  'все',
#  'чиновник',
#  'мечта',
#  '!',
#  '—',
#  'на',
#  'нем',
#  'был',
#  'картуз',
#  'неопределен',
#  'форм',
#  'и',
#  'син',
#  'ваточн',
#  'шинел',
#  'с',
#  'стар',
#  'бобров',
#  'воротник',
#  ';',
#  'черт',
#  'лиц',
#  'ег',
#  'различ',
#  'был',
#  'трудн',
#  ':',
#  'причин',
#  'том',
#  'козырек',
#  ',',
#  'воротник',
#  '—',
#  'и',
#  'сумерк',
#  ';',
#  '—',
#  'каза',
#  ',',
#  'он',
#  'не',
#  'тороп',
#  'дом',
#  ',',
#  'а',
#  'наслажда',
#  'чист',
#  'воздух',
#  'морозн',
#  'вечер',
#  ',',
#  'разлива',
#  'сквоз',
#  'зимн',
#  'мглу',
#  'розов',
#  'луч',
#  'сво',
#  'по',
#  'кровл',
#  'дом',
#  ',',
#  'соблазнительн',
#  'блистан',
#  'магазин',
#  'и',
#  'кондитерск',
#  ';',
#  'пор',
#  'подня',
#  'глаз',
#  'кверх',
#  'с',
#  'истин',
#  'поэтическ',
#  'умилен',
#  ',',
#  'сталкива',
#  'он',
#  'с',
#  'какой-нибуд',
#  'розов',
#  'шляпк',
#  'и',
#  'смут',
#  'извиня',
#  ';',
#  'коварн',
#  'розов',
#  'шляпк',
#  'серд',
#  ',',
#  '—',
#  'пот',
#  'заглядыва',
#  'ем',
#  'под',
#  'картуз',
#  'и',
#  ',',
#  'пройд',
#  'нескольк',
#  'шаг',
#  ',',
#  'оборачива',
#  ',',
#  'как',
#  'будт',
#  'ожид',
#  'вторичн',
#  'извинен',
#  ';',
#  'напрасн',
#  '!',
#  'молод',
#  'чиновник',
#  'был',
#  'совершен',
#  'недогадл',
#  '!',
#  '..',
#  'но',
#  'ещ',
#  'чащ',
#  'он',
#  'останавлива',
#  ',',
#  'чтоб',
#  'поглазет',
#  'сквоз',
#  'цельн',
#  'окн',
#  'магазин',
#  'ил',
#  'кондитерск',
#  ',',
#  'блиста',
#  'чудн',
#  'огн',
#  'и',
#  'великолепн',
#  'позолот',
#  '.',
#  'долг',
#  ',',
#  'пристальн',
#  ',',
#  'с',
#  'завист',
#  'разглядыва',
#  'различн',
#  'предмет',
#  ',',
#  '—',
#  'и',
#  ',',
#  'опомн',
#  ',',
#  'с',
#  'глубок',
#  'вздох',
#  'и',
#  'стоическ',
#  'твердост',
#  'продолжа',
#  'сво',
#  'пут',
#  ';',
#  '—',
#  'сам',
#  'же',
#  'ужасн',
#  'мучител',
#  'ег',
#  'был',
#  'извозчик',
#  ',',
#  '—',
#  'и',
#  'он',
#  'ненавидел',
#  'извозчик',
#  ';',
#  '«',
#  'барин',
#  '!',
#  'куд',
#  'извол',
#  '?',
#  '—',
#  'прикажет',
#  'подава',
#  '?',
#  '—',
#  'подавать-с',
#  '!',
#  '»',
#  'эт',
#  'был',
#  'пытк',
#  'танта',
#  ',',
#  'и',
#  'он',
#  'в',
#  'душ',
#  'глубок',
#  'ненавидел',
#  'извозчик',
#  '.',
#  'спуст',
#  'с',
#  'вознесенск',
#  'мост',
#  'и',
#  'собир',
#  'поворот',
#  'направ',
#  'по',
#  'канав',
#  ',',
#  'вдруг',
#  'слыш',
#  'он',
#  'крик',
#  ':',
#  '«',
#  'берег',
#  ',',
#  'под',
#  '!',
#  '..',
#  '»',
#  'прям',
#  'на',
#  'нег',
#  'летел',
#  'гнед',
#  'рысак',
#  ';',
#  'из-з',
#  'кучер',
#  'мелька',
#  'бел',
#  'султа',
#  ',',
#  'и',
#  'развева',
#  'воротник',
#  'сер',
#  'шинел',
#  '.',
#  '—',
#  'едв',
#  'он',
#  'успел',
#  'подня',
#  'глаз',
#  ',',
#  'уж',
#  'одн',
#  'оглобл',
#  'был',
#  'прот',
#  'ег',
#  'груд',
#  ',',
#  'и',
#  'пар',
#  ',',
#  'вылета',
#  'клуб',
#  'из',
#  'ноздр',
#  'бегун',
#  ',',
#  'обда',
#  'ем',
#  'лиц',
#  ';',
#  'машинальн',
#  'он',
#  'ухват',
#  'рук',
#  'за',
#  'оглобл',
#  'и',
#  'в',
#  'тот',
#  'же',
#  'миг',
#  'сильн',
#  'порыв',
#  'лошад',
#  'был',
#  'отброш',
#  'нескольк',
#  'шаг',
#  'в',
#  'сторон',
#  'на',
#  'тротуар…',
#  'разда',
#  'круг',
#  ':',
#  '«',
#  'задав',
#  ',',
#  'задав',
#  '»',
#  ',',
#  'извозчик',
#  'погна',
#  'за',
#  'нарушител',
#  'порядк',
#  ',',
#  '—',
#  'но',
#  'бел',
#  'султа',
#  'тольк',
#  'мелькнул',
#  'у',
#  'них',
#  'перед',
#  'глаз',
#  'и',
#  'был',
#  'так',
#  '.',
#  'когд',
#  'чиновник',
#  'очнул',
#  ',',
#  'бол',
#  'он',
#  'нигд',
#  'не',
#  'чувствова',
#  ',',
#  'но',
#  'кол',
#  'у',
#  'нег',
#  'трясл',
#  'ещ',
#  'от',
#  'страх',
#  ';',
#  'он',
#  'встал',
#  ',',
#  'облокот',
#  'на',
#  'перил',
#  'канав',
#  ',',
#  'стар',
#  'придт',
#  'в',
#  'себ',
#  ';',
#  'горьк',
#  'дум',
#  'овладел',
#  'ег',
#  'сердц',
#  ',',
#  'и',
#  'с',
#  'эт',
#  'минут',
#  'перенес',
#  'он',
#  'всю',
#  'ненавист',
#  ',',
#  'к',
#  'как',
#  'ег',
#  'душ',
#  'тольк',
#  'был',
#  'способн',
#  ',',
#  'с',
#  'извозчик',
#  'на',
#  'гнед',
#  'рысак',
#  'и',
#  'бел',
#  'султа',
#  '.',
#  'межд',
#  'тем',
#  'бел',
#  'султа',
#  'и',
#  'гнед',
#  'рысак',
#  'пронесл',
#  'вдол',
#  'до',
#  'по',
#  'канал',
#  ',',
#  'поворот',
#  'на',
#  'невск',
#  ',',
#  'с',
#  'невск',
#  'на',
#  'карава',
#  ',',
#  'оттуд',
#  'на',
#  'симионовск',
#  'мост',
#  ',',
#  'пот',
#  'направ',
#  'по',
#  'фонтанк',
#  '—',
#  'и',
#  'тут',
#  'останов',
#  'у',
#  'богат',
#  'подъезд',
#  ',',
#  'с',
#  'навес',
#  'и',
#  'стекля',
#  'дверьм',
#  ',',
#  'с',
#  'медн',
#  'блестя',
#  'обделк',
#  '.',
#  'ну',
#  ',',
#  'судар',
#  ',',
#  '—',
#  'сказа',
#  'кучер',
#  ',',
#  'широкоплеч',
#  'мужик',
#  'с',
#  'окладист',
#  'рыж',
#  'бород',
#  ',',
#  '—',
#  'васьк',
#  'нынч',
#  'показа',
#  'себ',
#  '!',
#  'надобн',
#  'замет',
#  ',',
#  'что',
#  'у',
#  'кучер',
#  'любим',
#  'их',
#  'лошад',
#  'называ',
#  'всегд',
#  'васьк',
#  ',',
#  'даж',
#  'вопрек',
#  'желан',
#  'господ',
#  ',',
#  'наделя',
#  'е',
#  'громк',
#  'имен',
#  'ахилл',
#  ',',
#  'гектора…',
#  'он',
#  'все-так',
#  'будет',
#  'для',
#  'кучер',
#  'не',
#  'ахел',
#  'и',
#  'не',
#  'нектор',
#  ',',
#  'а',
#  'васьк',
#  '.',
#  'офицер',
#  'слез',
#  ',',
#  'потрепа',
#  'дымя',
#  'рысак',
#  'по',
#  'крут',
#  'ше',
#  ',',
#  'улыбнул',
#  'ем',
#  'признательн',
#  'и',
#  'взошел',
#  'на',
#  'блестя',
#  'лестниц',
#  ';',
#  '—',
#  'об',
#  'раздавлен',
#  'чиновник',
#  'не',
#  'был',
#  'и',
#  'помину…',
#  'тепер',
#  ',',
#  'когд',
#  'он',
#  'снял',
#  'шинел',
#  ',',
#  'закида',
#  'снег',
#  ',',
#  'и',
#  'взошел',
#  'в',
#  'сво',
#  'кабинет',
#  ',',
#  'мы',
#  'свободн',
#  'мож',
#  'пойт',
#  'за',
#  'ним',
#  'и',
#  'описа',
#  'ег',
#  'наружн',
#  '—',
#  'к',
#  'несчаст',
#  ',',
#  'вовс',
#  'не',
#  'привлекательн',
#  ';',
#  'он',
#  'был',
#  'небольш',
#  'рост',
#  ',',
#  'широк',
#  'в',
#  'плеч',
#  'и',
#  'вообщ',
#  'несклад',
#  ';',
#  'каза',
#  'сильн',
#  'сложен',
#  ',',
#  'неспособн',
#  'к',
#  'чувствительн',
#  'и',
#  'раздражен',
#  ';',
#  'походк',
#  'ег',
#  'был',
#  'нескольк',
#  'осторожн',
#  'для',
#  'кавалерист',
#  ',',
#  'жест',
#  'ег',
#  'был',
#  'отрывист',
#  ',',
#  'хот',
#  'част',
#  'он',
#  'выказыва',
#  'лен',
#  'и',
#  'беззаботн',
#  'равнодуш',
#  ',',
#  'котор',
#  'тепер',
#  'в',
#  'мод',
#  'и',
#  'в',
#  'дух',
#  'век',
#  ',',
#  '—',
#  'есл',
#  'эт',
#  'не',
#  'плеоназм',
#  '.',
#  '—',
#  'но',
#  'сквоз',
#  'эт',
#  'холодн',
#  'кор',
#  'прорыва',
#  'част',
#  'настоя',
#  'природ',
#  'человек',
#  ';',
#  'видн',
#  'был',
#  ',',
#  'что',
#  'он',
#  'следова',
#  'не',
#  'всеобщ',
#  'мод',
#  ',',
#  'а',
#  'сжима',
#  'сво',
#  'чувств',
#  'и',
#  'мысл',
#  'из',
#  'недоверчив',
#  'ил',
#  'из',
#  'гордост',
#  '.',
#  'звук',
#  'ег',
#  'голос',
#  'был',
#  'то',
#  'густ',
#  ',',
#  'то',
#  'резк',
#  ',',
#  'смотр',
#  'по',
#  'влиян',
#  'текущ',
#  'минут',
#  ':',
#  'когд',
#  'он',
#  'хотел',
#  'говор',
#  'приятн',
#  ',',
#  'то',
#  'начина',
#  'запина',
#  ',',
#  'и',
#  'вдруг',
#  'оканчива',
#  'едк',
#  'шутк',
#  ',',
#  'чтоб',
#  'скрыт',
#  'собствен',
#  'смущен',
#  ',',
#  '—',
#  'и',
#  'в',
#  'свет',
#  'утвержда',
#  ',',
#  'что',
#  'язык',
#  'ег',
#  'зол',
#  'и',
#  'опасен…',
#  'иб',
#  'свет',
#  'не',
#  'терп',
#  'в',
#  'круг',
#  'сво',
#  'нич',
#  'сильн',
#  ',',
#  'потряса',
#  ',',
#  'нич',
#  ',',
#  'что',
#  'бы',
#  'могл',
#  'облич',
#  'характер',
#  'и',
#  'вол',
#  ':',
#  '—',
#  'свет',
#  'нужн',
#  'французск',
#  'водев',
#  'и',
#  'русск',
#  'покорн',
#  'чужд',
#  'мнен',
#  '.',
#  'лиц',
#  'ег',
#  'смугл',
#  ',',
#  'неправильн',
#  ',',
#  'но',
#  'полн',
#  'выразительн',
#  ',',
#  'был',
#  'бы',
#  'любопытн',
#  'для',
#  'лафатер',
#  'и',
#  'ег',
#  'последовател',
#  ':',
#  'он',
#  'прочл',
#  'бы',
#  'на',
#  'нем',
#  'глубок',
#  'след',
#  'прошедш',
#  'и',
#  'чудн',
#  'обещан',
#  'будущности…',
#  'толп',
#  'же',
#  'говор',
#  ',',
#  'что',
#  'в',
#  'ег',
#  'улыбк',
#  ',',
#  'в',
#  'ег',
#  'стран',
#  'блестя',
#  'глаз',
#  'ест',
#  'что-то…',
#  'в',
#  'заключен',
#  'портрет',
#  'скаж',
#  ',',
#  'что',
#  'он',
#  'называ',
#  'григор',
#  'александрович',
#  'печорин',
#  ',',
#  'а',
#  'межд',
#  'родн',
#  'прост',
#  'жорж',
#  ',',
#  'на',
#  'французск',
#  'лад',
#  ',',
#  'и',
#  'что',
#  'прит',
#  'ем',
#  'был',
#  '23',
#  'год',
#  ',',
#  '—',
#  'и',
#  'что',
#  'у',
#  'родител',
#  'ег',
#  'был',
#  '3',
#  'тысяч',
#  'душ',
#  'в',
#  'саратовск',
#  ',',
#  'воронежск',
#  'и',
#  'калужск',
#  'губерн',
#  ',',
#  '—',
#  'последн',
#  'я',
#  'прибавля',
#  ',',
#  'чтоб',
#  'немн',
#  'скрас',
#  'ег',
#  'наружн',
#  'во',
#  'мнен',
#  'строг',
#  'читател',
#  '!',
#  '—',
#  'виноват',
#  ',',
#  'заб',
#  'включ',
#  ',',
#  'что',
#  'жорж',
#  'был',
#  'единствен',
#  'сын',
#  ',',
#  'не',
#  'счит',
#  'сестр',
#  ',',
#  '16-летн',
#  'девочк',
#  ',',
#  'котор',
#  'был',
#  'очен',
#  'недурн',
#  'соб',
#  'и',
#  ',',
#  'по',
#  'слов',
#  'маменьк',
#  '(',
#  'папеньк',
#  'уж',
#  'не',
#  'был',
#  'на',
#  ...]

# %%
len(words)
# Out:
# 23223

# %%
len(tokenized_filtered)
# Out:
# 16931

# %% [markdown]
# Relatives

# %%
with open("4. Герой нашего времени.txt") as file:
    text_3 = file.read()

# %%
words=word_tokenize(text_3)
words
# Out:
# ['Во',
#  'всякой',
#  'книге',
#  'предисловие',
#  'есть',
#  'первая',
#  'и',
#  'вместе',
#  'с',
#  'тем',
#  'последняя',
#  'вещь',
#  ';',
#  'оно',
#  'или',
#  'служит',
#  'объяснением',
#  'цели',
#  'сочинения',
#  ',',
#  'или',
#  'оправданием',
#  'и',
#  'ответом',
#  'на',
#  'критики',
#  '.',
#  'Но',
#  'обыкновенно',
#  'читателям',
#  'дела',
#  'нет',
#  'до',
#  'нравственной',
#  'цели',
#  'и',
#  'до',
#  'журнальных',
#  'нападок',
#  ',',
#  'и',
#  'потому',
#  'они',
#  'не',
#  'читают',
#  'предисловий',
#  '.',
#  'А',
#  'жаль',
#  ',',
#  'что',
#  'это',
#  'так',
#  ',',
#  'особенно',
#  'у',
#  'нас',
#  '.',
#  'Наша',
#  'публика',
#  'так',
#  'еще',
#  'молода',
#  'и',
#  'простодушна',
#  ',',
#  'что',
#  'не',
#  'понимает',
#  'басни',
#  ',',
#  'если',
#  'в',
#  'конце',
#  'ее',
#  'не',
#  'находит',
#  'нравоучения',
#  '.',
#  'Она',
#  'не',
#  'угадывает',
#  'шутки',
#  ',',
#  'не',
#  'чувствует',
#  'иронии',
#  ';',
#  'она',
#  'просто',
#  'дурно',
#  'воспитана',
#  '.',
#  'Она',
#  'еще',
#  'не',
#  'знает',
#  ',',
#  'что',
#  'в',
#  'порядочном',
#  'обществе',
#  'и',
#  'в',
#  'порядочной',
#  'книге',
#  'явная',
#  'брань',
#  'не',
#  'может',
#  'иметь',
#  'места',
#  ';',
#  'что',
#  'современная',
#  'образованность',
#  'изобрела',
#  'орудие',
#  'более',
#  'острое',
#  ',',
#  'почти',
#  'невидимое',
#  'и',
#  'тем',
#  'не',
#  'менее',
#  'смертельное',
#  ',',
#  'которое',
#  ',',
#  'под',
#  'одеждою',
#  'лести',
#  ',',
#  'наносит',
#  'неотразимый',
#  'и',
#  'верный',
#  'удар',
#  '.',
#  'Наша',
#  'публика',
#  'похожа',
#  'на',
#  'провинциала',
#  ',',
#  'который',
#  ',',
#  'подслушав',
#  'разговор',
#  'двух',
#  'дипломатов',
#  ',',
#  'принадлежащих',
#  'к',
#  'враждебным',
#  'дворам',
#  ',',
#  'остался',
#  'бы',
#  'уверен',
#  ',',
#  'что',
#  'каждый',
#  'из',
#  'них',
#  'обманывает',
#  'свое',
#  'правительство',
#  'в',
#  'пользу',
#  'взаимной',
#  'нежнейшей',
#  'дружбы',
#  '.',
#  'Эта',
#  'книга',
#  'испытала',
#  'на',
#  'себе',
#  'еще',
#  'недавно',
#  'несчастную',
#  'доверчивость',
#  'некоторых',
#  'читателей',
#  'и',
#  'даже',
#  'журналов',
#  'к',
#  'буквальному',
#  'значению',
#  'слов',
#  '.',
#  'Иные',
#  'ужасно',
#  'обиделись',
#  ',',
#  'и',
#  'не',
#  'шутя',
#  ',',
#  'что',
#  'им',
#  'ставят',
#  'в',
#  'пример',
#  'такого',
#  'безнравственного',
#  'человека',
#  ',',
#  'как',
#  'Герой',
#  'Нашего',
#  'Времени',
#  ';',
#  'другие',
#  'же',
#  'очень',
#  'тонко',
#  'замечали',
#  ',',
#  'что',
#  'сочинитель',
#  'нарисовал',
#  'свой',
#  'портрет',
#  'и',
#  'портреты',
#  'своих',
#  'знакомых…',
#  'Старая',
#  'и',
#  'жалкая',
#  'шутка',
#  '!',
#  'Но',
#  ',',
#  'видно',
#  ',',
#  'Русь',
#  'так',
#  'уж',
#  'сотворена',
#  ',',
#  'что',
#  'все',
#  'в',
#  'ней',
#  'обновляется',
#  ',',
#  'кроме',
#  'подобных',
#  'нелепостей',
#  '.',
#  'Самая',
#  'волшебная',
#  'из',
#  'волшебных',
#  'сказок',
#  'у',
#  'нас',
#  'едва',
#  'ли',
#  'избегнет',
#  'упрека',
#  'в',
#  'покушении',
#  'на',
#  'оскорбление',
#  'личности',
#  '!',
#  'Герой',
#  'Нашего',
#  'Времени',
#  ',',
#  'милостивые',
#  'государи',
#  'мои',
#  ',',
#  'точно',
#  ',',
#  'портрет',
#  ',',
#  'но',
#  'не',
#  'одного',
#  'человека',
#  ':',
#  'это',
#  'портрет',
#  ',',
#  'составленный',
#  'из',
#  'пороков',
#  'всего',
#  'нашего',
#  'поколения',
#  ',',
#  'в',
#  'полном',
#  'их',
#  'развитии',
#  '.',
#  'Вы',
#  'мне',
#  'опять',
#  'скажете',
#  ',',
#  'что',
#  'человек',
#  'не',
#  'может',
#  'быть',
#  'так',
#  'дурен',
#  ',',
#  'а',
#  'я',
#  'вам',
#  'скажу',
#  ',',
#  'что',
#  'ежели',
#  'вы',
#  'верили',
#  'возможности',
#  'существования',
#  'всех',
#  'трагических',
#  'и',
#  'романтических',
#  'злодеев',
#  ',',
#  'отчего',
#  'же',
#  'вы',
#  'не',
#  'веруете',
#  'в',
#  'действительность',
#  'Печорина',
#  '?',
#  'Если',
#  'вы',
#  'любовались',
#  'вымыслами',
#  'гораздо',
#  'более',
#  'ужасными',
#  'и',
#  'уродливыми',
#  ',',
#  'отчего',
#  'же',
#  'этот',
#  'характер',
#  ',',
#  'даже',
#  'как',
#  'вымысел',
#  ',',
#  'не',
#  'находит',
#  'у',
#  'вас',
#  'пощады',
#  '?',
#  'Уж',
#  'не',
#  'оттого',
#  'ли',
#  ',',
#  'что',
#  'в',
#  'нем',
#  'больше',
#  'правды',
#  ',',
#  'нежели',
#  'бы',
#  'вы',
#  'того',
#  'желали',
#  '?',
#  '..',
#  'Вы',
#  'скажете',
#  ',',
#  'что',
#  'нравственность',
#  'от',
#  'этого',
#  'не',
#  'выигрывает',
#  '?',
#  'Извините',
#  '.',
#  'Довольно',
#  'людей',
#  'кормили',
#  'сластями',
#  ';',
#  'у',
#  'них',
#  'от',
#  'этого',
#  'испортился',
#  'желудок',
#  ':',
#  'нужны',
#  'горькие',
#  'лекарства',
#  ',',
#  'едкие',
#  'истины',
#  '.',
#  'Но',
#  'не',
#  'думайте',
#  ',',
#  'однако',
#  ',',
#  'после',
#  'этого',
#  ',',
#  'чтоб',
#  'автор',
#  'этой',
#  'книги',
#  'имел',
#  'когда-нибудь',
#  'гордую',
#  'мечту',
#  'сделаться',
#  'исправителем',
#  'людских',
#  'пороков',
#  '.',
#  'Боже',
#  'его',
#  'избави',
#  'от',
#  'такого',
#  'невежества',
#  '!',
#  'Ему',
#  'просто',
#  'было',
#  'весело',
#  'рисовать',
#  'современного',
#  'человека',
#  ',',
#  'каким',
#  'он',
#  'его',
#  'понимает',
#  ',',
#  'и',
#  'к',
#  'его',
#  'и',
#  'вашему',
#  'несчастью',
#  ',',
#  'слишком',
#  'часто',
#  'встречал',
#  '.',
#  'Будет',
#  'и',
#  'того',
#  ',',
#  'что',
#  'болезнь',
#  'указана',
#  ',',
#  'а',
#  'как',
#  'ее',
#  'излечить',
#  '–',
#  'это',
#  'уж',
#  'бог',
#  'знает',
#  '!',
#  'Часть',
#  'первая',
#  'I.',
#  'Бэла',
#  'Я',
#  'ехал',
#  'на',
#  'перекладных',
#  'из',
#  'Тифлиса',
#  '.',
#  'Вся',
#  'поклажа',
#  'моей',
#  'тележки',
#  'состояла',
#  'из',
#  'одного',
#  'небольшого',
#  'чемодана',
#  ',',
#  'который',
#  'до',
#  'половины',
#  'был',
#  'набит',
#  'путевыми',
#  'записками',
#  'о',
#  'Грузии',
#  '.',
#  'Большая',
#  'часть',
#  'из',
#  'них',
#  ',',
#  'к',
#  'счастию',
#  'для',
#  'вас',
#  ',',
#  'потеряна',
#  ',',
#  'а',
#  'чемодан',
#  'с',
#  'остальными',
#  'вещами',
#  ',',
#  'к',
#  'счастью',
#  'для',
#  'меня',
#  ',',
#  'остался',
#  'цел',
#  '.',
#  'Уж',
#  'солнце',
#  'начинало',
#  'прятаться',
#  'за',
#  'снеговой',
#  'хребет',
#  ',',
#  'когда',
#  'я',
#  'въехал',
#  'в',
#  'Койшаурскую',
#  'долину',
#  '.',
#  'Осетин-извозчик',
#  'неутомимо',
#  'погонял',
#  'лошадей',
#  ',',
#  'чтоб',
#  'успеть',
#  'до',
#  'ночи',
#  'взобраться',
#  'на',
#  'Койшаурскую',
#  'гору',
#  ',',
#  'и',
#  'во',
#  'все',
#  'горло',
#  'распевал',
#  'песни',
#  '.',
#  'Славное',
#  'место',
#  'эта',
#  'долина',
#  '!',
#  'Со',
#  'всех',
#  'сторон',
#  'горы',
#  'неприступные',
#  ',',
#  'красноватые',
#  'скалы',
#  ',',
#  'обвешанные',
#  'зеленым',
#  'плющом',
#  'и',
#  'увенчанные',
#  'купами',
#  'чинар',
#  ',',
#  'желтые',
#  'обрывы',
#  ',',
#  'исчерченные',
#  'промоинами',
#  ',',
#  'а',
#  'там',
#  'высоко-высоко',
#  'золотая',
#  'бахрома',
#  'снегов',
#  ',',
#  'а',
#  'внизу',
#  'Арагва',
#  ',',
#  'обнявшись',
#  'с',
#  'другой',
#  'безыменной',
#  'речкой',
#  ',',
#  'шумно',
#  'вырывающейся',
#  'из',
#  'черного',
#  ',',
#  'полного',
#  'мглою',
#  'ущелья',
#  ',',
#  'тянется',
#  'серебряною',
#  'нитью',
#  'и',
#  'сверкает',
#  ',',
#  'как',
#  'змея',
#  'своею',
#  'чешуею',
#  '.',
#  'Подъехав',
#  'к',
#  'подошве',
#  'Койшаурской',
#  'горы',
#  ',',
#  'мы',
#  'остановились',
#  'возле',
#  'духана',
#  '.',
#  'Тут',
#  'толпилось',
#  'шумно',
#  'десятка',
#  'два',
#  'грузин',
#  'и',
#  'горцев',
#  ';',
#  'поблизости',
#  'караван',
#  'верблюдов',
#  'остановился',
#  'для',
#  'ночлега',
#  '.',
#  'Я',
#  'должен',
#  'был',
#  'нанять',
#  'быков',
#  ',',
#  'чтоб',
#  'втащить',
#  'мою',
#  'тележку',
#  'на',
#  'эту',
#  'проклятую',
#  'гору',
#  ',',
#  'потому',
#  'что',
#  'была',
#  'уже',
#  'осень',
#  'и',
#  'гололедица',
#  ',',
#  '–',
#  'а',
#  'эта',
#  'гора',
#  'имеет',
#  'около',
#  'двух',
#  'верст',
#  'длины',
#  '.',
#  'Нечего',
#  'делать',
#  ',',
#  'я',
#  'нанял',
#  'шесть',
#  'быков',
#  'и',
#  'нескольких',
#  'осетин',
#  '.',
#  'Один',
#  'из',
#  'них',
#  'взвалил',
#  'себе',
#  'на',
#  'плечи',
#  'мой',
#  'чемодан',
#  ',',
#  'другие',
#  'стали',
#  'помогать',
#  'быкам',
#  'почти',
#  'одним',
#  'криком',
#  '.',
#  'За',
#  'моею',
#  'тележкою',
#  'четверка',
#  'быков',
#  'тащила',
#  'другую',
#  'как',
#  'ни',
#  'в',
#  'чем',
#  'не',
#  'бывало',
#  ',',
#  'несмотря',
#  'на',
#  'то',
#  ',',
#  'что',
#  'она',
#  'была',
#  'доверху',
#  'накладена',
#  '.',
#  'Это',
#  'обстоятельство',
#  'меня',
#  'удивило',
#  '.',
#  'За',
#  'нею',
#  'шел',
#  'ее',
#  'хозяин',
#  ',',
#  'покуривая',
#  'из',
#  'маленькой',
#  'кабардинской',
#  'трубочки',
#  ',',
#  'обделанной',
#  'в',
#  'серебро',
#  '.',
#  'На',
#  'нем',
#  'был',
#  'офицерский',
#  'сюртук',
#  'без',
#  'эполет',
#  'и',
#  'черкесская',
#  'мохнатая',
#  'шапка',
#  '.',
#  'Он',
#  'казался',
#  'лет',
#  'пятидесяти',
#  ';',
#  'смуглый',
#  'цвет',
#  'лица',
#  'его',
#  'показывал',
#  ',',
#  'что',
#  'оно',
#  'давно',
#  'знакомо',
#  'с',
#  'закавказским',
#  'солнцем',
#  ',',
#  'и',
#  'преждевременно',
#  'поседевшие',
#  'усы',
#  'не',
#  'соответствовали',
#  'его',
#  'твердой',
#  'походке',
#  'и',
#  'бодрому',
#  'виду',
#  '.',
#  'Я',
#  'подошел',
#  'к',
#  'нему',
#  'и',
#  'поклонился',
#  ':',
#  'он',
#  'молча',
#  'отвечал',
#  'мне',
#  'на',
#  'поклон',
#  'и',
#  'пустил',
#  'огромный',
#  'клуб',
#  'дыма',
#  '.',
#  '–',
#  'Мы',
#  'с',
#  'вами',
#  'попутчики',
#  ',',
#  'кажется',
#  '?',
#  'Он',
#  'молча',
#  'опять',
#  'поклонился',
#  '.',
#  '–',
#  'Вы',
#  ',',
#  'верно',
#  ',',
#  'едете',
#  'в',
#  'Ставрополь',
#  '?',
#  '–',
#  'Так-с',
#  'точно…',
#  'с',
#  'казенными',
#  'вещами',
#  '.',
#  '–',
#  'Скажите',
#  ',',
#  'пожалуйста',
#  ',',
#  'отчего',
#  'это',
#  'вашу',
#  'тяжелую',
#  'тележку',
#  'четыре',
#  'быка',
#  'тащат',
#  'шутя',
#  ',',
#  'а',
#  'мою',
#  ',',
#  'пустую',
#  ',',
#  'шесть',
#  'скотов',
#  'едва',
#  'подвигают',
#  'с',
#  'помощью',
#  'этих',
#  'осетин',
#  '?',
#  'Он',
#  'лукаво',
#  'улыбнулся',
#  'и',
#  'значительно',
#  'взглянул',
#  'на',
#  'меня',
#  '.',
#  '–',
#  'Вы',
#  ',',
#  'верно',
#  ',',
#  'недавно',
#  'на',
#  'Кавказе',
#  '?',
#  '–',
#  'С',
#  'год',
#  ',',
#  '–',
#  'отвечал',
#  'я.',
#  'Он',
#  'улыбнулся',
#  'вторично',
#  '.',
#  '–',
#  'А',
#  'что',
#  'ж',
#  '?',
#  '–',
#  'Да',
#  'так-с',
#  '!',
#  'Ужасные',
#  'бестии',
#  'эти',
#  'азиаты',
#  '!',
#  'Вы',
#  'думаете',
#  ',',
#  'они',
#  'помогают',
#  ',',
#  'что',
#  'кричат',
#  '?',
#  'А',
#  'черт',
#  'их',
#  'разберет',
#  ',',
#  'что',
#  'они',
#  'кричат',
#  '?',
#  'Быки-то',
#  'их',
#  'понимают',
#  ';',
#  'запрягите',
#  'хоть',
#  'двадцать',
#  ',',
#  'так',
#  'коли',
#  'они',
#  'крикнут',
#  'по-своему',
#  ',',
#  'быки',
#  'все',
#  'ни',
#  'с',
#  'места…',
#  'Ужасные',
#  'плуты',
#  '!',
#  'А',
#  'что',
#  'с',
#  'них',
#  'возьмешь',
#  '?',
#  '..',
#  'Любят',
#  'деньги',
#  'драть',
#  'с',
#  'проезжающих…',
#  'Избаловали',
#  'мошенников',
#  '!',
#  ...]

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['Во',
#  'всякой',
#  'книге',
#  'предисловие',
#  'первая',
#  'вместе',
#  'последняя',
#  'вещь',
#  ';',
#  'оно',
#  'служит',
#  'объяснением',
#  'цели',
#  'сочинения',
#  ',',
#  'оправданием',
#  'ответом',
#  'критики',
#  '.',
#  'Но',
#  'обыкновенно',
#  'читателям',
#  'дела',
#  'нравственной',
#  'цели',
#  'журнальных',
#  'нападок',
#  ',',
#  'читают',
#  'предисловий',
#  '.',
#  'А',
#  'жаль',
#  ',',
#  'это',
#  ',',
#  'особенно',
#  '.',
#  'Наша',
#  'публика',
#  'молода',
#  'простодушна',
#  ',',
#  'понимает',
#  'басни',
#  ',',
#  'конце',
#  'находит',
#  'нравоучения',
#  '.',
#  'Она',
#  'угадывает',
#  'шутки',
#  ',',
#  'чувствует',
#  'иронии',
#  ';',
#  'просто',
#  'дурно',
#  'воспитана',
#  '.',
#  'Она',
#  'знает',
#  ',',
#  'порядочном',
#  'обществе',
#  'порядочной',
#  'книге',
#  'явная',
#  'брань',
#  'иметь',
#  'места',
#  ';',
#  'современная',
#  'образованность',
#  'изобрела',
#  'орудие',
#  'острое',
#  ',',
#  'невидимое',
#  'менее',
#  'смертельное',
#  ',',
#  'которое',
#  ',',
#  'одеждою',
#  'лести',
#  ',',
#  'наносит',
#  'неотразимый',
#  'верный',
#  'удар',
#  '.',
#  'Наша',
#  'публика',
#  'похожа',
#  'провинциала',
#  ',',
#  'который',
#  ',',
#  'подслушав',
#  'разговор',
#  'двух',
#  'дипломатов',
#  ',',
#  'принадлежащих',
#  'враждебным',
#  'дворам',
#  ',',
#  'остался',
#  'уверен',
#  ',',
#  'каждый',
#  'обманывает',
#  'свое',
#  'правительство',
#  'пользу',
#  'взаимной',
#  'нежнейшей',
#  'дружбы',
#  '.',
#  'Эта',
#  'книга',
#  'испытала',
#  'недавно',
#  'несчастную',
#  'доверчивость',
#  'некоторых',
#  'читателей',
#  'журналов',
#  'буквальному',
#  'значению',
#  'слов',
#  '.',
#  'Иные',
#  'ужасно',
#  'обиделись',
#  ',',
#  'шутя',
#  ',',
#  'ставят',
#  'пример',
#  'такого',
#  'безнравственного',
#  'человека',
#  ',',
#  'Герой',
#  'Нашего',
#  'Времени',
#  ';',
#  'другие',
#  'очень',
#  'тонко',
#  'замечали',
#  ',',
#  'сочинитель',
#  'нарисовал',
#  'свой',
#  'портрет',
#  'портреты',
#  'своих',
#  'знакомых…',
#  'Старая',
#  'жалкая',
#  'шутка',
#  '!',
#  'Но',
#  ',',
#  'видно',
#  ',',
#  'Русь',
#  'сотворена',
#  ',',
#  'обновляется',
#  ',',
#  'кроме',
#  'подобных',
#  'нелепостей',
#  '.',
#  'Самая',
#  'волшебная',
#  'волшебных',
#  'сказок',
#  'едва',
#  'избегнет',
#  'упрека',
#  'покушении',
#  'оскорбление',
#  'личности',
#  '!',
#  'Герой',
#  'Нашего',
#  'Времени',
#  ',',
#  'милостивые',
#  'государи',
#  'мои',
#  ',',
#  'точно',
#  ',',
#  'портрет',
#  ',',
#  'одного',
#  'человека',
#  ':',
#  'это',
#  'портрет',
#  ',',
#  'составленный',
#  'пороков',
#  'нашего',
#  'поколения',
#  ',',
#  'полном',
#  'развитии',
#  '.',
#  'Вы',
#  'скажете',
#  ',',
#  'человек',
#  'дурен',
#  ',',
#  'скажу',
#  ',',
#  'ежели',
#  'верили',
#  'возможности',
#  'существования',
#  'трагических',
#  'романтических',
#  'злодеев',
#  ',',
#  'отчего',
#  'веруете',
#  'действительность',
#  'Печорина',
#  '?',
#  'Если',
#  'любовались',
#  'вымыслами',
#  'гораздо',
#  'ужасными',
#  'уродливыми',
#  ',',
#  'отчего',
#  'характер',
#  ',',
#  'вымысел',
#  ',',
#  'находит',
#  'пощады',
#  '?',
#  'Уж',
#  'оттого',
#  ',',
#  'нем',
#  'правды',
#  ',',
#  'нежели',
#  'желали',
#  '?',
#  '..',
#  'Вы',
#  'скажете',
#  ',',
#  'нравственность',
#  'выигрывает',
#  '?',
#  'Извините',
#  '.',
#  'Довольно',
#  'людей',
#  'кормили',
#  'сластями',
#  ';',
#  'испортился',
#  'желудок',
#  ':',
#  'нужны',
#  'горькие',
#  'лекарства',
#  ',',
#  'едкие',
#  'истины',
#  '.',
#  'Но',
#  'думайте',
#  ',',
#  'однако',
#  ',',
#  ',',
#  'автор',
#  'книги',
#  'имел',
#  'когда-нибудь',
#  'гордую',
#  'мечту',
#  'сделаться',
#  'исправителем',
#  'людских',
#  'пороков',
#  '.',
#  'Боже',
#  'избави',
#  'такого',
#  'невежества',
#  '!',
#  'Ему',
#  'просто',
#  'весело',
#  'рисовать',
#  'современного',
#  'человека',
#  ',',
#  'каким',
#  'понимает',
#  ',',
#  'вашему',
#  'несчастью',
#  ',',
#  'слишком',
#  'часто',
#  'встречал',
#  '.',
#  'Будет',
#  ',',
#  'болезнь',
#  'указана',
#  ',',
#  'излечить',
#  '–',
#  'это',
#  'бог',
#  'знает',
#  '!',
#  'Часть',
#  'первая',
#  'I.',
#  'Бэла',
#  'Я',
#  'ехал',
#  'перекладных',
#  'Тифлиса',
#  '.',
#  'Вся',
#  'поклажа',
#  'моей',
#  'тележки',
#  'состояла',
#  'одного',
#  'небольшого',
#  'чемодана',
#  ',',
#  'который',
#  'половины',
#  'набит',
#  'путевыми',
#  'записками',
#  'Грузии',
#  '.',
#  'Большая',
#  'часть',
#  ',',
#  'счастию',
#  ',',
#  'потеряна',
#  ',',
#  'чемодан',
#  'остальными',
#  'вещами',
#  ',',
#  'счастью',
#  ',',
#  'остался',
#  'цел',
#  '.',
#  'Уж',
#  'солнце',
#  'начинало',
#  'прятаться',
#  'снеговой',
#  'хребет',
#  ',',
#  'въехал',
#  'Койшаурскую',
#  'долину',
#  '.',
#  'Осетин-извозчик',
#  'неутомимо',
#  'погонял',
#  'лошадей',
#  ',',
#  'успеть',
#  'ночи',
#  'взобраться',
#  'Койшаурскую',
#  'гору',
#  ',',
#  'горло',
#  'распевал',
#  'песни',
#  '.',
#  'Славное',
#  'место',
#  'эта',
#  'долина',
#  '!',
#  'Со',
#  'сторон',
#  'горы',
#  'неприступные',
#  ',',
#  'красноватые',
#  'скалы',
#  ',',
#  'обвешанные',
#  'зеленым',
#  'плющом',
#  'увенчанные',
#  'купами',
#  'чинар',
#  ',',
#  'желтые',
#  'обрывы',
#  ',',
#  'исчерченные',
#  'промоинами',
#  ',',
#  'высоко-высоко',
#  'золотая',
#  'бахрома',
#  'снегов',
#  ',',
#  'внизу',
#  'Арагва',
#  ',',
#  'обнявшись',
#  'безыменной',
#  'речкой',
#  ',',
#  'шумно',
#  'вырывающейся',
#  'черного',
#  ',',
#  'полного',
#  'мглою',
#  'ущелья',
#  ',',
#  'тянется',
#  'серебряною',
#  'нитью',
#  'сверкает',
#  ',',
#  'змея',
#  'своею',
#  'чешуею',
#  '.',
#  'Подъехав',
#  'подошве',
#  'Койшаурской',
#  'горы',
#  ',',
#  'остановились',
#  'возле',
#  'духана',
#  '.',
#  'Тут',
#  'толпилось',
#  'шумно',
#  'десятка',
#  'грузин',
#  'горцев',
#  ';',
#  'поблизости',
#  'караван',
#  'верблюдов',
#  'остановился',
#  'ночлега',
#  '.',
#  'Я',
#  'должен',
#  'нанять',
#  'быков',
#  ',',
#  'втащить',
#  'мою',
#  'тележку',
#  'проклятую',
#  'гору',
#  ',',
#  'осень',
#  'гололедица',
#  ',',
#  '–',
#  'эта',
#  'гора',
#  'имеет',
#  'около',
#  'двух',
#  'верст',
#  'длины',
#  '.',
#  'Нечего',
#  'делать',
#  ',',
#  'нанял',
#  'шесть',
#  'быков',
#  'нескольких',
#  'осетин',
#  '.',
#  'Один',
#  'взвалил',
#  'плечи',
#  'чемодан',
#  ',',
#  'другие',
#  'стали',
#  'помогать',
#  'быкам',
#  'одним',
#  'криком',
#  '.',
#  'За',
#  'моею',
#  'тележкою',
#  'четверка',
#  'быков',
#  'тащила',
#  'другую',
#  'бывало',
#  ',',
#  'несмотря',
#  ',',
#  'доверху',
#  'накладена',
#  '.',
#  'Это',
#  'обстоятельство',
#  'удивило',
#  '.',
#  'За',
#  'нею',
#  'шел',
#  'хозяин',
#  ',',
#  'покуривая',
#  'маленькой',
#  'кабардинской',
#  'трубочки',
#  ',',
#  'обделанной',
#  'серебро',
#  '.',
#  'На',
#  'нем',
#  'офицерский',
#  'сюртук',
#  'эполет',
#  'черкесская',
#  'мохнатая',
#  'шапка',
#  '.',
#  'Он',
#  'казался',
#  'лет',
#  'пятидесяти',
#  ';',
#  'смуглый',
#  'цвет',
#  'лица',
#  'показывал',
#  ',',
#  'оно',
#  'давно',
#  'знакомо',
#  'закавказским',
#  'солнцем',
#  ',',
#  'преждевременно',
#  'поседевшие',
#  'усы',
#  'соответствовали',
#  'твердой',
#  'походке',
#  'бодрому',
#  'виду',
#  '.',
#  'Я',
#  'подошел',
#  'нему',
#  'поклонился',
#  ':',
#  'молча',
#  'отвечал',
#  'поклон',
#  'пустил',
#  'огромный',
#  'клуб',
#  'дыма',
#  '.',
#  '–',
#  'Мы',
#  'вами',
#  'попутчики',
#  ',',
#  'кажется',
#  '?',
#  'Он',
#  'молча',
#  'поклонился',
#  '.',
#  '–',
#  'Вы',
#  ',',
#  'верно',
#  ',',
#  'едете',
#  'Ставрополь',
#  '?',
#  '–',
#  'Так-с',
#  'точно…',
#  'казенными',
#  'вещами',
#  '.',
#  '–',
#  'Скажите',
#  ',',
#  'пожалуйста',
#  ',',
#  'отчего',
#  'это',
#  'вашу',
#  'тяжелую',
#  'тележку',
#  'четыре',
#  'быка',
#  'тащат',
#  'шутя',
#  ',',
#  'мою',
#  ',',
#  'пустую',
#  ',',
#  'шесть',
#  'скотов',
#  'едва',
#  'подвигают',
#  'помощью',
#  'этих',
#  'осетин',
#  '?',
#  'Он',
#  'лукаво',
#  'улыбнулся',
#  'значительно',
#  'взглянул',
#  '.',
#  '–',
#  'Вы',
#  ',',
#  'верно',
#  ',',
#  'недавно',
#  'Кавказе',
#  '?',
#  '–',
#  'С',
#  'год',
#  ',',
#  '–',
#  'отвечал',
#  'я.',
#  'Он',
#  'улыбнулся',
#  'вторично',
#  '.',
#  '–',
#  'А',
#  '?',
#  '–',
#  'Да',
#  'так-с',
#  '!',
#  'Ужасные',
#  'бестии',
#  'азиаты',
#  '!',
#  'Вы',
#  'думаете',
#  ',',
#  'помогают',
#  ',',
#  'кричат',
#  '?',
#  'А',
#  'черт',
#  'разберет',
#  ',',
#  'кричат',
#  '?',
#  'Быки-то',
#  'понимают',
#  ';',
#  'запрягите',
#  'двадцать',
#  ',',
#  'коли',
#  'крикнут',
#  'по-своему',
#  ',',
#  'быки',
#  'места…',
#  'Ужасные',
#  'плуты',
#  '!',
#  'А',
#  'возьмешь',
#  '?',
#  '..',
#  'Любят',
#  'деньги',
#  'драть',
#  'проезжающих…',
#  'Избаловали',
#  'мошенников',
#  '!',
#  'Увидите',
#  ',',
#  'возьмут',
#  'водку',
#  '.',
#  'Уж',
#  'знаю',
#  ',',
#  'проведут',
#  '!',
#  '–',
#  'А',
#  'давно',
#  'служите',
#  '?',
#  '–',
#  'Да',
#  ',',
#  'служил',
#  'Алексее',
#  'Петровиче',
#  '[',
#  '[',
#  '1',
#  '-',
#  'Ермолове',
#  '.',
#  '(',
#  'Прим',
#  '.',
#  'Лермонтова',
#  '.',
#  ')',
#  ']',
#  ']',
#  ',',
#  '–',
#  'отвечал',
#  ',',
#  'приосанившись',
#  '.',
#  '–',
#  'Когда',
#  'приехал',
#  'Линию',
#  ',',
#  'подпоручиком',
#  ',',
#  '–',
#  'прибавил',
#  ',',
#  '–',
#  'нем',
#  'получил',
#  'чина',
#  'дела',
#  'против',
#  'горцев',
#  '.',
#  '–',
#  'А',
#  '?',
#  '..',
#  '–',
#  'Теперь',
#  'считаюсь',
#  'третьем',
#  'линейном',
#  'батальоне',
#  '.',
#  'А',
#  ',',
#  'смею',
#  'спросить',
#  '?',
#  '..',
#  'Я',
#  'сказал',
#  '.',
#  'Разговор',
#  'этим',
#  'кончился',
#  'продолжали',
#  'молча',
#  'идти',
#  'друг',
#  'подле',
#  'друга',
#  '.',
#  'На',
#  'вершине',
#  'горы',
#  'нашли',
#  'снег',
#  '.',
#  'Солнце',
#  'закатилось',
#  ',',
#  'ночь',
#  'последовала',
#  'днем',
#  'промежутка',
#  ',',
#  'это',
#  'обыкновенно',
#  'бывает',
#  'юге',
#  ';',
#  'благодаря',
#  'отливу',
#  'снегов',
#  'легко',
#  'могли',
#  'различать',
#  'дорогу',
#  ',',
#  'которая',
#  'шла',
#  'гору',
#  ',',
#  'хотя',
#  'круто',
#  '.',
#  'Я',
#  'велел',
#  'положить',
#  'чемодан',
#  'свой',
#  'тележку',
#  ',',
#  'заменить',
#  'быков',
#  'лошадьми',
#  'последний',
#  'оглянулся',
#  'долину',
#  ';',
#  'густой',
#  'туман',
#  ',',
#  'нахлынувший',
#  'волнами',
#  'ущелий',
#  ',',
#  'покрывал',
#  'совершенно',
#  ',',
#  'единый',
#  'звук',
#  'долетал',
#  'оттуда',
#  'нашего',
#  'слуха',
#  '.',
#  'Осетины',
#  'шумно',
#  'обступили',
#  'требовали',
#  'водку',
#  ';',
#  'штабс-капитан',
#  'грозно',
#  'прикрикнул',
#  ',',
#  'вмиг',
#  'разбежались',
#  '.',
#  '–',
#  'Ведь',
#  'этакий',
#  'народ',
#  '!',
#  '–',
#  'сказал',
#  ',',
#  '–',
#  'хлеба',
#  'по-русски',
#  'назвать',
#  'умеет',
#  ',',
#  'выучил',
#  ':',
#  '«',
#  'Офицер',
#  ',',
#  'дай',
#  'водку',
#  '!',
#  '»',
#  'Уж',
#  'татары',
#  ':',
#  'те',
#  'непьющие…',
#  'До',
#  'станции',
#  'оставалось',
#  'версту',
#  '.',
#  'Кругом',
#  'тихо',
#  ',',
#  'тихо',
#  ',',
#  'жужжанию',
#  'комара',
#  'следить',
#  'полетом',
#  '.',
#  'Налево',
#  'чернело',
#  'глубокое',
#  'ущелье',
#  ';',
#  'впереди',
#  'темно-синие',
#  'вершины',
#  'гор',
#  ',',
#  'изрытые',
#  'морщинами',
#  ',',
#  'покрытые',
#  'слоями',
#  'снега',
#  ',',
#  'рисовались',
#  'бледном',
#  'небосклоне',
#  ',',
#  'сохранявшем',
#  'последний',
#  'отблеск',
#  'зари',
#  '.',
#  'На',
#  'темном',
#  'небе',
#  'начинали',
#  'мелькать',
#  'звезды',
#  ',',
#  'странно',
#  ',',
#  'показалось',
#  ',',
#  'оно',
#  'гораздо',
#  'выше',
#  ',',
#  'севере',
#  '.',
#  'По',
#  'обеим',
#  'сторонам',
#  'дороги',
#  'торчали',
#  'голые',
#  ',',
#  'черные',
#  'камни',
#  ';',
#  'кой-где',
#  'из-под',
#  'снега',
#  'выглядывали',
#  'кустарники',
#  ',',
#  'сухой',
#  'листок',
#  'шевелился',
#  ...]

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_3)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['во',
#  'всяк',
#  'книг',
#  'предислов',
#  'ест',
#  'перв',
#  'и',
#  'вмест',
#  'с',
#  'тем',
#  'последн',
#  'вещ',
#  ';',
#  'он',
#  'ил',
#  'служ',
#  'объяснен',
#  'цел',
#  'сочинен',
#  ',',
#  'ил',
#  'оправдан',
#  'и',
#  'ответ',
#  'на',
#  'критик',
#  '.',
#  'но',
#  'обыкновен',
#  'читател',
#  'дел',
#  'нет',
#  'до',
#  'нравствен',
#  'цел',
#  'и',
#  'до',
#  'журнальн',
#  'нападок',
#  ',',
#  'и',
#  'пот',
#  'он',
#  'не',
#  'чита',
#  'предислов',
#  '.',
#  'а',
#  'жал',
#  ',',
#  'что',
#  'эт',
#  'так',
#  ',',
#  'особен',
#  'у',
#  'нас',
#  '.',
#  'наш',
#  'публик',
#  'так',
#  'ещ',
#  'молод',
#  'и',
#  'простодушн',
#  ',',
#  'что',
#  'не',
#  'понима',
#  'басн',
#  ',',
#  'есл',
#  'в',
#  'конц',
#  'е',
#  'не',
#  'наход',
#  'нравоучен',
#  '.',
#  'он',
#  'не',
#  'угадыва',
#  'шутк',
#  ',',
#  'не',
#  'чувств',
#  'ирон',
#  ';',
#  'он',
#  'прост',
#  'дурн',
#  'воспита',
#  '.',
#  'он',
#  'ещ',
#  'не',
#  'знает',
#  ',',
#  'что',
#  'в',
#  'порядочн',
#  'обществ',
#  'и',
#  'в',
#  'порядочн',
#  'книг',
#  'явн',
#  'бран',
#  'не',
#  'может',
#  'имет',
#  'мест',
#  ';',
#  'что',
#  'современ',
#  'образован',
#  'изобрел',
#  'оруд',
#  'бол',
#  'остр',
#  ',',
#  'почт',
#  'невидим',
#  'и',
#  'тем',
#  'не',
#  'мен',
#  'смертельн',
#  ',',
#  'котор',
#  ',',
#  'под',
#  'одежд',
#  'лест',
#  ',',
#  'нанос',
#  'неотразим',
#  'и',
#  'верн',
#  'удар',
#  '.',
#  'наш',
#  'публик',
#  'похож',
#  'на',
#  'провинциа',
#  ',',
#  'котор',
#  ',',
#  'подслуша',
#  'разговор',
#  'двух',
#  'дипломат',
#  ',',
#  'принадлежа',
#  'к',
#  'враждебн',
#  'двор',
#  ',',
#  'оста',
#  'бы',
#  'увер',
#  ',',
#  'что',
#  'кажд',
#  'из',
#  'них',
#  'обманыва',
#  'сво',
#  'правительств',
#  'в',
#  'польз',
#  'взаимн',
#  'нежн',
#  'дружб',
#  '.',
#  'эт',
#  'книг',
#  'испыта',
#  'на',
#  'себ',
#  'ещ',
#  'недавн',
#  'несчастн',
#  'доверчив',
#  'некотор',
#  'читател',
#  'и',
#  'даж',
#  'журнал',
#  'к',
#  'буквальн',
#  'значен',
#  'слов',
#  '.',
#  'ин',
#  'ужасн',
#  'обидел',
#  ',',
#  'и',
#  'не',
#  'шут',
#  ',',
#  'что',
#  'им',
#  'став',
#  'в',
#  'пример',
#  'так',
#  'безнравствен',
#  'человек',
#  ',',
#  'как',
#  'гер',
#  'наш',
#  'времен',
#  ';',
#  'друг',
#  'же',
#  'очен',
#  'тонк',
#  'замеча',
#  ',',
#  'что',
#  'сочинител',
#  'нарисова',
#  'сво',
#  'портрет',
#  'и',
#  'портрет',
#  'сво',
#  'знакомых…',
#  'стар',
#  'и',
#  'жалк',
#  'шутк',
#  '!',
#  'но',
#  ',',
#  'видн',
#  ',',
#  'ру',
#  'так',
#  'уж',
#  'сотвор',
#  ',',
#  'что',
#  'все',
#  'в',
#  'не',
#  'обновля',
#  ',',
#  'кром',
#  'подобн',
#  'нелеп',
#  '.',
#  'сам',
#  'волшебн',
#  'из',
#  'волшебн',
#  'сказок',
#  'у',
#  'нас',
#  'едв',
#  'ли',
#  'избегнет',
#  'упрек',
#  'в',
#  'покушен',
#  'на',
#  'оскорблен',
#  'личност',
#  '!',
#  'гер',
#  'наш',
#  'времен',
#  ',',
#  'милостив',
#  'государ',
#  'мо',
#  ',',
#  'точн',
#  ',',
#  'портрет',
#  ',',
#  'но',
#  'не',
#  'одн',
#  'человек',
#  ':',
#  'эт',
#  'портрет',
#  ',',
#  'составлен',
#  'из',
#  'порок',
#  'всег',
#  'наш',
#  'поколен',
#  ',',
#  'в',
#  'полн',
#  'их',
#  'развит',
#  '.',
#  'вы',
#  'мне',
#  'опя',
#  'скажет',
#  ',',
#  'что',
#  'человек',
#  'не',
#  'может',
#  'быт',
#  'так',
#  'дур',
#  ',',
#  'а',
#  'я',
#  'вам',
#  'скаж',
#  ',',
#  'что',
#  'ежел',
#  'вы',
#  'вер',
#  'возможн',
#  'существован',
#  'всех',
#  'трагическ',
#  'и',
#  'романтическ',
#  'злоде',
#  ',',
#  'отч',
#  'же',
#  'вы',
#  'не',
#  'верует',
#  'в',
#  'действительн',
#  'печорин',
#  '?',
#  'есл',
#  'вы',
#  'любова',
#  'вымысл',
#  'горазд',
#  'бол',
#  'ужасн',
#  'и',
#  'уродлив',
#  ',',
#  'отч',
#  'же',
#  'этот',
#  'характер',
#  ',',
#  'даж',
#  'как',
#  'вымысел',
#  ',',
#  'не',
#  'наход',
#  'у',
#  'вас',
#  'пощад',
#  '?',
#  'уж',
#  'не',
#  'отт',
#  'ли',
#  ',',
#  'что',
#  'в',
#  'нем',
#  'больш',
#  'правд',
#  ',',
#  'нежел',
#  'бы',
#  'вы',
#  'тог',
#  'жела',
#  '?',
#  '..',
#  'вы',
#  'скажет',
#  ',',
#  'что',
#  'нравствен',
#  'от',
#  'эт',
#  'не',
#  'выигрыва',
#  '?',
#  'извин',
#  '.',
#  'довольн',
#  'люд',
#  'корм',
#  'сласт',
#  ';',
#  'у',
#  'них',
#  'от',
#  'эт',
#  'испорт',
#  'желудок',
#  ':',
#  'нужн',
#  'горьк',
#  'лекарств',
#  ',',
#  'едк',
#  'истин',
#  '.',
#  'но',
#  'не',
#  'дума',
#  ',',
#  'однак',
#  ',',
#  'посл',
#  'эт',
#  ',',
#  'чтоб',
#  'автор',
#  'эт',
#  'книг',
#  'имел',
#  'когда-нибуд',
#  'горд',
#  'мечт',
#  'сдела',
#  'исправител',
#  'людск',
#  'порок',
#  '.',
#  'бож',
#  'ег',
#  'избав',
#  'от',
#  'так',
#  'невежеств',
#  '!',
#  'ем',
#  'прост',
#  'был',
#  'весел',
#  'рисова',
#  'современ',
#  'человек',
#  ',',
#  'как',
#  'он',
#  'ег',
#  'понима',
#  ',',
#  'и',
#  'к',
#  'ег',
#  'и',
#  'ваш',
#  'несчаст',
#  ',',
#  'слишк',
#  'част',
#  'встреча',
#  '.',
#  'будет',
#  'и',
#  'тог',
#  ',',
#  'что',
#  'болезн',
#  'указа',
#  ',',
#  'а',
#  'как',
#  'е',
#  'излеч',
#  '–',
#  'эт',
#  'уж',
#  'бог',
#  'знает',
#  '!',
#  'част',
#  'перв',
#  'I.',
#  'бэл',
#  'я',
#  'еха',
#  'на',
#  'перекладн',
#  'из',
#  'тифлис',
#  '.',
#  'вся',
#  'поклаж',
#  'мо',
#  'тележк',
#  'состоя',
#  'из',
#  'одн',
#  'небольш',
#  'чемода',
#  ',',
#  'котор',
#  'до',
#  'половин',
#  'был',
#  'наб',
#  'путев',
#  'записк',
#  'о',
#  'груз',
#  '.',
#  'больш',
#  'част',
#  'из',
#  'них',
#  ',',
#  'к',
#  'счаст',
#  'для',
#  'вас',
#  ',',
#  'потеря',
#  ',',
#  'а',
#  'чемода',
#  'с',
#  'остальн',
#  'вещ',
#  ',',
#  'к',
#  'счаст',
#  'для',
#  'мен',
#  ',',
#  'оста',
#  'цел',
#  '.',
#  'уж',
#  'солнц',
#  'начина',
#  'прята',
#  'за',
#  'снегов',
#  'хребет',
#  ',',
#  'когд',
#  'я',
#  'въеха',
#  'в',
#  'койшаурск',
#  'долин',
#  '.',
#  'осетин-извозчик',
#  'неутомим',
#  'погоня',
#  'лошад',
#  ',',
#  'чтоб',
#  'успет',
#  'до',
#  'ноч',
#  'взобра',
#  'на',
#  'койшаурск',
#  'гор',
#  ',',
#  'и',
#  'во',
#  'все',
#  'горл',
#  'распева',
#  'песн',
#  '.',
#  'славн',
#  'мест',
#  'эт',
#  'долин',
#  '!',
#  'со',
#  'всех',
#  'сторон',
#  'гор',
#  'неприступн',
#  ',',
#  'красноват',
#  'скал',
#  ',',
#  'обвеша',
#  'зелен',
#  'плющ',
#  'и',
#  'увенча',
#  'куп',
#  'чинар',
#  ',',
#  'желт',
#  'обрыв',
#  ',',
#  'исчерчен',
#  'промоин',
#  ',',
#  'а',
#  'там',
#  'высоко-высок',
#  'золот',
#  'бахром',
#  'снег',
#  ',',
#  'а',
#  'вниз',
#  'арагв',
#  ',',
#  'обня',
#  'с',
#  'друг',
#  'безымен',
#  'речк',
#  ',',
#  'шумн',
#  'вырыва',
#  'из',
#  'черн',
#  ',',
#  'полн',
#  'мгло',
#  'ущел',
#  ',',
#  'тянет',
#  'серебрян',
#  'нит',
#  'и',
#  'сверка',
#  ',',
#  'как',
#  'зме',
#  'сво',
#  'чешу',
#  '.',
#  'подъеха',
#  'к',
#  'подошв',
#  'койшаурск',
#  'гор',
#  ',',
#  'мы',
#  'останов',
#  'возл',
#  'духа',
#  '.',
#  'тут',
#  'толп',
#  'шумн',
#  'десятк',
#  'два',
#  'грузин',
#  'и',
#  'горц',
#  ';',
#  'поблиз',
#  'карава',
#  'верблюд',
#  'останов',
#  'для',
#  'ночлег',
#  '.',
#  'я',
#  'долж',
#  'был',
#  'наня',
#  'бык',
#  ',',
#  'чтоб',
#  'втащ',
#  'мо',
#  'тележк',
#  'на',
#  'эт',
#  'проклят',
#  'гор',
#  ',',
#  'пот',
#  'что',
#  'был',
#  'уж',
#  'осен',
#  'и',
#  'гололедиц',
#  ',',
#  '–',
#  'а',
#  'эт',
#  'гор',
#  'имеет',
#  'окол',
#  'двух',
#  'верст',
#  'длин',
#  '.',
#  'неч',
#  'дела',
#  ',',
#  'я',
#  'наня',
#  'шест',
#  'бык',
#  'и',
#  'нескольк',
#  'осетин',
#  '.',
#  'один',
#  'из',
#  'них',
#  'взвал',
#  'себ',
#  'на',
#  'плеч',
#  'мо',
#  'чемода',
#  ',',
#  'друг',
#  'стал',
#  'помога',
#  'бык',
#  'почт',
#  'одн',
#  'крик',
#  '.',
#  'за',
#  'мо',
#  'тележк',
#  'четверк',
#  'бык',
#  'тащ',
#  'друг',
#  'как',
#  'ни',
#  'в',
#  'чем',
#  'не',
#  'быва',
#  ',',
#  'несмотр',
#  'на',
#  'то',
#  ',',
#  'что',
#  'он',
#  'был',
#  'доверх',
#  'наклад',
#  '.',
#  'эт',
#  'обстоятельств',
#  'мен',
#  'удив',
#  '.',
#  'за',
#  'не',
#  'шел',
#  'е',
#  'хозяин',
#  ',',
#  'покурив',
#  'из',
#  'маленьк',
#  'кабардинск',
#  'трубочк',
#  ',',
#  'обдела',
#  'в',
#  'серебр',
#  '.',
#  'на',
#  'нем',
#  'был',
#  'офицерск',
#  'сюртук',
#  'без',
#  'эполет',
#  'и',
#  'черкесск',
#  'мохнат',
#  'шапк',
#  '.',
#  'он',
#  'каза',
#  'лет',
#  'пятидесят',
#  ';',
#  'смугл',
#  'цвет',
#  'лиц',
#  'ег',
#  'показыва',
#  ',',
#  'что',
#  'он',
#  'давн',
#  'знаком',
#  'с',
#  'закавказск',
#  'солнц',
#  ',',
#  'и',
#  'преждевремен',
#  'поседевш',
#  'ус',
#  'не',
#  'соответствова',
#  'ег',
#  'тверд',
#  'походк',
#  'и',
#  'бодр',
#  'вид',
#  '.',
#  'я',
#  'подошел',
#  'к',
#  'нем',
#  'и',
#  'поклон',
#  ':',
#  'он',
#  'молч',
#  'отвеча',
#  'мне',
#  'на',
#  'поклон',
#  'и',
#  'пуст',
#  'огромн',
#  'клуб',
#  'дым',
#  '.',
#  '–',
#  'мы',
#  'с',
#  'вам',
#  'попутчик',
#  ',',
#  'кажет',
#  '?',
#  'он',
#  'молч',
#  'опя',
#  'поклон',
#  '.',
#  '–',
#  'вы',
#  ',',
#  'верн',
#  ',',
#  'едет',
#  'в',
#  'ставропол',
#  '?',
#  '–',
#  'так-с',
#  'точно…',
#  'с',
#  'казен',
#  'вещ',
#  '.',
#  '–',
#  'скаж',
#  ',',
#  'пожалуйст',
#  ',',
#  'отч',
#  'эт',
#  'ваш',
#  'тяжел',
#  'тележк',
#  'четыр',
#  'бык',
#  'тащат',
#  'шут',
#  ',',
#  'а',
#  'мо',
#  ',',
#  'пуст',
#  ',',
#  'шест',
#  'скот',
#  'едв',
#  'подвига',
#  'с',
#  'помощ',
#  'эт',
#  'осетин',
#  '?',
#  'он',
#  'лукав',
#  'улыбнул',
#  'и',
#  'значительн',
#  'взглянул',
#  'на',
#  'мен',
#  '.',
#  '–',
#  'вы',
#  ',',
#  'верн',
#  ',',
#  'недавн',
#  'на',
#  'кавказ',
#  '?',
#  '–',
#  'с',
#  'год',
#  ',',
#  '–',
#  'отвеча',
#  'я.',
#  'он',
#  'улыбнул',
#  'вторичн',
#  '.',
#  '–',
#  'а',
#  'что',
#  'ж',
#  '?',
#  '–',
#  'да',
#  'так-с',
#  '!',
#  'ужасн',
#  'бест',
#  'эт',
#  'азиат',
#  '!',
#  'вы',
#  'дума',
#  ',',
#  'он',
#  'помога',
#  ',',
#  'что',
#  'кричат',
#  '?',
#  'а',
#  'черт',
#  'их',
#  'разберет',
#  ',',
#  'что',
#  'он',
#  'кричат',
#  '?',
#  'быки-т',
#  'их',
#  'понима',
#  ';',
#  'запряг',
#  'хот',
#  'двадца',
#  ',',
#  'так',
#  'кол',
#  'он',
#  'крикнут',
#  'по-сво',
#  ',',
#  'бык',
#  'все',
#  'ни',
#  'с',
#  'места…',
#  'ужасн',
#  'плут',
#  '!',
#  'а',
#  'что',
#  'с',
#  'них',
#  'возьмеш',
#  '?',
#  '..',
#  'люб',
#  'деньг',
#  'драт',
#  'с',
#  'проезжающих…',
#  'избалова',
#  'мошенник',
#  '!',
#  ...]

# %%
len(words)
# Out:
# 53901

# %%
len(tokenized_filtered)
# Out:
# 38661

# %% [markdown]
# Silence

# %%
with open("5. Мцыри.txt") as file:
    text_4=file.read()

# %%
words=word_tokenize(text_4)
words
# Out:
# ['1',
#  'Немного',
#  'лет',
#  'тому',
#  'назад',
#  ',',
#  'Там',
#  ',',
#  'где',
#  'сливаяся',
#  'шумят',
#  'Обнявшись',
#  ',',
#  'будто',
#  'две',
#  'сестры',
#  ',',
#  'Струи',
#  'Арагвы',
#  'и',
#  'Куры',
#  ',',
#  'Был',
#  'монастырь',
#  '.',
#  'Из-за',
#  'горы',
#  'И',
#  'нынче',
#  'видит',
#  'пешеход',
#  'Столбы',
#  'обрушенных',
#  'ворот',
#  ',',
#  'И',
#  'башни',
#  ',',
#  'и',
#  'церковный',
#  'свод',
#  ';',
#  'Но',
#  'не',
#  'курится',
#  'уж',
#  'под',
#  'ним',
#  'Кадильниц',
#  'благовонный',
#  'дым',
#  ',',
#  'Не',
#  'слышно',
#  'пенье',
#  'в',
#  'поздний',
#  'час',
#  'Молящих',
#  'иноков',
#  'за',
#  'нас',
#  '.',
#  'Теперь',
#  'один',
#  'старик',
#  'седой',
#  ',',
#  'Развалин',
#  'страж',
#  'полуживой',
#  ',',
#  'Людьми',
#  'и',
#  'смертию',
#  'забыт',
#  ',',
#  'Сметает',
#  'пыль',
#  'с',
#  'могильных',
#  'плит',
#  ',',
#  'Которых',
#  'надпись',
#  'говорит',
#  'О',
#  'славе',
#  'прошлой',
#  '–',
#  'и',
#  'о',
#  'том',
#  ',',
#  'Как',
#  'удручен',
#  'своим',
#  'венцом',
#  ',',
#  'Такой-то',
#  'царь',
#  ',',
#  'в',
#  'такой-то',
#  'год',
#  ',',
#  'Вручал',
#  'России',
#  'свой',
#  'народ',
#  '.',
#  'И',
#  'божья',
#  'благодать',
#  'сошла',
#  'На',
#  'Грузию',
#  '!',
#  '–',
#  'она',
#  'цвела',
#  'С',
#  'тех',
#  'пор',
#  'в',
#  'тени',
#  'своих',
#  'садов',
#  ',',
#  'Не',
#  'опасаяся',
#  'врагов',
#  ',',
#  'За',
#  'гранью',
#  'дружеских',
#  'штыков',
#  '.',
#  '2',
#  'Однажды',
#  'русский',
#  'генерал',
#  'Из',
#  'гор',
#  'к',
#  'Тифлису',
#  'проезжал',
#  ';',
#  'Ребенка',
#  'пленного',
#  'он',
#  'вез',
#  '.',
#  'Тот',
#  'занемог',
#  ',',
#  'не',
#  'перенес',
#  'Трудов',
#  'далекого',
#  'пути',
#  '.',
#  'Он',
#  'был',
#  ',',
#  'казалось',
#  ',',
#  'лет',
#  'шести',
#  ';',
#  'Как',
#  'серна',
#  'гор',
#  ',',
#  'пуглив',
#  'и',
#  'дик',
#  'И',
#  'слаб',
#  'и',
#  'гибок',
#  ',',
#  'как',
#  'тростник',
#  '.',
#  'Но',
#  'в',
#  'нем',
#  'мучительный',
#  'недуг',
#  'Развил',
#  'тогда',
#  'могучий',
#  'дух',
#  'Его',
#  'отцов',
#  '.',
#  'Без',
#  'жалоб',
#  'он',
#  'Томился',
#  '–',
#  'даже',
#  'слабый',
#  'стон',
#  'Из',
#  'детских',
#  'губ',
#  'не',
#  'вылетал',
#  ',',
#  'Он',
#  'знаком',
#  'пищу',
#  'отвергал',
#  ',',
#  'И',
#  'тихо',
#  ',',
#  'гордо',
#  'умирал',
#  '.',
#  'Из',
#  'жалости',
#  'один',
#  'монах',
#  'Больного',
#  'призрел',
#  ',',
#  'и',
#  'в',
#  'стенах',
#  'Хранительных',
#  'остался',
#  'он',
#  'Искусством',
#  'дружеским',
#  'спасен',
#  '.',
#  'Но',
#  ',',
#  'чужд',
#  'ребяческих',
#  'утех',
#  ',',
#  'Сначала',
#  'бегал',
#  'он',
#  'от',
#  'всех',
#  ',',
#  'Бродил',
#  'безмолвен',
#  ',',
#  'одинок',
#  ',',
#  'Смотрел',
#  'вздыхая',
#  'на',
#  'восток',
#  ',',
#  'Томим',
#  'неясною',
#  'тоской',
#  'По',
#  'стороне',
#  'своей',
#  'родной',
#  '.',
#  'Но',
#  'после',
#  'к',
#  'плену',
#  'он',
#  'привык',
#  ',',
#  'Стал',
#  'понимать',
#  'чужой',
#  'язык',
#  ',',
#  'Был',
#  'окрещен',
#  'святым',
#  'отцом',
#  ',',
#  'И',
#  ',',
#  'с',
#  'шумным',
#  'светом',
#  'незнаком',
#  ',',
#  'Уже',
#  'хотел',
#  'во',
#  'цвете',
#  'лет',
#  'Изречь',
#  'монашеский',
#  'обет',
#  ',',
#  'Как',
#  'вдруг',
#  'однажды',
#  'он',
#  'исчез',
#  'Осенней',
#  'ночью',
#  '.',
#  'Темный',
#  'лес',
#  'Тянулся',
#  'по',
#  'горам',
#  'кругом',
#  '.',
#  'Три',
#  'дня',
#  'все',
#  'поиски',
#  'по',
#  'нем',
#  'Напрасны',
#  'были',
#  ',',
#  'но',
#  'потом',
#  'Его',
#  'в',
#  'степи',
#  'без',
#  'чувств',
#  'нашли',
#  'И',
#  'вновь',
#  'в',
#  'обитель',
#  'принесли',
#  ';',
#  'Он',
#  'страшно',
#  'бледен',
#  'был',
#  'и',
#  'худ',
#  'И',
#  'слаб',
#  ',',
#  'как',
#  'будто',
#  'долгий',
#  'труд',
#  ',',
#  'Болезнь',
#  'иль',
#  'голод',
#  'испытал',
#  '.',
#  'Он',
#  'на',
#  'допрос',
#  'не',
#  'отвечал',
#  ',',
#  'И',
#  'с',
#  'каждым',
#  'днем',
#  'приметно',
#  'вял',
#  ';',
#  'И',
#  'близок',
#  'стал',
#  'его',
#  'конец',
#  '.',
#  'Тогда',
#  'пришел',
#  'к',
#  'нему',
#  'чернец',
#  'С',
#  'увещеваньем',
#  'и',
#  'мольбой',
#  ';',
#  'И',
#  ',',
#  'гордо',
#  'выслушав',
#  ',',
#  'больной',
#  'Привстал',
#  ',',
#  'собрав',
#  'остаток',
#  'сил',
#  ',',
#  'И',
#  'долго',
#  'так',
#  'он',
#  'говорил',
#  ':',
#  '3',
#  '«',
#  'Ты',
#  'слушать',
#  'исповедь',
#  'мою',
#  'Сюда',
#  'пришел',
#  ',',
#  'благодарю',
#  '.',
#  'Всё',
#  'лучше',
#  'перед',
#  'кем-нибудь',
#  'Словами',
#  'облегчить',
#  'мне',
#  'грудь',
#  ';',
#  'Но',
#  'людям',
#  'я',
#  'не',
#  'делал',
#  'зла',
#  ',',
#  'И',
#  'потому',
#  'мои',
#  'дела',
#  'Не',
#  'много',
#  'пользы',
#  'вам',
#  'узнать',
#  ';',
#  'А',
#  'душу',
#  'можно',
#  'ль',
#  'рассказать',
#  '?',
#  'Я',
#  'мало',
#  'жил',
#  ',',
#  'и',
#  'жил',
#  'в',
#  'плену',
#  '.',
#  'Таких',
#  'две',
#  'жизни',
#  'за',
#  'одну',
#  ',',
#  'Но',
#  'только',
#  'полную',
#  'тревог',
#  ',',
#  'Я',
#  'променял',
#  'бы',
#  ',',
#  'если',
#  'б',
#  'мог',
#  '.',
#  'Я',
#  'знал',
#  'одной',
#  'лишь',
#  'думы',
#  'власть',
#  ',',
#  'Одну',
#  '–',
#  'но',
#  'пламенную',
#  'страсть',
#  ':',
#  'Она',
#  ',',
#  'как',
#  'червь',
#  ',',
#  'во',
#  'мне',
#  'жила',
#  ',',
#  'Изгрызла',
#  'душу',
#  'и',
#  'сожгла',
#  '.',
#  'Она',
#  'мечты',
#  'мои',
#  'звала',
#  'От',
#  'келий',
#  'душных',
#  'и',
#  'молитв',
#  'В',
#  'тот',
#  'чудный',
#  'мир',
#  'тревог',
#  'и',
#  'битв',
#  ',',
#  'Где',
#  'в',
#  'тучах',
#  'прячутся',
#  'скалы',
#  ',',
#  'Где',
#  'люди',
#  'вольны',
#  ',',
#  'как',
#  'орлы',
#  '.',
#  'Я',
#  'эту',
#  'страсть',
#  'во',
#  'тьме',
#  'ночной',
#  'Вскормил',
#  'слезами',
#  'и',
#  'тоской',
#  ';',
#  'Ее',
#  'пред',
#  'небом',
#  'и',
#  'землей',
#  'Я',
#  'ныне',
#  'громко',
#  'признаю',
#  'И',
#  'о',
#  'прощеньи',
#  'не',
#  'молю',
#  '.',
#  '4',
#  '«',
#  'Старик',
#  '!',
#  'я',
#  'слышал',
#  'много',
#  'раз',
#  ',',
#  'Что',
#  'ты',
#  'меня',
#  'от',
#  'смерти',
#  'спас',
#  '—',
#  'Зачем',
#  '?',
#  '…',
#  'угрюм',
#  'и',
#  'одинок',
#  ',',
#  'Грозой',
#  'оторванный',
#  'листок',
#  ',',
#  'Я',
#  'вырос',
#  'в',
#  'сумрачных',
#  'стенах',
#  ',',
#  'Душой',
#  'дитя',
#  ',',
#  'судьбой',
#  'монах',
#  '.',
#  'Я',
#  'никому',
#  'не',
#  'мог',
#  'сказать',
#  'Священных',
#  'слов',
#  '–',
#  '«',
#  'отец',
#  '»',
#  'и',
#  '«',
#  'мать',
#  '»',
#  '.',
#  'Конечно',
#  ',',
#  'ты',
#  'хотел',
#  ',',
#  'старик',
#  ',',
#  'Чтоб',
#  'я',
#  'в',
#  'обители',
#  'отвык',
#  'От',
#  'этих',
#  'сладостных',
#  'имен',
#  '.',
#  'Напрасно',
#  ':',
#  'звук',
#  'их',
#  'был',
#  'рожден',
#  'Со',
#  'мной',
#  '.',
#  'Я',
#  'видел',
#  'у',
#  'других',
#  'Отчизну',
#  ',',
#  'дом',
#  ',',
#  'друзей',
#  ',',
#  'родных',
#  ',',
#  'А',
#  'у',
#  'себя',
#  'не',
#  'находил',
#  'Не',
#  'только',
#  'милых',
#  'душ',
#  '–',
#  'могил',
#  '!',
#  'Тогда',
#  ',',
#  'пустых',
#  'не',
#  'тратя',
#  'слез',
#  ',',
#  'В',
#  'душе',
#  'я',
#  'клятву',
#  'произнес',
#  ':',
#  'Хотя',
#  'на',
#  'миг',
#  'когда-нибудь',
#  'Мою',
#  'пылающую',
#  'грудь',
#  'Прижать',
#  'с',
#  'тоской',
#  'к',
#  'груди',
#  'другой',
#  ',',
#  'Хоть',
#  'незнакомой',
#  ',',
#  'но',
#  'родной',
#  '.',
#  'Увы',
#  ',',
#  'теперь',
#  'мечтанья',
#  'те',
#  'Погибли',
#  'в',
#  'полной',
#  'красоте',
#  ',',
#  'И',
#  'я',
#  ',',
#  'как',
#  'жил',
#  ',',
#  'в',
#  'земле',
#  'чужой',
#  'Умру',
#  'рабом',
#  'и',
#  'сиротой',
#  '.',
#  '5',
#  '«',
#  'Меня',
#  'могила',
#  'не',
#  'страшит',
#  ':',
#  'Там',
#  ',',
#  'говорят',
#  ',',
#  'страданье',
#  'спит',
#  'В',
#  'холодной',
#  ',',
#  'вечной',
#  'тишине',
#  ';',
#  'Но',
#  'с',
#  'жизнью',
#  'жаль',
#  'расстаться',
#  'мне',
#  '.',
#  'Я',
#  'молод',
#  ',',
#  'молод…',
#  'Знал',
#  'ли',
#  'ты',
#  'Разгульной',
#  'юности',
#  'мечты',
#  '?',
#  'Или',
#  'не',
#  'знал',
#  ',',
#  'или',
#  'забыл',
#  ',',
#  'Как',
#  'ненавидел',
#  'и',
#  'любил',
#  ';',
#  'Как',
#  'сердце',
#  'билося',
#  'живей',
#  'При',
#  'виде',
#  'солнца',
#  'и',
#  'полей',
#  'С',
#  'высокой',
#  'башни',
#  'угловой',
#  ',',
#  'Где',
#  'воздух',
#  'свеж',
#  'и',
#  'где',
#  'порой',
#  'В',
#  'глубокой',
#  'скважине',
#  'стены',
#  ',',
#  'Дитя',
#  'неведомой',
#  'страны',
#  ',',
#  'Прижавшись',
#  ',',
#  'голубь',
#  'молодой',
#  'Сидит',
#  ',',
#  'испуганный',
#  'грозой',
#  '?',
#  'Пускай',
#  'теперь',
#  'прекрасный',
#  'свет',
#  'Тебе',
#  'постыл',
#  ':',
#  'ты',
#  'слаб',
#  ',',
#  'ты',
#  'сед',
#  ',',
#  'И',
#  'от',
#  'желаний',
#  'ты',
#  'отвык',
#  '.',
#  'Что',
#  'за',
#  'нужда',
#  '?',
#  'Ты',
#  'жил',
#  ',',
#  'старик',
#  '!',
#  'Тебе',
#  'есть',
#  'в',
#  'мире',
#  'что',
#  'забыть',
#  ',',
#  'Ты',
#  'жил',
#  ',',
#  '–',
#  'я',
#  'также',
#  'мог',
#  'бы',
#  'жить',
#  '!',
#  '6',
#  '«',
#  'Ты',
#  'хочешь',
#  'знать',
#  ',',
#  'что',
#  'видел',
#  'я',
#  'На',
#  'воле',
#  '?',
#  '–',
#  'Пышные',
#  'поля',
#  ',',
#  'Холмы',
#  ',',
#  'покрытые',
#  'венцом',
#  'Дерев',
#  ',',
#  'разросшихся',
#  'кругом',
#  ',',
#  'Шумящих',
#  'свежею',
#  'толпой',
#  ',',
#  'Как',
#  'братья',
#  'в',
#  'пляске',
#  'круговой',
#  '.',
#  'Я',
#  'видел',
#  'груды',
#  'темных',
#  'скал',
#  ',',
#  'Когда',
#  'поток',
#  'их',
#  'разделял',
#  ',',
#  'И',
#  'думы',
#  'их',
#  'я',
#  'угадал',
#  ':',
#  'Мне',
#  'было',
#  'свыше',
#  'то',
#  'дано',
#  '!',
#  'Простерты',
#  'в',
#  'воздухе',
#  'давно',
#  'Объятья',
#  'каменные',
#  'их',
#  ',',
#  'И',
#  'жаждут',
#  'встречи',
#  'каждый',
#  'миг',
#  ';',
#  'Но',
#  'дни',
#  'бегут',
#  ',',
#  'бегут',
#  'года',
#  '—',
#  'Им',
#  'не',
#  'сойтися',
#  'никогда',
#  '!',
#  'Я',
#  'видел',
#  'горные',
#  'хребты',
#  ',',
#  'Причудливые',
#  'как',
#  'мечты',
#  ',',
#  'Когда',
#  'в',
#  'час',
#  'утренней',
#  'зари',
#  'Курилися',
#  ',',
#  'как',
#  'алтари',
#  ',',
#  'Их',
#  'выси',
#  'в',
#  'небе',
#  'голубом',
#  ',',
#  'И',
#  'облачко',
#  'за',
#  'облачком',
#  ',',
#  'Покинув',
#  'тайный',
#  'свой',
#  'ночлег',
#  ',',
#  'К',
#  'востоку',
#  'направляло',
#  'бег',
#  '—',
#  'Как',
#  'будто',
#  'белый',
#  'караван',
#  'Залетных',
#  'птиц',
#  'из',
#  'дальних',
#  'стран',
#  '!',
#  'В',
#  'дали',
#  'я',
#  'видел',
#  'сквозь',
#  'туман',
#  ',',
#  'В',
#  'снегах',
#  ',',
#  'горящих',
#  'как',
#  ...]

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['1',
#  'Немного',
#  'лет',
#  'тому',
#  'назад',
#  ',',
#  'Там',
#  ',',
#  'сливаяся',
#  'шумят',
#  'Обнявшись',
#  ',',
#  'две',
#  'сестры',
#  ',',
#  'Струи',
#  'Арагвы',
#  'Куры',
#  ',',
#  'Был',
#  'монастырь',
#  '.',
#  'Из-за',
#  'горы',
#  'И',
#  'нынче',
#  'видит',
#  'пешеход',
#  'Столбы',
#  'обрушенных',
#  'ворот',
#  ',',
#  'И',
#  'башни',
#  ',',
#  'церковный',
#  'свод',
#  ';',
#  'Но',
#  'курится',
#  'Кадильниц',
#  'благовонный',
#  'дым',
#  ',',
#  'Не',
#  'слышно',
#  'пенье',
#  'поздний',
#  'час',
#  'Молящих',
#  'иноков',
#  '.',
#  'Теперь',
#  'старик',
#  'седой',
#  ',',
#  'Развалин',
#  'страж',
#  'полуживой',
#  ',',
#  'Людьми',
#  'смертию',
#  'забыт',
#  ',',
#  'Сметает',
#  'пыль',
#  'могильных',
#  'плит',
#  ',',
#  'Которых',
#  'надпись',
#  'говорит',
#  'О',
#  'славе',
#  'прошлой',
#  '–',
#  ',',
#  'Как',
#  'удручен',
#  'своим',
#  'венцом',
#  ',',
#  'Такой-то',
#  'царь',
#  ',',
#  'такой-то',
#  'год',
#  ',',
#  'Вручал',
#  'России',
#  'свой',
#  'народ',
#  '.',
#  'И',
#  'божья',
#  'благодать',
#  'сошла',
#  'На',
#  'Грузию',
#  '!',
#  '–',
#  'цвела',
#  'С',
#  'тех',
#  'пор',
#  'тени',
#  'своих',
#  'садов',
#  ',',
#  'Не',
#  'опасаяся',
#  'врагов',
#  ',',
#  'За',
#  'гранью',
#  'дружеских',
#  'штыков',
#  '.',
#  '2',
#  'Однажды',
#  'русский',
#  'генерал',
#  'Из',
#  'гор',
#  'Тифлису',
#  'проезжал',
#  ';',
#  'Ребенка',
#  'пленного',
#  'вез',
#  '.',
#  'Тот',
#  'занемог',
#  ',',
#  'перенес',
#  'Трудов',
#  'далекого',
#  'пути',
#  '.',
#  'Он',
#  ',',
#  'казалось',
#  ',',
#  'лет',
#  'шести',
#  ';',
#  'Как',
#  'серна',
#  'гор',
#  ',',
#  'пуглив',
#  'дик',
#  'И',
#  'слаб',
#  'гибок',
#  ',',
#  'тростник',
#  '.',
#  'Но',
#  'нем',
#  'мучительный',
#  'недуг',
#  'Развил',
#  'могучий',
#  'дух',
#  'Его',
#  'отцов',
#  '.',
#  'Без',
#  'жалоб',
#  'Томился',
#  '–',
#  'слабый',
#  'стон',
#  'Из',
#  'детских',
#  'губ',
#  'вылетал',
#  ',',
#  'Он',
#  'знаком',
#  'пищу',
#  'отвергал',
#  ',',
#  'И',
#  'тихо',
#  ',',
#  'гордо',
#  'умирал',
#  '.',
#  'Из',
#  'жалости',
#  'монах',
#  'Больного',
#  'призрел',
#  ',',
#  'стенах',
#  'Хранительных',
#  'остался',
#  'Искусством',
#  'дружеским',
#  'спасен',
#  '.',
#  'Но',
#  ',',
#  'чужд',
#  'ребяческих',
#  'утех',
#  ',',
#  'Сначала',
#  'бегал',
#  ',',
#  'Бродил',
#  'безмолвен',
#  ',',
#  'одинок',
#  ',',
#  'Смотрел',
#  'вздыхая',
#  'восток',
#  ',',
#  'Томим',
#  'неясною',
#  'тоской',
#  'По',
#  'стороне',
#  'своей',
#  'родной',
#  '.',
#  'Но',
#  'плену',
#  'привык',
#  ',',
#  'Стал',
#  'понимать',
#  'чужой',
#  'язык',
#  ',',
#  'Был',
#  'окрещен',
#  'святым',
#  'отцом',
#  ',',
#  'И',
#  ',',
#  'шумным',
#  'светом',
#  'незнаком',
#  ',',
#  'Уже',
#  'хотел',
#  'цвете',
#  'лет',
#  'Изречь',
#  'монашеский',
#  'обет',
#  ',',
#  'Как',
#  'однажды',
#  'исчез',
#  'Осенней',
#  'ночью',
#  '.',
#  'Темный',
#  'лес',
#  'Тянулся',
#  'горам',
#  'кругом',
#  '.',
#  'Три',
#  'дня',
#  'поиски',
#  'нем',
#  'Напрасны',
#  ',',
#  'Его',
#  'степи',
#  'чувств',
#  'нашли',
#  'И',
#  'вновь',
#  'обитель',
#  'принесли',
#  ';',
#  'Он',
#  'страшно',
#  'бледен',
#  'худ',
#  'И',
#  'слаб',
#  ',',
#  'долгий',
#  'труд',
#  ',',
#  'Болезнь',
#  'иль',
#  'голод',
#  'испытал',
#  '.',
#  'Он',
#  'допрос',
#  'отвечал',
#  ',',
#  'И',
#  'каждым',
#  'днем',
#  'приметно',
#  'вял',
#  ';',
#  'И',
#  'близок',
#  'стал',
#  'конец',
#  '.',
#  'Тогда',
#  'пришел',
#  'нему',
#  'чернец',
#  'С',
#  'увещеваньем',
#  'мольбой',
#  ';',
#  'И',
#  ',',
#  'гордо',
#  'выслушав',
#  ',',
#  'больной',
#  'Привстал',
#  ',',
#  'собрав',
#  'остаток',
#  'сил',
#  ',',
#  'И',
#  'долго',
#  'говорил',
#  ':',
#  '3',
#  '«',
#  'Ты',
#  'слушать',
#  'исповедь',
#  'мою',
#  'Сюда',
#  'пришел',
#  ',',
#  'благодарю',
#  '.',
#  'Всё',
#  'кем-нибудь',
#  'Словами',
#  'облегчить',
#  'грудь',
#  ';',
#  'Но',
#  'людям',
#  'делал',
#  'зла',
#  ',',
#  'И',
#  'мои',
#  'дела',
#  'Не',
#  'пользы',
#  'узнать',
#  ';',
#  'А',
#  'душу',
#  'ль',
#  'рассказать',
#  '?',
#  'Я',
#  'мало',
#  'жил',
#  ',',
#  'жил',
#  'плену',
#  '.',
#  'Таких',
#  'две',
#  'жизни',
#  'одну',
#  ',',
#  'Но',
#  'полную',
#  'тревог',
#  ',',
#  'Я',
#  'променял',
#  ',',
#  'б',
#  'мог',
#  '.',
#  'Я',
#  'знал',
#  'одной',
#  'лишь',
#  'думы',
#  'власть',
#  ',',
#  'Одну',
#  '–',
#  'пламенную',
#  'страсть',
#  ':',
#  'Она',
#  ',',
#  'червь',
#  ',',
#  'жила',
#  ',',
#  'Изгрызла',
#  'душу',
#  'сожгла',
#  '.',
#  'Она',
#  'мечты',
#  'мои',
#  'звала',
#  'От',
#  'келий',
#  'душных',
#  'молитв',
#  'В',
#  'чудный',
#  'мир',
#  'тревог',
#  'битв',
#  ',',
#  'Где',
#  'тучах',
#  'прячутся',
#  'скалы',
#  ',',
#  'Где',
#  'люди',
#  'вольны',
#  ',',
#  'орлы',
#  '.',
#  'Я',
#  'страсть',
#  'тьме',
#  'ночной',
#  'Вскормил',
#  'слезами',
#  'тоской',
#  ';',
#  'Ее',
#  'пред',
#  'небом',
#  'землей',
#  'Я',
#  'ныне',
#  'громко',
#  'признаю',
#  'И',
#  'прощеньи',
#  'молю',
#  '.',
#  '4',
#  '«',
#  'Старик',
#  '!',
#  'слышал',
#  ',',
#  'Что',
#  'смерти',
#  'спас',
#  '—',
#  'Зачем',
#  '?',
#  '…',
#  'угрюм',
#  'одинок',
#  ',',
#  'Грозой',
#  'оторванный',
#  'листок',
#  ',',
#  'Я',
#  'вырос',
#  'сумрачных',
#  'стенах',
#  ',',
#  'Душой',
#  'дитя',
#  ',',
#  'судьбой',
#  'монах',
#  '.',
#  'Я',
#  'никому',
#  'мог',
#  'сказать',
#  'Священных',
#  'слов',
#  '–',
#  '«',
#  'отец',
#  '»',
#  '«',
#  'мать',
#  '»',
#  '.',
#  'Конечно',
#  ',',
#  'хотел',
#  ',',
#  'старик',
#  ',',
#  'Чтоб',
#  'обители',
#  'отвык',
#  'От',
#  'этих',
#  'сладостных',
#  'имен',
#  '.',
#  'Напрасно',
#  ':',
#  'звук',
#  'рожден',
#  'Со',
#  'мной',
#  '.',
#  'Я',
#  'видел',
#  'других',
#  'Отчизну',
#  ',',
#  'дом',
#  ',',
#  'друзей',
#  ',',
#  'родных',
#  ',',
#  'А',
#  'находил',
#  'Не',
#  'милых',
#  'душ',
#  '–',
#  'могил',
#  '!',
#  'Тогда',
#  ',',
#  'пустых',
#  'тратя',
#  'слез',
#  ',',
#  'В',
#  'душе',
#  'клятву',
#  'произнес',
#  ':',
#  'Хотя',
#  'миг',
#  'когда-нибудь',
#  'Мою',
#  'пылающую',
#  'грудь',
#  'Прижать',
#  'тоской',
#  'груди',
#  ',',
#  'Хоть',
#  'незнакомой',
#  ',',
#  'родной',
#  '.',
#  'Увы',
#  ',',
#  'мечтанья',
#  'те',
#  'Погибли',
#  'полной',
#  'красоте',
#  ',',
#  'И',
#  ',',
#  'жил',
#  ',',
#  'земле',
#  'чужой',
#  'Умру',
#  'рабом',
#  'сиротой',
#  '.',
#  '5',
#  '«',
#  'Меня',
#  'могила',
#  'страшит',
#  ':',
#  'Там',
#  ',',
#  'говорят',
#  ',',
#  'страданье',
#  'спит',
#  'В',
#  'холодной',
#  ',',
#  'вечной',
#  'тишине',
#  ';',
#  'Но',
#  'жизнью',
#  'жаль',
#  'расстаться',
#  '.',
#  'Я',
#  'молод',
#  ',',
#  'молод…',
#  'Знал',
#  'Разгульной',
#  'юности',
#  'мечты',
#  '?',
#  'Или',
#  'знал',
#  ',',
#  'забыл',
#  ',',
#  'Как',
#  'ненавидел',
#  'любил',
#  ';',
#  'Как',
#  'сердце',
#  'билося',
#  'живей',
#  'При',
#  'виде',
#  'солнца',
#  'полей',
#  'С',
#  'высокой',
#  'башни',
#  'угловой',
#  ',',
#  'Где',
#  'воздух',
#  'свеж',
#  'порой',
#  'В',
#  'глубокой',
#  'скважине',
#  'стены',
#  ',',
#  'Дитя',
#  'неведомой',
#  'страны',
#  ',',
#  'Прижавшись',
#  ',',
#  'голубь',
#  'молодой',
#  'Сидит',
#  ',',
#  'испуганный',
#  'грозой',
#  '?',
#  'Пускай',
#  'прекрасный',
#  'свет',
#  'Тебе',
#  'постыл',
#  ':',
#  'слаб',
#  ',',
#  'сед',
#  ',',
#  'И',
#  'желаний',
#  'отвык',
#  '.',
#  'Что',
#  'нужда',
#  '?',
#  'Ты',
#  'жил',
#  ',',
#  'старик',
#  '!',
#  'Тебе',
#  'мире',
#  'забыть',
#  ',',
#  'Ты',
#  'жил',
#  ',',
#  '–',
#  'также',
#  'мог',
#  'жить',
#  '!',
#  '6',
#  '«',
#  'Ты',
#  'хочешь',
#  'знать',
#  ',',
#  'видел',
#  'На',
#  'воле',
#  '?',
#  '–',
#  'Пышные',
#  'поля',
#  ',',
#  'Холмы',
#  ',',
#  'покрытые',
#  'венцом',
#  'Дерев',
#  ',',
#  'разросшихся',
#  'кругом',
#  ',',
#  'Шумящих',
#  'свежею',
#  'толпой',
#  ',',
#  'Как',
#  'братья',
#  'пляске',
#  'круговой',
#  '.',
#  'Я',
#  'видел',
#  'груды',
#  'темных',
#  'скал',
#  ',',
#  'Когда',
#  'поток',
#  'разделял',
#  ',',
#  'И',
#  'думы',
#  'угадал',
#  ':',
#  'Мне',
#  'свыше',
#  'дано',
#  '!',
#  'Простерты',
#  'воздухе',
#  'давно',
#  'Объятья',
#  'каменные',
#  ',',
#  'И',
#  'жаждут',
#  'встречи',
#  'каждый',
#  'миг',
#  ';',
#  'Но',
#  'дни',
#  'бегут',
#  ',',
#  'бегут',
#  'года',
#  '—',
#  'Им',
#  'сойтися',
#  '!',
#  'Я',
#  'видел',
#  'горные',
#  'хребты',
#  ',',
#  'Причудливые',
#  'мечты',
#  ',',
#  'Когда',
#  'час',
#  'утренней',
#  'зари',
#  'Курилися',
#  ',',
#  'алтари',
#  ',',
#  'Их',
#  'выси',
#  'небе',
#  'голубом',
#  ',',
#  'И',
#  'облачко',
#  'облачком',
#  ',',
#  'Покинув',
#  'тайный',
#  'свой',
#  'ночлег',
#  ',',
#  'К',
#  'востоку',
#  'направляло',
#  'бег',
#  '—',
#  'Как',
#  'белый',
#  'караван',
#  'Залетных',
#  'птиц',
#  'дальних',
#  'стран',
#  '!',
#  'В',
#  'дали',
#  'видел',
#  'сквозь',
#  'туман',
#  ',',
#  'В',
#  'снегах',
#  ',',
#  'горящих',
#  'алмаз',
#  ',',
#  'Седой',
#  ',',
#  'незыблемый',
#  'Кавказ',
#  ';',
#  'И',
#  'сердцу',
#  'моему',
#  'Легко',
#  ',',
#  'знаю',
#  'почему',
#  '.',
#  'Мне',
#  'тайный',
#  'голос',
#  'говорил',
#  ',',
#  'Что',
#  'некогда',
#  'жил',
#  ',',
#  'И',
#  'стало',
#  'памяти',
#  'моей',
#  'Прошедшее',
#  'ясней',
#  ',',
#  'ясней',
#  '.',
#  '7',
#  '«',
#  'И',
#  'вспомнил',
#  'отцовский',
#  'дом',
#  ',',
#  'Ущелье',
#  'наше',
#  ',',
#  'кругом',
#  'В',
#  'тени',
#  'рассыпанный',
#  'аул',
#  ';',
#  'Мне',
#  'слышался',
#  'вечерний',
#  'гул',
#  'Домой',
#  'бегущих',
#  'табунов',
#  'И',
#  'дальний',
#  'лай',
#  'знакомых',
#  'псов',
#  '.',
#  'Я',
#  'помнил',
#  'смуглых',
#  'стариков',
#  ',',
#  'При',
#  'свете',
#  'лунных',
#  'вечеров',
#  'Против',
#  'отцовского',
#  'крыльца',
#  'Сидевших',
#  'важностью',
#  'лица',
#  ';',
#  'И',
#  'блеск',
#  'оправленных',
#  'ножон',
#  'Кинжалов',
#  'длинных…',
#  'сон',
#  'Всё',
#  'это',
#  'смутной',
#  'чередой',
#  'Вдруг',
#  'пробегало',
#  'предо',
#  'мной',
#  '.',
#  'А',
#  'отец',
#  '?',
#  'живой',
#  'В',
#  'своей',
#  'одежде',
#  'боевой',
#  'Являлся',
#  ',',
#  'помнил',
#  'Кольчуги',
#  'звон',
#  ',',
#  'блеск',
#  'ружья',
#  ',',
#  'И',
#  'гордый',
#  'непреклонный',
#  'взор',
#  ',',
#  'И',
#  'молодых',
#  'моих',
#  'сестер…',
#  'Лучи',
#  'сладостных',
#  'очей',
#  'И',
#  'звук',
#  'песен',
#  'речей',
#  'Над',
#  'колыбелию',
#  'моей…',
#  'В',
#  'ущельи',
#  'бежал',
#  'поток',
#  ',',
#  'Он',
#  'шумен',
#  ',',
#  'глубок',
#  ';',
#  'К',
#  'нему',
#  ',',
#  'золотой',
#  'песок',
#  ',',
#  'Играть',
#  'полдень',
#  'уходил',
#  'И',
#  'взором',
#  'ласточек',
#  'следил',
#  ',',
#  'Когда',
#  ',',
#  'дождем',
#  ',',
#  'Волны',
#  'касалися',
#  'крылом',
#  '.',
#  'И',
#  'вспомнил',
#  'наш',
#  'мирный',
#  'дом',
#  'И',
#  'пред',
#  'вечерним',
#  'очагом',
#  'Рассказы',
#  'долгие',
#  ',',
#  'Как',
#  ...]

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_4)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['1',
#  'немн',
#  'лет',
#  'том',
#  'назад',
#  ',',
#  'там',
#  ',',
#  'где',
#  'слив',
#  'шум',
#  'обня',
#  ',',
#  'будт',
#  'две',
#  'сестр',
#  ',',
#  'стру',
#  'арагв',
#  'и',
#  'кур',
#  ',',
#  'был',
#  'монастыр',
#  '.',
#  'из-з',
#  'гор',
#  'и',
#  'нынч',
#  'вид',
#  'пешеход',
#  'столб',
#  'обрушен',
#  'ворот',
#  ',',
#  'и',
#  'башн',
#  ',',
#  'и',
#  'церковн',
#  'свод',
#  ';',
#  'но',
#  'не',
#  'кур',
#  'уж',
#  'под',
#  'ним',
#  'кадильниц',
#  'благовон',
#  'дым',
#  ',',
#  'не',
#  'слышн',
#  'пен',
#  'в',
#  'поздн',
#  'час',
#  'моля',
#  'инок',
#  'за',
#  'нас',
#  '.',
#  'тепер',
#  'один',
#  'старик',
#  'сед',
#  ',',
#  'развалин',
#  'страж',
#  'полужив',
#  ',',
#  'людьм',
#  'и',
#  'смерт',
#  'заб',
#  ',',
#  'смета',
#  'пыл',
#  'с',
#  'могильн',
#  'плит',
#  ',',
#  'котор',
#  'надп',
#  'говор',
#  'о',
#  'слав',
#  'прошл',
#  '–',
#  'и',
#  'о',
#  'том',
#  ',',
#  'как',
#  'удруч',
#  'сво',
#  'венц',
#  ',',
#  'такой-т',
#  'цар',
#  ',',
#  'в',
#  'такой-т',
#  'год',
#  ',',
#  'вруча',
#  'росс',
#  'сво',
#  'народ',
#  '.',
#  'и',
#  'бож',
#  'благода',
#  'сошл',
#  'на',
#  'груз',
#  '!',
#  '–',
#  'он',
#  'цвел',
#  'с',
#  'тех',
#  'пор',
#  'в',
#  'тен',
#  'сво',
#  'сад',
#  ',',
#  'не',
#  'опас',
#  'враг',
#  ',',
#  'за',
#  'гран',
#  'дружеск',
#  'штык',
#  '.',
#  '2',
#  'однажд',
#  'русск',
#  'генера',
#  'из',
#  'гор',
#  'к',
#  'тифлис',
#  'проезжа',
#  ';',
#  'ребенк',
#  'плен',
#  'он',
#  'вез',
#  '.',
#  'тот',
#  'занемог',
#  ',',
#  'не',
#  'перенес',
#  'труд',
#  'далек',
#  'пут',
#  '.',
#  'он',
#  'был',
#  ',',
#  'каза',
#  ',',
#  'лет',
#  'шест',
#  ';',
#  'как',
#  'серн',
#  'гор',
#  ',',
#  'пугл',
#  'и',
#  'дик',
#  'и',
#  'слаб',
#  'и',
#  'гибок',
#  ',',
#  'как',
#  'тростник',
#  '.',
#  'но',
#  'в',
#  'нем',
#  'мучительн',
#  'недуг',
#  'разв',
#  'тогд',
#  'могуч',
#  'дух',
#  'ег',
#  'отц',
#  '.',
#  'без',
#  'жалоб',
#  'он',
#  'том',
#  '–',
#  'даж',
#  'слаб',
#  'стон',
#  'из',
#  'детск',
#  'губ',
#  'не',
#  'вылета',
#  ',',
#  'он',
#  'знак',
#  'пищ',
#  'отверга',
#  ',',
#  'и',
#  'тих',
#  ',',
#  'горд',
#  'умира',
#  '.',
#  'из',
#  'жалост',
#  'один',
#  'мон',
#  'больн',
#  'призрел',
#  ',',
#  'и',
#  'в',
#  'стен',
#  'хранительн',
#  'оста',
#  'он',
#  'искусств',
#  'дружеск',
#  'спас',
#  '.',
#  'но',
#  ',',
#  'чужд',
#  'ребяческ',
#  'утех',
#  ',',
#  'снача',
#  'бега',
#  'он',
#  'от',
#  'всех',
#  ',',
#  'брод',
#  'безмолв',
#  ',',
#  'одинок',
#  ',',
#  'смотрел',
#  'вздых',
#  'на',
#  'восток',
#  ',',
#  'том',
#  'неясн',
#  'тоск',
#  'по',
#  'сторон',
#  'сво',
#  'родн',
#  '.',
#  'но',
#  'посл',
#  'к',
#  'плен',
#  'он',
#  'привык',
#  ',',
#  'стал',
#  'понима',
#  'чуж',
#  'язык',
#  ',',
#  'был',
#  'окрещ',
#  'свят',
#  'отц',
#  ',',
#  'и',
#  ',',
#  'с',
#  'шумн',
#  'свет',
#  'незнак',
#  ',',
#  'уж',
#  'хотел',
#  'во',
#  'цвет',
#  'лет',
#  'изреч',
#  'монашеск',
#  'обет',
#  ',',
#  'как',
#  'вдруг',
#  'однажд',
#  'он',
#  'исчез',
#  'осен',
#  'ноч',
#  '.',
#  'темн',
#  'лес',
#  'тянул',
#  'по',
#  'гор',
#  'круг',
#  '.',
#  'три',
#  'дня',
#  'все',
#  'поиск',
#  'по',
#  'нем',
#  'напрасн',
#  'был',
#  ',',
#  'но',
#  'пот',
#  'ег',
#  'в',
#  'степ',
#  'без',
#  'чувств',
#  'нашл',
#  'и',
#  'внов',
#  'в',
#  'обител',
#  'принесл',
#  ';',
#  'он',
#  'страшн',
#  'блед',
#  'был',
#  'и',
#  'худ',
#  'и',
#  'слаб',
#  ',',
#  'как',
#  'будт',
#  'долг',
#  'труд',
#  ',',
#  'болезн',
#  'ил',
#  'голод',
#  'испыта',
#  '.',
#  'он',
#  'на',
#  'допрос',
#  'не',
#  'отвеча',
#  ',',
#  'и',
#  'с',
#  'кажд',
#  'днем',
#  'приметн',
#  'вял',
#  ';',
#  'и',
#  'близок',
#  'стал',
#  'ег',
#  'конец',
#  '.',
#  'тогд',
#  'пришел',
#  'к',
#  'нем',
#  'чернец',
#  'с',
#  'увещеван',
#  'и',
#  'мольб',
#  ';',
#  'и',
#  ',',
#  'горд',
#  'выслуша',
#  ',',
#  'больн',
#  'привста',
#  ',',
#  'собра',
#  'остаток',
#  'сил',
#  ',',
#  'и',
#  'долг',
#  'так',
#  'он',
#  'говор',
#  ':',
#  '3',
#  '«',
#  'ты',
#  'слуша',
#  'исповед',
#  'мо',
#  'сюд',
#  'пришел',
#  ',',
#  'благодар',
#  '.',
#  'все',
#  'лучш',
#  'перед',
#  'кем-нибуд',
#  'слов',
#  'облегч',
#  'мне',
#  'груд',
#  ';',
#  'но',
#  'люд',
#  'я',
#  'не',
#  'дела',
#  'зла',
#  ',',
#  'и',
#  'пот',
#  'мо',
#  'дел',
#  'не',
#  'мног',
#  'польз',
#  'вам',
#  'узна',
#  ';',
#  'а',
#  'душ',
#  'можн',
#  'л',
#  'рассказа',
#  '?',
#  'я',
#  'мал',
#  'жил',
#  ',',
#  'и',
#  'жил',
#  'в',
#  'плен',
#  '.',
#  'так',
#  'две',
#  'жизн',
#  'за',
#  'одн',
#  ',',
#  'но',
#  'тольк',
#  'полн',
#  'тревог',
#  ',',
#  'я',
#  'променя',
#  'бы',
#  ',',
#  'есл',
#  'б',
#  'мог',
#  '.',
#  'я',
#  'знал',
#  'одн',
#  'лиш',
#  'дум',
#  'власт',
#  ',',
#  'одн',
#  '–',
#  'но',
#  'пламен',
#  'страст',
#  ':',
#  'он',
#  ',',
#  'как',
#  'черв',
#  ',',
#  'во',
#  'мне',
#  'жил',
#  ',',
#  'изгрызл',
#  'душ',
#  'и',
#  'сожгл',
#  '.',
#  'он',
#  'мечт',
#  'мо',
#  'звал',
#  'от',
#  'кел',
#  'душн',
#  'и',
#  'молитв',
#  'в',
#  'тот',
#  'чудн',
#  'мир',
#  'тревог',
#  'и',
#  'битв',
#  ',',
#  'где',
#  'в',
#  'туч',
#  'прячут',
#  'скал',
#  ',',
#  'где',
#  'люд',
#  'вольн',
#  ',',
#  'как',
#  'орл',
#  '.',
#  'я',
#  'эт',
#  'страст',
#  'во',
#  'тьме',
#  'ночн',
#  'вскорм',
#  'слез',
#  'и',
#  'тоск',
#  ';',
#  'е',
#  'пред',
#  'неб',
#  'и',
#  'земл',
#  'я',
#  'нын',
#  'громк',
#  'призна',
#  'и',
#  'о',
#  'прощен',
#  'не',
#  'мол',
#  '.',
#  '4',
#  '«',
#  'старик',
#  '!',
#  'я',
#  'слыша',
#  'мног',
#  'раз',
#  ',',
#  'что',
#  'ты',
#  'мен',
#  'от',
#  'смерт',
#  'спас',
#  '—',
#  'зач',
#  '?',
#  '…',
#  'угрюм',
#  'и',
#  'одинок',
#  ',',
#  'гроз',
#  'оторва',
#  'листок',
#  ',',
#  'я',
#  'вырос',
#  'в',
#  'сумрачн',
#  'стен',
#  ',',
#  'душ',
#  'дит',
#  ',',
#  'судьб',
#  'мон',
#  '.',
#  'я',
#  'ник',
#  'не',
#  'мог',
#  'сказа',
#  'священ',
#  'слов',
#  '–',
#  '«',
#  'отец',
#  '»',
#  'и',
#  '«',
#  'мат',
#  '»',
#  '.',
#  'конечн',
#  ',',
#  'ты',
#  'хотел',
#  ',',
#  'старик',
#  ',',
#  'чтоб',
#  'я',
#  'в',
#  'обител',
#  'отвык',
#  'от',
#  'эт',
#  'сладостн',
#  'им',
#  '.',
#  'напрасн',
#  ':',
#  'звук',
#  'их',
#  'был',
#  'рожд',
#  'со',
#  'мно',
#  '.',
#  'я',
#  'видел',
#  'у',
#  'друг',
#  'отчизн',
#  ',',
#  'дом',
#  ',',
#  'друз',
#  ',',
#  'родн',
#  ',',
#  'а',
#  'у',
#  'себ',
#  'не',
#  'наход',
#  'не',
#  'тольк',
#  'мил',
#  'душ',
#  '–',
#  'мог',
#  '!',
#  'тогд',
#  ',',
#  'пуст',
#  'не',
#  'трат',
#  'слез',
#  ',',
#  'в',
#  'душ',
#  'я',
#  'клятв',
#  'произнес',
#  ':',
#  'хот',
#  'на',
#  'миг',
#  'когда-нибуд',
#  'мо',
#  'пыла',
#  'груд',
#  'прижа',
#  'с',
#  'тоск',
#  'к',
#  'груд',
#  'друг',
#  ',',
#  'хот',
#  'незнаком',
#  ',',
#  'но',
#  'родн',
#  '.',
#  'ув',
#  ',',
#  'тепер',
#  'мечтан',
#  'те',
#  'погибл',
#  'в',
#  'полн',
#  'красот',
#  ',',
#  'и',
#  'я',
#  ',',
#  'как',
#  'жил',
#  ',',
#  'в',
#  'земл',
#  'чуж',
#  'умр',
#  'раб',
#  'и',
#  'сирот',
#  '.',
#  '5',
#  '«',
#  'мен',
#  'мог',
#  'не',
#  'страш',
#  ':',
#  'там',
#  ',',
#  'говор',
#  ',',
#  'страдан',
#  'спит',
#  'в',
#  'холодн',
#  ',',
#  'вечн',
#  'тишин',
#  ';',
#  'но',
#  'с',
#  'жизн',
#  'жал',
#  'расста',
#  'мне',
#  '.',
#  'я',
#  'молод',
#  ',',
#  'молод…',
#  'знал',
#  'ли',
#  'ты',
#  'разгульн',
#  'юност',
#  'мечт',
#  '?',
#  'ил',
#  'не',
#  'знал',
#  ',',
#  'ил',
#  'заб',
#  ',',
#  'как',
#  'ненавидел',
#  'и',
#  'люб',
#  ';',
#  'как',
#  'сердц',
#  'бил',
#  'жив',
#  'при',
#  'вид',
#  'солнц',
#  'и',
#  'пол',
#  'с',
#  'высок',
#  'башн',
#  'углов',
#  ',',
#  'где',
#  'воздух',
#  'свеж',
#  'и',
#  'где',
#  'пор',
#  'в',
#  'глубок',
#  'скважин',
#  'стен',
#  ',',
#  'дит',
#  'неведом',
#  'стран',
#  ',',
#  'прижа',
#  ',',
#  'голуб',
#  'молод',
#  'сид',
#  ',',
#  'испуга',
#  'гроз',
#  '?',
#  'пуска',
#  'тепер',
#  'прекрасн',
#  'свет',
#  'теб',
#  'пост',
#  ':',
#  'ты',
#  'слаб',
#  ',',
#  'ты',
#  'сед',
#  ',',
#  'и',
#  'от',
#  'желан',
#  'ты',
#  'отвык',
#  '.',
#  'что',
#  'за',
#  'нужд',
#  '?',
#  'ты',
#  'жил',
#  ',',
#  'старик',
#  '!',
#  'теб',
#  'ест',
#  'в',
#  'мир',
#  'что',
#  'заб',
#  ',',
#  'ты',
#  'жил',
#  ',',
#  '–',
#  'я',
#  'такж',
#  'мог',
#  'бы',
#  'жит',
#  '!',
#  '6',
#  '«',
#  'ты',
#  'хочеш',
#  'знат',
#  ',',
#  'что',
#  'видел',
#  'я',
#  'на',
#  'вол',
#  '?',
#  '–',
#  'пышн',
#  'пол',
#  ',',
#  'холм',
#  ',',
#  'покрыт',
#  'венц',
#  'дер',
#  ',',
#  'разросш',
#  'круг',
#  ',',
#  'шумя',
#  'свеж',
#  'толп',
#  ',',
#  'как',
#  'брат',
#  'в',
#  'пляск',
#  'кругов',
#  '.',
#  'я',
#  'видел',
#  'груд',
#  'темн',
#  'скал',
#  ',',
#  'когд',
#  'поток',
#  'их',
#  'разделя',
#  ',',
#  'и',
#  'дум',
#  'их',
#  'я',
#  'угада',
#  ':',
#  'мне',
#  'был',
#  'свыш',
#  'то',
#  'дан',
#  '!',
#  'простерт',
#  'в',
#  'воздух',
#  'давн',
#  'объят',
#  'камен',
#  'их',
#  ',',
#  'и',
#  'жаждут',
#  'встреч',
#  'кажд',
#  'миг',
#  ';',
#  'но',
#  'дни',
#  'бегут',
#  ',',
#  'бегут',
#  'год',
#  '—',
#  'им',
#  'не',
#  'сойт',
#  'никогд',
#  '!',
#  'я',
#  'видел',
#  'горн',
#  'хребт',
#  ',',
#  'причудлив',
#  'как',
#  'мечт',
#  ',',
#  'когд',
#  'в',
#  'час',
#  'утрен',
#  'зар',
#  'кур',
#  ',',
#  'как',
#  'алтар',
#  ',',
#  'их',
#  'выс',
#  'в',
#  'неб',
#  'голуб',
#  ',',
#  'и',
#  'облачк',
#  'за',
#  'облачк',
#  ',',
#  'покинув',
#  'тайн',
#  'сво',
#  'ночлег',
#  ',',
#  'к',
#  'восток',
#  'направля',
#  'бег',
#  '—',
#  'как',
#  'будт',
#  'бел',
#  'карава',
#  'залетн',
#  'птиц',
#  'из',
#  'дальн',
#  'стран',
#  '!',
#  'в',
#  'дал',
#  'я',
#  'видел',
#  'сквоз',
#  'тума',
#  ',',
#  'в',
#  'снег',
#  ',',
#  'горя',
#  'как',
#  ...]

# %%
len(words)
# Out:
# 4136

# %%
len(tokenized_filtered)
# Out:
# 3393

# %% [markdown]
# Warm_snow

# %%
with open("6. Штосс.txt", encoding='utf-8') as file:
    text_5=file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\user\Desktop\python\Предобработка\1.ipynb Cell 53 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/python/%D0%9F%D1%80%D0%B5%D0%B4%D0%BE%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0/1.ipynb#Y103sZmlsZQ%3D%3D?line=0'>1</a> with open("6. Штосс", encoding='utf-8') as file:
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/python/%D0%9F%D1%80%D0%B5%D0%B4%D0%BE%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0/1.ipynb#Y103sZmlsZQ%3D%3D?line=1'>2</a>     text_5=file.read()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '6. Штосс'

# %%
words=word_tokenize(text_5)
words
# Out:
# ['Юрий',
#  'Бондарев',
#  'ГОРЯЧИЙ',
#  'СНЕГ',
#  'Глава',
#  'первая',
#  'Кузнецову',
#  'не',
#  'спалось',
#  '.',
#  'Все',
#  'сильнее',
#  'стучало',
#  ',',
#  'гремело',
#  'по',
#  'крыше',
#  'вагона',
#  ',',
#  'вьюжно',
#  'ударяли',
#  'нахлесты',
#  'ветра',
#  ',',
#  'все',
#  'плотнее',
#  'забивало',
#  'снегом',
#  'едва',
#  'угадываемое',
#  'оконце',
#  'над',
#  'нарами',
#  '.',
#  'Паровоз',
#  'с',
#  'диким',
#  ',',
#  'раздирающим',
#  'метель',
#  'ревом',
#  'гнал',
#  'эшелон',
#  'в',
#  'ночных',
#  'полях',
#  ',',
#  'в',
#  'белой',
#  ',',
#  'несущейся',
#  'со',
#  'всех',
#  'сторон',
#  'мути',
#  ',',
#  'и',
#  'в',
#  'гремучей',
#  'темноте',
#  'вагона',
#  ',',
#  'сквозь',
#  'мерзлый',
#  'визг',
#  'колес',
#  ',',
#  'сквозь',
#  'тревожные',
#  'всхлипы',
#  ',',
#  'бормотание',
#  'во',
#  'сне',
#  'солдат',
#  'был',
#  'слышен',
#  'этот',
#  'непрерывно',
#  'предупреждающий',
#  'кого-то',
#  'рев',
#  'паровоза',
#  ',',
#  'и',
#  'чудилось',
#  'Кузнецову',
#  ',',
#  'что',
#  'там',
#  ',',
#  'впереди',
#  ',',
#  'за',
#  'метелью',
#  ',',
#  'уже',
#  'мутно',
#  'проступало',
#  'зарево',
#  'горящего',
#  'города',
#  '.',
#  'После',
#  'стоянки',
#  'в',
#  'Саратове',
#  'всем',
#  'стало',
#  'ясно',
#  ',',
#  'что',
#  'дивизию',
#  'срочно',
#  'перебрасывают',
#  'под',
#  'Сталинград',
#  ',',
#  'а',
#  'не',
#  'на',
#  'Западный',
#  'фронт',
#  ',',
#  'как',
#  'предполагалось',
#  'вначале',
#  ';',
#  'и',
#  'теперь',
#  'Кузнецов',
#  'знал',
#  ',',
#  'что',
#  'ехать',
#  'оставалось',
#  'несколько',
#  'часов',
#  '.',
#  'И',
#  ',',
#  'натягивая',
#  'на',
#  'щеку',
#  'жесткий',
#  ',',
#  'неприятно',
#  'влажный',
#  'воротник',
#  'шинели',
#  ',',
#  'он',
#  'никак',
#  'не',
#  'мог',
#  'согреться',
#  ',',
#  'набрать',
#  'тепло',
#  ',',
#  'чтобы',
#  'уснуть',
#  ':',
#  'пронзительно',
#  'дуло',
#  'в',
#  'невидимые',
#  'щели',
#  'заметенного',
#  'оконца',
#  ',',
#  'ледяные',
#  'сквозняки',
#  'гуляли',
#  'по',
#  'нарам',
#  '.',
#  '«',
#  'Значит',
#  ',',
#  'я',
#  'долго',
#  'не',
#  'увижу',
#  'мать',
#  ',',
#  '—',
#  'съеживаясь',
#  'от',
#  'холода',
#  ',',
#  'подумал',
#  'Кузнецов',
#  ',',
#  '—',
#  'нас',
#  'провезли',
#  'мимо…',
#  '»',
#  '.',
#  'То',
#  ',',
#  'что',
#  'было',
#  'прошлой',
#  'жизнью',
#  ',',
#  '—',
#  'летние',
#  'месяцы',
#  'в',
#  'училище',
#  'в',
#  'жарком',
#  ',',
#  'пыльном',
#  'Актюбинске',
#  ',',
#  'с',
#  'раскаленными',
#  'ветрами',
#  'из',
#  'степи',
#  ',',
#  'с',
#  'задыхающимися',
#  'в',
#  'закатной',
#  'тишине',
#  'криками',
#  'ишаков',
#  'на',
#  'окраинах',
#  ',',
#  'такими',
#  'ежевечерне',
#  'точными',
#  'по',
#  'времени',
#  ',',
#  'что',
#  'командиры',
#  'взводов',
#  'на',
#  'тактических',
#  'занятиях',
#  ',',
#  'изнывая',
#  'от',
#  'жажды',
#  ',',
#  'не',
#  'без',
#  'облегчения',
#  'сверяли',
#  'по',
#  'ним',
#  'часы',
#  ',',
#  'марши',
#  'в',
#  'одуряющем',
#  'зное',
#  ',',
#  'пропотевшие',
#  'и',
#  'выжженные',
#  'на',
#  'солнце',
#  'добела',
#  'гимнастерки',
#  ',',
#  'скрип',
#  'песка',
#  'на',
#  'зубах',
#  ';',
#  'воскресное',
#  'патрулирование',
#  'города',
#  ',',
#  'в',
#  'городском',
#  'саду',
#  ',',
#  'где',
#  'по',
#  'вечерам',
#  'мирно',
#  'играл',
#  'на',
#  'танцплощадке',
#  'военный',
#  'духовой',
#  'оркестр',
#  ';',
#  'затем',
#  'выпуск',
#  'в',
#  'училище',
#  ',',
#  'погрузка',
#  'по',
#  'тревоге',
#  'осенней',
#  'ночью',
#  'в',
#  'вагоны',
#  ',',
#  'угрюмый',
#  ',',
#  'в',
#  'диких',
#  'снегах',
#  'лес',
#  ',',
#  'сугробы',
#  ',',
#  'землянки',
#  'формировочного',
#  'лагеря',
#  'под',
#  'Тамбовом',
#  ',',
#  'потом',
#  'опять',
#  'по',
#  'тревоге',
#  'на',
#  'морозно',
#  'розовеющем',
#  'декабрьском',
#  'рассвете',
#  'спешная',
#  'погрузка',
#  'в',
#  'эшелон',
#  'и',
#  ',',
#  'наконец',
#  ',',
#  'отъезд',
#  '—',
#  'вся',
#  'эта',
#  'зыбкая',
#  ',',
#  'временная',
#  ',',
#  'кем-то',
#  'управляемая',
#  'жизнь',
#  'потускнела',
#  'сейчас',
#  ',',
#  'оставалась',
#  'далеко',
#  'позади',
#  ',',
#  'в',
#  'прошлом',
#  '.',
#  'И',
#  'не',
#  'было',
#  'надежды',
#  'увидеть',
#  'мать',
#  ',',
#  'а',
#  'он',
#  'совсем',
#  'недавно',
#  'почти',
#  'не',
#  'сомневался',
#  ',',
#  'что',
#  'их',
#  'повезут',
#  'на',
#  'запад',
#  'через',
#  'Москву',
#  '.',
#  '«',
#  'Я',
#  'напишу',
#  'ей',
#  ',',
#  '—',
#  'с',
#  'внезапно',
#  'обострившимся',
#  'чувством',
#  'одиночества',
#  'подумал',
#  'Кузнецов',
#  ',',
#  '—',
#  'и',
#  'все',
#  'объясню',
#  '.',
#  'Ведь',
#  'мы',
#  'не',
#  'виделись',
#  'девять',
#  'месяцев…',
#  '»',
#  '.',
#  'А',
#  'весь',
#  'вагон',
#  'спал',
#  'под',
#  'скрежет',
#  ',',
#  'визг',
#  ',',
#  'под',
#  'чугунный',
#  'гул',
#  'разбежавшихся',
#  'колес',
#  ',',
#  'стены',
#  'туго',
#  'качались',
#  ',',
#  'верхние',
#  'нары',
#  'мотало',
#  'бешеной',
#  'скоростью',
#  'эшелона',
#  ',',
#  'и',
#  'Кузнецов',
#  ',',
#  'вздрагивая',
#  ',',
#  'окончательно',
#  'прозябнув',
#  'на',
#  'сквозняках',
#  'возле',
#  'оконца',
#  ',',
#  'отогнул',
#  'воротник',
#  ',',
#  'с',
#  'завистью',
#  'посмотрел',
#  'на',
#  'спящего',
#  'рядом',
#  'командира',
#  'второго',
#  'взвода',
#  'лейтенанта',
#  'Давлатяна',
#  '—',
#  'в',
#  'темноте',
#  'нар',
#  'лица',
#  'его',
#  'не',
#  'было',
#  'видно',
#  '.',
#  '«',
#  'Нет',
#  ',',
#  'здесь',
#  ',',
#  'возле',
#  'окна',
#  ',',
#  'я',
#  'не',
#  'усну',
#  ',',
#  'замерзну',
#  'до',
#  'передовой',
#  '»',
#  ',',
#  '—',
#  'с',
#  'досадой',
#  'на',
#  'себя',
#  'подумал',
#  'Кузнецов',
#  'и',
#  'задвигался',
#  ',',
#  'пошевелился',
#  ',',
#  'слыша',
#  ',',
#  'как',
#  'хрустит',
#  'иней',
#  'на',
#  'досках',
#  'вагона',
#  '.',
#  'Он',
#  'высвободился',
#  'из',
#  'холодной',
#  ',',
#  'колючей',
#  'тесноты',
#  'своего',
#  'места',
#  ',',
#  'спрыгнул',
#  'с',
#  'нар',
#  ',',
#  'чувствуя',
#  ',',
#  'что',
#  'надо',
#  'обогреться',
#  'у',
#  'печки',
#  ':',
#  'спина',
#  'вконец',
#  'окоченела',
#  '.',
#  'В',
#  'железной',
#  'печке',
#  'сбоку',
#  'закрытой',
#  'двери',
#  ',',
#  'мерцающей',
#  'толстым',
#  'инеем',
#  ',',
#  'давно',
#  'погас',
#  'огонь',
#  ',',
#  'только',
#  'неподвижным',
#  'зрачком',
#  'краснело',
#  'поддувало',
#  '.',
#  'Но',
#  'здесь',
#  ',',
#  'внизу',
#  ',',
#  'казалось',
#  ',',
#  'было',
#  'немного',
#  'теплее',
#  '.',
#  'В',
#  'вагонном',
#  'сумраке',
#  'этот',
#  'багровый',
#  'отсвет',
#  'угля',
#  'слабо',
#  'озарял',
#  'разнообразно',
#  'торчащие',
#  'в',
#  'проходе',
#  'новые',
#  'валенки',
#  ',',
#  'котелки',
#  ',',
#  'вещмешки',
#  'под',
#  'головами',
#  '.',
#  'Дневальный',
#  'Чибисов',
#  'неудобно',
#  'спал',
#  'на',
#  'нижних',
#  'нарах',
#  ',',
#  'прямо',
#  'на',
#  'ногах',
#  'солдат',
#  ';',
#  'голова',
#  'его',
#  'до',
#  'верха',
#  'шапки',
#  'была',
#  'упрятана',
#  'в',
#  'воротник',
#  ',',
#  'руки',
#  'засунуты',
#  'в',
#  'рукава',
#  '.',
#  '—',
#  'Чибисов',
#  '!',
#  '—',
#  'позвал',
#  'Кузнецов',
#  'и',
#  'открыл',
#  'дверцу',
#  'печки',
#  ',',
#  'повеявшей',
#  'изнутри',
#  'еле',
#  'уловимым',
#  'теплом',
#  '.',
#  '—',
#  'Все',
#  'погасло',
#  ',',
#  'Чибисов',
#  '!',
#  'Ответа',
#  'не',
#  'было',
#  '.',
#  '—',
#  'Дневальный',
#  ',',
#  'слышите',
#  '?',
#  'Чибисов',
#  'испуганно',
#  'вскинулся',
#  ',',
#  'заспанный',
#  ',',
#  'помятый',
#  ',',
#  'шапка-ушанка',
#  'низко',
#  'надвинута',
#  ',',
#  'стянута',
#  'тесемками',
#  'у',
#  'подбородка',
#  '.',
#  'Еще',
#  'не',
#  'очнувшись',
#  'ото',
#  'сна',
#  ',',
#  'он',
#  'пытался',
#  'оттолкнуть',
#  'ушанку',
#  'со',
#  'лба',
#  ',',
#  'развязать',
#  'тесемки',
#  ',',
#  'непонимающе',
#  'и',
#  'робко',
#  'вскрикивая',
#  ':',
#  '—',
#  'Что',
#  'это',
#  'я',
#  '?',
#  'Никак',
#  ',',
#  'заснул',
#  '?',
#  'Ровно',
#  'оглушило',
#  'меня',
#  'беспамятством',
#  '.',
#  'Извиняюсь',
#  'я',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '!',
#  'Ух',
#  ',',
#  'до',
#  'косточек',
#  'пробрало',
#  'меня',
#  'в',
#  'дремоте-то',
#  '!',
#  '..',
#  '—',
#  'Заснули',
#  'и',
#  'весь',
#  'вагон',
#  'выстудили',
#  ',',
#  '—',
#  'сказал',
#  'с',
#  'упреком',
#  'Кузнецов',
#  '.',
#  '—',
#  'Да',
#  'не',
#  'хотел',
#  'я',
#  ',',
#  'товарищ',
#  'лейтенант',
#  ',',
#  'невзначай',
#  ',',
#  'без',
#  'умыслу',
#  ',',
#  '—',
#  'забормотал',
#  'Чибисов',
#  '.',
#  '—',
#  'Повалило',
#  'меня…',
#  'Затем',
#  ',',
#  'не',
#  'дожидаясь',
#  'приказаний',
#  'Кузнецова',
#  ',',
#  'с',
#  'излишней',
#  'бодростью',
#  'засуетился',
#  ',',
#  'схватил',
#  'с',
#  'пола',
#  'доску',
#  ',',
#  'разломал',
#  'ее',
#  'о',
#  'колено',
#  'и',
#  'стал',
#  'заталкивать',
#  'обломки',
#  'в',
#  'печку',
#  '.',
#  'При',
#  'этом',
#  'бестолково',
#  ',',
#  'будто',
#  'бока',
#  'чесались',
#  ',',
#  'двигал',
#  'локтями',
#  'и',
#  'плечами',
#  ',',
#  'часто',
#  'нагибаясь',
#  ',',
#  'деловито',
#  'заглядывал',
#  'в',
#  'поддувало',
#  ',',
#  'где',
#  'ленивыми',
#  'отблесками',
#  'заползал',
#  'огонь',
#  ';',
#  'ожившее',
#  ',',
#  'запачканное',
#  'сажей',
#  'лицо',
#  'Чибисова',
#  'выражало',
#  'заговорщицкую',
#  'подобострастность',
#  '.',
#  '—',
#  'Я',
#  'теперича',
#  ',',
#  'товарищ',
#  'лейтенант',
#  ',',
#  'тепло',
#  'нагоню',
#  '!',
#  'Накалим',
#  ',',
#  'ровно',
#  'в',
#  'баньке',
#  'будет',
#  '.',
#  'Иззябся',
#  'я',
#  'сам',
#  'за',
#  'войну-то',
#  '!',
#  'Ох',
#  'как',
#  'иззябся',
#  ',',
#  'кажную',
#  'косточку',
#  'ломит',
#  '—',
#  'слов',
#  'нет',
#  '!',
#  '..',
#  'Кузнецов',
#  'сел',
#  'против',
#  'раскрытой',
#  'дверцы',
#  'печки',
#  '.',
#  'Ему',
#  'неприятна',
#  'была',
#  'преувеличенно',
#  'нарочитая',
#  'суетливость',
#  'дневального',
#  ',',
#  'этот',
#  'явный',
#  'намек',
#  'на',
#  'свое',
#  'прошлое',
#  '.',
#  'Чибисов',
#  'был',
#  'из',
#  'его',
#  'взвода',
#  '.',
#  'И',
#  'то',
#  ',',
#  'что',
#  'он',
#  ',',
#  'со',
#  'своим',
#  'неумеренным',
#  'старанием',
#  ',',
#  'всегда',
#  'безотказный',
#  ',',
#  'прожил',
#  'несколько',
#  'месяцев',
#  'в',
#  'немецком',
#  'плену',
#  ',',
#  'а',
#  'с',
#  'первого',
#  'дня',
#  'появления',
#  'во',
#  'взводе',
#  'постоянно',
#  'готов',
#  'был',
#  'услужить',
#  'каждому',
#  ',',
#  'вызывало',
#  'к',
#  'нему',
#  'настороженную',
#  'жалость',
#  '.',
#  'Чибисов',
#  'мягко',
#  ',',
#  'по-бабьи',
#  'опустился',
#  'на',
#  'нары',
#  ',',
#  'непроспанные',
#  'глаза',
#  'его',
#  'моргали',
#  '.',
#  '—',
#  'В',
#  'Сталинград',
#  ',',
#  'значит',
#  ',',
#  'едем',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '?',
#  'По',
#  'сводкам-то',
#  'какая',
#  'мясорубка',
#  'там',
#  '!',
#  'Не',
#  'боязно',
#  'вам',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '?',
#  'Ничего',
#  '?',
#  '—',
#  'Приедем',
#  '—',
#  'увидим',
#  ',',
#  'что',
#  'за',
#  'мясорубка',
#  ',',
#  '—',
#  'вяло',
#  'отозвался',
#  'Кузнецов',
#  ',',
#  'всматриваясь',
#  'в',
#  'огонь',
#  '.',
#  '—',
#  'А',
#  'вы',
#  'что',
#  ',',
#  'боитесь',
#  '?',
#  'Почему',
#  'спросили',
#  '?',
#  '—',
#  'Да',
#  ',',
#  'можно',
#  'сказать',
#  ',',
#  'того',
#  'страху',
#  'нету',
#  ',',
#  'что',
#  ...]

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Дима
# [nltk_data]     Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['Юрий',
#  'Бондарев',
#  'ГОРЯЧИЙ',
#  'СНЕГ',
#  'Глава',
#  'первая',
#  'Кузнецову',
#  'спалось',
#  '.',
#  'Все',
#  'сильнее',
#  'стучало',
#  ',',
#  'гремело',
#  'крыше',
#  'вагона',
#  ',',
#  'вьюжно',
#  'ударяли',
#  'нахлесты',
#  'ветра',
#  ',',
#  'плотнее',
#  'забивало',
#  'снегом',
#  'едва',
#  'угадываемое',
#  'оконце',
#  'нарами',
#  '.',
#  'Паровоз',
#  'диким',
#  ',',
#  'раздирающим',
#  'метель',
#  'ревом',
#  'гнал',
#  'эшелон',
#  'ночных',
#  'полях',
#  ',',
#  'белой',
#  ',',
#  'несущейся',
#  'сторон',
#  'мути',
#  ',',
#  'гремучей',
#  'темноте',
#  'вагона',
#  ',',
#  'сквозь',
#  'мерзлый',
#  'визг',
#  'колес',
#  ',',
#  'сквозь',
#  'тревожные',
#  'всхлипы',
#  ',',
#  'бормотание',
#  'сне',
#  'солдат',
#  'слышен',
#  'непрерывно',
#  'предупреждающий',
#  'кого-то',
#  'рев',
#  'паровоза',
#  ',',
#  'чудилось',
#  'Кузнецову',
#  ',',
#  ',',
#  'впереди',
#  ',',
#  'метелью',
#  ',',
#  'мутно',
#  'проступало',
#  'зарево',
#  'горящего',
#  'города',
#  '.',
#  'После',
#  'стоянки',
#  'Саратове',
#  'всем',
#  'стало',
#  'ясно',
#  ',',
#  'дивизию',
#  'срочно',
#  'перебрасывают',
#  'Сталинград',
#  ',',
#  'Западный',
#  'фронт',
#  ',',
#  'предполагалось',
#  'вначале',
#  ';',
#  'Кузнецов',
#  'знал',
#  ',',
#  'ехать',
#  'оставалось',
#  'несколько',
#  'часов',
#  '.',
#  'И',
#  ',',
#  'натягивая',
#  'щеку',
#  'жесткий',
#  ',',
#  'неприятно',
#  'влажный',
#  'воротник',
#  'шинели',
#  ',',
#  'никак',
#  'мог',
#  'согреться',
#  ',',
#  'набрать',
#  'тепло',
#  ',',
#  'уснуть',
#  ':',
#  'пронзительно',
#  'дуло',
#  'невидимые',
#  'щели',
#  'заметенного',
#  'оконца',
#  ',',
#  'ледяные',
#  'сквозняки',
#  'гуляли',
#  'нарам',
#  '.',
#  '«',
#  'Значит',
#  ',',
#  'долго',
#  'увижу',
#  'мать',
#  ',',
#  '—',
#  'съеживаясь',
#  'холода',
#  ',',
#  'подумал',
#  'Кузнецов',
#  ',',
#  '—',
#  'провезли',
#  'мимо…',
#  '»',
#  '.',
#  'То',
#  ',',
#  'прошлой',
#  'жизнью',
#  ',',
#  '—',
#  'летние',
#  'месяцы',
#  'училище',
#  'жарком',
#  ',',
#  'пыльном',
#  'Актюбинске',
#  ',',
#  'раскаленными',
#  'ветрами',
#  'степи',
#  ',',
#  'задыхающимися',
#  'закатной',
#  'тишине',
#  'криками',
#  'ишаков',
#  'окраинах',
#  ',',
#  'такими',
#  'ежевечерне',
#  'точными',
#  'времени',
#  ',',
#  'командиры',
#  'взводов',
#  'тактических',
#  'занятиях',
#  ',',
#  'изнывая',
#  'жажды',
#  ',',
#  'облегчения',
#  'сверяли',
#  'часы',
#  ',',
#  'марши',
#  'одуряющем',
#  'зное',
#  ',',
#  'пропотевшие',
#  'выжженные',
#  'солнце',
#  'добела',
#  'гимнастерки',
#  ',',
#  'скрип',
#  'песка',
#  'зубах',
#  ';',
#  'воскресное',
#  'патрулирование',
#  'города',
#  ',',
#  'городском',
#  'саду',
#  ',',
#  'вечерам',
#  'мирно',
#  'играл',
#  'танцплощадке',
#  'военный',
#  'духовой',
#  'оркестр',
#  ';',
#  'затем',
#  'выпуск',
#  'училище',
#  ',',
#  'погрузка',
#  'тревоге',
#  'осенней',
#  'ночью',
#  'вагоны',
#  ',',
#  'угрюмый',
#  ',',
#  'диких',
#  'снегах',
#  'лес',
#  ',',
#  'сугробы',
#  ',',
#  'землянки',
#  'формировочного',
#  'лагеря',
#  'Тамбовом',
#  ',',
#  'тревоге',
#  'морозно',
#  'розовеющем',
#  'декабрьском',
#  'рассвете',
#  'спешная',
#  'погрузка',
#  'эшелон',
#  ',',
#  ',',
#  'отъезд',
#  '—',
#  'вся',
#  'эта',
#  'зыбкая',
#  ',',
#  'временная',
#  ',',
#  'кем-то',
#  'управляемая',
#  'жизнь',
#  'потускнела',
#  ',',
#  'оставалась',
#  'далеко',
#  'позади',
#  ',',
#  'прошлом',
#  '.',
#  'И',
#  'надежды',
#  'увидеть',
#  'мать',
#  ',',
#  'недавно',
#  'сомневался',
#  ',',
#  'повезут',
#  'запад',
#  'Москву',
#  '.',
#  '«',
#  'Я',
#  'напишу',
#  ',',
#  '—',
#  'внезапно',
#  'обострившимся',
#  'чувством',
#  'одиночества',
#  'подумал',
#  'Кузнецов',
#  ',',
#  '—',
#  'объясню',
#  '.',
#  'Ведь',
#  'виделись',
#  'девять',
#  'месяцев…',
#  '»',
#  '.',
#  'А',
#  'весь',
#  'вагон',
#  'спал',
#  'скрежет',
#  ',',
#  'визг',
#  ',',
#  'чугунный',
#  'гул',
#  'разбежавшихся',
#  'колес',
#  ',',
#  'стены',
#  'туго',
#  'качались',
#  ',',
#  'верхние',
#  'нары',
#  'мотало',
#  'бешеной',
#  'скоростью',
#  'эшелона',
#  ',',
#  'Кузнецов',
#  ',',
#  'вздрагивая',
#  ',',
#  'окончательно',
#  'прозябнув',
#  'сквозняках',
#  'возле',
#  'оконца',
#  ',',
#  'отогнул',
#  'воротник',
#  ',',
#  'завистью',
#  'посмотрел',
#  'спящего',
#  'рядом',
#  'командира',
#  'второго',
#  'взвода',
#  'лейтенанта',
#  'Давлатяна',
#  '—',
#  'темноте',
#  'нар',
#  'лица',
#  'видно',
#  '.',
#  '«',
#  'Нет',
#  ',',
#  ',',
#  'возле',
#  'окна',
#  ',',
#  'усну',
#  ',',
#  'замерзну',
#  'передовой',
#  '»',
#  ',',
#  '—',
#  'досадой',
#  'подумал',
#  'Кузнецов',
#  'задвигался',
#  ',',
#  'пошевелился',
#  ',',
#  'слыша',
#  ',',
#  'хрустит',
#  'иней',
#  'досках',
#  'вагона',
#  '.',
#  'Он',
#  'высвободился',
#  'холодной',
#  ',',
#  'колючей',
#  'тесноты',
#  'своего',
#  'места',
#  ',',
#  'спрыгнул',
#  'нар',
#  ',',
#  'чувствуя',
#  ',',
#  'обогреться',
#  'печки',
#  ':',
#  'спина',
#  'вконец',
#  'окоченела',
#  '.',
#  'В',
#  'железной',
#  'печке',
#  'сбоку',
#  'закрытой',
#  'двери',
#  ',',
#  'мерцающей',
#  'толстым',
#  'инеем',
#  ',',
#  'давно',
#  'погас',
#  'огонь',
#  ',',
#  'неподвижным',
#  'зрачком',
#  'краснело',
#  'поддувало',
#  '.',
#  'Но',
#  ',',
#  'внизу',
#  ',',
#  'казалось',
#  ',',
#  'немного',
#  'теплее',
#  '.',
#  'В',
#  'вагонном',
#  'сумраке',
#  'багровый',
#  'отсвет',
#  'угля',
#  'слабо',
#  'озарял',
#  'разнообразно',
#  'торчащие',
#  'проходе',
#  'новые',
#  'валенки',
#  ',',
#  'котелки',
#  ',',
#  'вещмешки',
#  'головами',
#  '.',
#  'Дневальный',
#  'Чибисов',
#  'неудобно',
#  'спал',
#  'нижних',
#  'нарах',
#  ',',
#  'прямо',
#  'ногах',
#  'солдат',
#  ';',
#  'голова',
#  'верха',
#  'шапки',
#  'упрятана',
#  'воротник',
#  ',',
#  'руки',
#  'засунуты',
#  'рукава',
#  '.',
#  '—',
#  'Чибисов',
#  '!',
#  '—',
#  'позвал',
#  'Кузнецов',
#  'открыл',
#  'дверцу',
#  'печки',
#  ',',
#  'повеявшей',
#  'изнутри',
#  'еле',
#  'уловимым',
#  'теплом',
#  '.',
#  '—',
#  'Все',
#  'погасло',
#  ',',
#  'Чибисов',
#  '!',
#  'Ответа',
#  '.',
#  '—',
#  'Дневальный',
#  ',',
#  'слышите',
#  '?',
#  'Чибисов',
#  'испуганно',
#  'вскинулся',
#  ',',
#  'заспанный',
#  ',',
#  'помятый',
#  ',',
#  'шапка-ушанка',
#  'низко',
#  'надвинута',
#  ',',
#  'стянута',
#  'тесемками',
#  'подбородка',
#  '.',
#  'Еще',
#  'очнувшись',
#  'ото',
#  'сна',
#  ',',
#  'пытался',
#  'оттолкнуть',
#  'ушанку',
#  'лба',
#  ',',
#  'развязать',
#  'тесемки',
#  ',',
#  'непонимающе',
#  'робко',
#  'вскрикивая',
#  ':',
#  '—',
#  'Что',
#  'это',
#  '?',
#  'Никак',
#  ',',
#  'заснул',
#  '?',
#  'Ровно',
#  'оглушило',
#  'беспамятством',
#  '.',
#  'Извиняюсь',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '!',
#  'Ух',
#  ',',
#  'косточек',
#  'пробрало',
#  'дремоте-то',
#  '!',
#  '..',
#  '—',
#  'Заснули',
#  'весь',
#  'вагон',
#  'выстудили',
#  ',',
#  '—',
#  'сказал',
#  'упреком',
#  'Кузнецов',
#  '.',
#  '—',
#  'Да',
#  'хотел',
#  ',',
#  'товарищ',
#  'лейтенант',
#  ',',
#  'невзначай',
#  ',',
#  'умыслу',
#  ',',
#  '—',
#  'забормотал',
#  'Чибисов',
#  '.',
#  '—',
#  'Повалило',
#  'меня…',
#  'Затем',
#  ',',
#  'дожидаясь',
#  'приказаний',
#  'Кузнецова',
#  ',',
#  'излишней',
#  'бодростью',
#  'засуетился',
#  ',',
#  'схватил',
#  'пола',
#  'доску',
#  ',',
#  'разломал',
#  'колено',
#  'стал',
#  'заталкивать',
#  'обломки',
#  'печку',
#  '.',
#  'При',
#  'бестолково',
#  ',',
#  'бока',
#  'чесались',
#  ',',
#  'двигал',
#  'локтями',
#  'плечами',
#  ',',
#  'часто',
#  'нагибаясь',
#  ',',
#  'деловито',
#  'заглядывал',
#  'поддувало',
#  ',',
#  'ленивыми',
#  'отблесками',
#  'заползал',
#  'огонь',
#  ';',
#  'ожившее',
#  ',',
#  'запачканное',
#  'сажей',
#  'лицо',
#  'Чибисова',
#  'выражало',
#  'заговорщицкую',
#  'подобострастность',
#  '.',
#  '—',
#  'Я',
#  'теперича',
#  ',',
#  'товарищ',
#  'лейтенант',
#  ',',
#  'тепло',
#  'нагоню',
#  '!',
#  'Накалим',
#  ',',
#  'ровно',
#  'баньке',
#  '.',
#  'Иззябся',
#  'войну-то',
#  '!',
#  'Ох',
#  'иззябся',
#  ',',
#  'кажную',
#  'косточку',
#  'ломит',
#  '—',
#  'слов',
#  '!',
#  '..',
#  'Кузнецов',
#  'сел',
#  'против',
#  'раскрытой',
#  'дверцы',
#  'печки',
#  '.',
#  'Ему',
#  'неприятна',
#  'преувеличенно',
#  'нарочитая',
#  'суетливость',
#  'дневального',
#  ',',
#  'явный',
#  'намек',
#  'свое',
#  'прошлое',
#  '.',
#  'Чибисов',
#  'взвода',
#  '.',
#  'И',
#  ',',
#  ',',
#  'своим',
#  'неумеренным',
#  'старанием',
#  ',',
#  'безотказный',
#  ',',
#  'прожил',
#  'несколько',
#  'месяцев',
#  'немецком',
#  'плену',
#  ',',
#  'первого',
#  'дня',
#  'появления',
#  'взводе',
#  'постоянно',
#  'готов',
#  'услужить',
#  'каждому',
#  ',',
#  'вызывало',
#  'нему',
#  'настороженную',
#  'жалость',
#  '.',
#  'Чибисов',
#  'мягко',
#  ',',
#  'по-бабьи',
#  'опустился',
#  'нары',
#  ',',
#  'непроспанные',
#  'глаза',
#  'моргали',
#  '.',
#  '—',
#  'В',
#  'Сталинград',
#  ',',
#  'значит',
#  ',',
#  'едем',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '?',
#  'По',
#  'сводкам-то',
#  'мясорубка',
#  '!',
#  'Не',
#  'боязно',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '?',
#  'Ничего',
#  '?',
#  '—',
#  'Приедем',
#  '—',
#  'увидим',
#  ',',
#  'мясорубка',
#  ',',
#  '—',
#  'вяло',
#  'отозвался',
#  'Кузнецов',
#  ',',
#  'всматриваясь',
#  'огонь',
#  '.',
#  '—',
#  'А',
#  ',',
#  'боитесь',
#  '?',
#  'Почему',
#  'спросили',
#  '?',
#  '—',
#  'Да',
#  ',',
#  'сказать',
#  ',',
#  'страху',
#  'нету',
#  ',',
#  'раньше-то',
#  ',',
#  '—',
#  'фальшиво',
#  'весело',
#  'ответил',
#  'Чибисов',
#  ',',
#  'вздохнув',
#  ',',
#  'положил',
#  'маленькие',
#  'руки',
#  'колени',
#  ',',
#  'заговорил',
#  'доверительным',
#  'тоном',
#  ',',
#  'желая',
#  'убедить',
#  'Кузнецова',
#  ':',
#  '—',
#  'После',
#  ',',
#  'наши',
#  'плена-то',
#  'освободили',
#  ',',
#  'поверили',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '.',
#  'А',
#  'цельных',
#  'месяца',
#  ',',
#  'ровно',
#  'щенок',
#  'дерьме',
#  ',',
#  'немцев',
#  'просидел',
#  '.',
#  'Поверили…',
#  'Война',
#  'вон',
#  'огромная',
#  ',',
#  'разный',
#  'народ',
#  'воюет',
#  '.',
#  'Как',
#  'сразу',
#  'верить-то',
#  '?',
#  '—',
#  'Чибисов',
#  'скосился',
#  'осторожно',
#  'Кузнецова',
#  ';',
#  'молчал',
#  ',',
#  'делая',
#  'вид',
#  ',',
#  'занят',
#  'печкой',
#  ',',
#  'обогреваясь',
#  'живым',
#  'теплом',
#  ':',
#  'сосредоточенно',
#  'сжимал',
#  'разжимал',
#  'пальцы',
#  'открытой',
#  'дверцей',
#  '.',
#  '—',
#  'Знаете',
#  ',',
#  'плен-то',
#  'попал',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '?',
#  '..',
#  'Не',
#  'говорил',
#  ',',
#  'сказать',
#  'хочу',
#  '.',
#  'В',
#  'овраг',
#  'немцы',
#  'загнали',
#  '.',
#  'Под',
#  'Вязьмой',
#  '.',
#  'И',
#  'танки',
#  'ихние',
#  'вплотную',
#  'подошли',
#  ',',
#  'окружили',
#  ',',
#  'снарядов',
#  ',',
#  'комиссар',
#  'полка',
#  'верх',
#  'своей',
#  '«',
#  'эмки',
#  '»',
#  'выскочил',
#  'пистолетом',
#  ',',
#  'кричит',
#  ':',
#  '«',
#  'Лучше',
#  'смерть',
#  ',',
#  'плен',
#  'фашистским',
#  'гадам',
#  '!',
#  '»',
#  '—',
#  'выстрелил',
#  'висок',
#  '.',
#  'От',
#  'головы',
#  'брызнуло',
#  '.',
#  'А',
#  'немцы',
#  'сторон',
#  'бегут',
#  'нам',
#  '.',
#  'Танки',
#  'живьем',
#  'людей',
#  'душат',
#  '.',
#  'Тут',
#  'и…',
#  'полковник',
#  'кто-то…',
#  '—',
#  'А',
#  '?',
#  '—',
#  'спросил',
#  'Кузнецов',
#  '.',
#  '—',
#  'Я',
#  'выстрелить',
#  'мог',
#  '.',
#  'Сгрудили',
#  'кучу',
#  ',',
#  'орут',
#  '«',
#  'хенде',
#  'хох',
#  '»',
#  '.',
#  'И',
#  'повели…',
#  '—',
#  'Понятно',
#  ',',
#  '—',
#  'сказал',
#  'Кузнецов',
#  'той',
#  'серьезной',
#  'интонацией',
#  ',',
#  'которая',
#  'ясно',
#  'говорила',
#  ',',
#  'месте',
#  'Чибисова',
#  ...]

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_5)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['юр',
#  'бондар',
#  'горяч',
#  'снег',
#  'глав',
#  'перв',
#  'кузнецов',
#  'не',
#  'спал',
#  '.',
#  'все',
#  'сильн',
#  'стуча',
#  ',',
#  'гремел',
#  'по',
#  'крыш',
#  'вагон',
#  ',',
#  'вьюжн',
#  'ударя',
#  'нахлест',
#  'ветр',
#  ',',
#  'все',
#  'плотн',
#  'забива',
#  'снег',
#  'едв',
#  'угадыва',
#  'оконц',
#  'над',
#  'нар',
#  '.',
#  'паровоз',
#  'с',
#  'дик',
#  ',',
#  'раздира',
#  'метел',
#  'рев',
#  'гнал',
#  'эшелон',
#  'в',
#  'ночн',
#  'пол',
#  ',',
#  'в',
#  'бел',
#  ',',
#  'несущ',
#  'со',
#  'всех',
#  'сторон',
#  'мут',
#  ',',
#  'и',
#  'в',
#  'гремуч',
#  'темнот',
#  'вагон',
#  ',',
#  'сквоз',
#  'мерзл',
#  'визг',
#  'колес',
#  ',',
#  'сквоз',
#  'тревожн',
#  'всхлип',
#  ',',
#  'бормотан',
#  'во',
#  'сне',
#  'солдат',
#  'был',
#  'слыш',
#  'этот',
#  'непрерывн',
#  'предупрежда',
#  'кого-т',
#  'рев',
#  'паровоз',
#  ',',
#  'и',
#  'чуд',
#  'кузнецов',
#  ',',
#  'что',
#  'там',
#  ',',
#  'вперед',
#  ',',
#  'за',
#  'метел',
#  ',',
#  'уж',
#  'мутн',
#  'проступа',
#  'зарев',
#  'горя',
#  'город',
#  '.',
#  'посл',
#  'стоянк',
#  'в',
#  'саратов',
#  'всем',
#  'стал',
#  'ясн',
#  ',',
#  'что',
#  'дивиз',
#  'срочн',
#  'перебрасыва',
#  'под',
#  'сталинград',
#  ',',
#  'а',
#  'не',
#  'на',
#  'западн',
#  'фронт',
#  ',',
#  'как',
#  'предполага',
#  'вначал',
#  ';',
#  'и',
#  'тепер',
#  'кузнец',
#  'знал',
#  ',',
#  'что',
#  'еха',
#  'остава',
#  'нескольк',
#  'час',
#  '.',
#  'и',
#  ',',
#  'натягив',
#  'на',
#  'щек',
#  'жестк',
#  ',',
#  'неприятн',
#  'влажн',
#  'воротник',
#  'шинел',
#  ',',
#  'он',
#  'никак',
#  'не',
#  'мог',
#  'согрет',
#  ',',
#  'набра',
#  'тепл',
#  ',',
#  'чтоб',
#  'уснут',
#  ':',
#  'пронзительн',
#  'дул',
#  'в',
#  'невидим',
#  'щел',
#  'заметен',
#  'оконц',
#  ',',
#  'ледян',
#  'сквозняк',
#  'гуля',
#  'по',
#  'нар',
#  '.',
#  '«',
#  'знач',
#  ',',
#  'я',
#  'долг',
#  'не',
#  'увиж',
#  'мат',
#  ',',
#  '—',
#  'съежив',
#  'от',
#  'холод',
#  ',',
#  'подума',
#  'кузнец',
#  ',',
#  '—',
#  'нас',
#  'провезл',
#  'мимо…',
#  '»',
#  '.',
#  'то',
#  ',',
#  'что',
#  'был',
#  'прошл',
#  'жизн',
#  ',',
#  '—',
#  'летн',
#  'месяц',
#  'в',
#  'училищ',
#  'в',
#  'жарк',
#  ',',
#  'пыльн',
#  'актюбинск',
#  ',',
#  'с',
#  'раскален',
#  'ветр',
#  'из',
#  'степ',
#  ',',
#  'с',
#  'задыха',
#  'в',
#  'закатн',
#  'тишин',
#  'крик',
#  'ишак',
#  'на',
#  'окраин',
#  ',',
#  'так',
#  'ежевечерн',
#  'точн',
#  'по',
#  'времен',
#  ',',
#  'что',
#  'командир',
#  'взвод',
#  'на',
#  'тактическ',
#  'занят',
#  ',',
#  'изныв',
#  'от',
#  'жажд',
#  ',',
#  'не',
#  'без',
#  'облегчен',
#  'сверя',
#  'по',
#  'ним',
#  'час',
#  ',',
#  'марш',
#  'в',
#  'одуря',
#  'зно',
#  ',',
#  'пропотевш',
#  'и',
#  'выжжен',
#  'на',
#  'солнц',
#  'добел',
#  'гимнастерк',
#  ',',
#  'скрип',
#  'песк',
#  'на',
#  'зуб',
#  ';',
#  'воскресн',
#  'патрулирован',
#  'город',
#  ',',
#  'в',
#  'городск',
#  'сад',
#  ',',
#  'где',
#  'по',
#  'вечер',
#  'мирн',
#  'игра',
#  'на',
#  'танцплощадк',
#  'воен',
#  'духов',
#  'оркестр',
#  ';',
#  'зат',
#  'выпуск',
#  'в',
#  'училищ',
#  ',',
#  'погрузк',
#  'по',
#  'тревог',
#  'осен',
#  'ноч',
#  'в',
#  'вагон',
#  ',',
#  'угрюм',
#  ',',
#  'в',
#  'дик',
#  'снег',
#  'лес',
#  ',',
#  'сугроб',
#  ',',
#  'землянк',
#  'формировочн',
#  'лагер',
#  'под',
#  'тамбов',
#  ',',
#  'пот',
#  'опя',
#  'по',
#  'тревог',
#  'на',
#  'морозн',
#  'розовеющ',
#  'декабрьск',
#  'рассвет',
#  'спешн',
#  'погрузк',
#  'в',
#  'эшелон',
#  'и',
#  ',',
#  'наконец',
#  ',',
#  'отъезд',
#  '—',
#  'вся',
#  'эт',
#  'зыбк',
#  ',',
#  'времен',
#  ',',
#  'кем-т',
#  'управля',
#  'жизн',
#  'потускнел',
#  'сейчас',
#  ',',
#  'остава',
#  'далек',
#  'позад',
#  ',',
#  'в',
#  'прошл',
#  '.',
#  'и',
#  'не',
#  'был',
#  'надежд',
#  'увидет',
#  'мат',
#  ',',
#  'а',
#  'он',
#  'совс',
#  'недавн',
#  'почт',
#  'не',
#  'сомнева',
#  ',',
#  'что',
#  'их',
#  'повезут',
#  'на',
#  'запад',
#  'через',
#  'москв',
#  '.',
#  '«',
#  'я',
#  'напиш',
#  'е',
#  ',',
#  '—',
#  'с',
#  'внезапн',
#  'обостр',
#  'чувств',
#  'одиночеств',
#  'подума',
#  'кузнец',
#  ',',
#  '—',
#  'и',
#  'все',
#  'объясн',
#  '.',
#  'вед',
#  'мы',
#  'не',
#  'видел',
#  'девя',
#  'месяцев…',
#  '»',
#  '.',
#  'а',
#  'ве',
#  'вагон',
#  'спал',
#  'под',
#  'скрежет',
#  ',',
#  'визг',
#  ',',
#  'под',
#  'чугун',
#  'гул',
#  'разбежа',
#  'колес',
#  ',',
#  'стен',
#  'туг',
#  'кача',
#  ',',
#  'верхн',
#  'нар',
#  'мота',
#  'бешен',
#  'скорост',
#  'эшелон',
#  ',',
#  'и',
#  'кузнец',
#  ',',
#  'вздрагив',
#  ',',
#  'окончательн',
#  'прозябнув',
#  'на',
#  'сквозняк',
#  'возл',
#  'оконц',
#  ',',
#  'отогнул',
#  'воротник',
#  ',',
#  'с',
#  'завист',
#  'посмотрел',
#  'на',
#  'спящ',
#  'ряд',
#  'командир',
#  'втор',
#  'взвод',
#  'лейтенант',
#  'давлатя',
#  '—',
#  'в',
#  'темнот',
#  'нар',
#  'лиц',
#  'ег',
#  'не',
#  'был',
#  'видн',
#  '.',
#  '«',
#  'нет',
#  ',',
#  'зде',
#  ',',
#  'возл',
#  'окн',
#  ',',
#  'я',
#  'не',
#  'усн',
#  ',',
#  'замерзн',
#  'до',
#  'передов',
#  '»',
#  ',',
#  '—',
#  'с',
#  'досад',
#  'на',
#  'себ',
#  'подума',
#  'кузнец',
#  'и',
#  'задвига',
#  ',',
#  'пошевел',
#  ',',
#  'слыш',
#  ',',
#  'как',
#  'хруст',
#  'ин',
#  'на',
#  'доск',
#  'вагон',
#  '.',
#  'он',
#  'высвобод',
#  'из',
#  'холодн',
#  ',',
#  'колюч',
#  'теснот',
#  'сво',
#  'мест',
#  ',',
#  'спрыгнул',
#  'с',
#  'нар',
#  ',',
#  'чувству',
#  ',',
#  'что',
#  'над',
#  'обогрет',
#  'у',
#  'печк',
#  ':',
#  'спин',
#  'вконец',
#  'окоченел',
#  '.',
#  'в',
#  'железн',
#  'печк',
#  'сбок',
#  'закрыт',
#  'двер',
#  ',',
#  'мерца',
#  'толст',
#  'ине',
#  ',',
#  'давн',
#  'погас',
#  'огон',
#  ',',
#  'тольк',
#  'неподвижн',
#  'зрачк',
#  'краснел',
#  'поддува',
#  '.',
#  'но',
#  'зде',
#  ',',
#  'вниз',
#  ',',
#  'каза',
#  ',',
#  'был',
#  'немн',
#  'тепл',
#  '.',
#  'в',
#  'вагон',
#  'сумрак',
#  'этот',
#  'багров',
#  'отсвет',
#  'угл',
#  'слаб',
#  'озаря',
#  'разнообразн',
#  'торча',
#  'в',
#  'проход',
#  'нов',
#  'валенк',
#  ',',
#  'котелк',
#  ',',
#  'вещмешк',
#  'под',
#  'голов',
#  '.',
#  'дневальн',
#  'чибис',
#  'неудобн',
#  'спал',
#  'на',
#  'нижн',
#  'нар',
#  ',',
#  'прям',
#  'на',
#  'ног',
#  'солдат',
#  ';',
#  'голов',
#  'ег',
#  'до',
#  'верх',
#  'шапк',
#  'был',
#  'упрята',
#  'в',
#  'воротник',
#  ',',
#  'рук',
#  'засунут',
#  'в',
#  'рукав',
#  '.',
#  '—',
#  'чибис',
#  '!',
#  '—',
#  'позва',
#  'кузнец',
#  'и',
#  'откр',
#  'дверц',
#  'печк',
#  ',',
#  'повея',
#  'изнутр',
#  'ел',
#  'уловим',
#  'тепл',
#  '.',
#  '—',
#  'все',
#  'погасл',
#  ',',
#  'чибис',
#  '!',
#  'ответ',
#  'не',
#  'был',
#  '.',
#  '—',
#  'дневальн',
#  ',',
#  'слыш',
#  '?',
#  'чибис',
#  'испуга',
#  'вскинул',
#  ',',
#  'заспа',
#  ',',
#  'помят',
#  ',',
#  'шапка-ушанк',
#  'низк',
#  'надвинут',
#  ',',
#  'стянут',
#  'тесемк',
#  'у',
#  'подбородк',
#  '.',
#  'ещ',
#  'не',
#  'очнувш',
#  'от',
#  'сна',
#  ',',
#  'он',
#  'пыта',
#  'оттолкнут',
#  'ушанк',
#  'со',
#  'лба',
#  ',',
#  'развяза',
#  'тесемк',
#  ',',
#  'непонимающ',
#  'и',
#  'робк',
#  'вскрикив',
#  ':',
#  '—',
#  'что',
#  'эт',
#  'я',
#  '?',
#  'никак',
#  ',',
#  'заснул',
#  '?',
#  'ровн',
#  'оглуш',
#  'мен',
#  'беспамятств',
#  '.',
#  'извиня',
#  'я',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '!',
#  'ух',
#  ',',
#  'до',
#  'косточек',
#  'пробра',
#  'мен',
#  'в',
#  'дремоте-т',
#  '!',
#  '..',
#  '—',
#  'заснул',
#  'и',
#  'ве',
#  'вагон',
#  'выстуд',
#  ',',
#  '—',
#  'сказа',
#  'с',
#  'упрек',
#  'кузнец',
#  '.',
#  '—',
#  'да',
#  'не',
#  'хотел',
#  'я',
#  ',',
#  'товарищ',
#  'лейтенант',
#  ',',
#  'невзнача',
#  ',',
#  'без',
#  'умысл',
#  ',',
#  '—',
#  'забормота',
#  'чибис',
#  '.',
#  '—',
#  'повал',
#  'меня…',
#  'зат',
#  ',',
#  'не',
#  'дожид',
#  'приказан',
#  'кузнецов',
#  ',',
#  'с',
#  'излишн',
#  'бодрост',
#  'засует',
#  ',',
#  'схват',
#  'с',
#  'пол',
#  'доск',
#  ',',
#  'разлома',
#  'е',
#  'о',
#  'кол',
#  'и',
#  'стал',
#  'заталкива',
#  'обломк',
#  'в',
#  'печк',
#  '.',
#  'при',
#  'эт',
#  'бестолков',
#  ',',
#  'будт',
#  'бок',
#  'чеса',
#  ',',
#  'двига',
#  'локт',
#  'и',
#  'плеч',
#  ',',
#  'част',
#  'нагиб',
#  ',',
#  'деловит',
#  'заглядыва',
#  'в',
#  'поддува',
#  ',',
#  'где',
#  'ленив',
#  'отблеск',
#  'заполза',
#  'огон',
#  ';',
#  'ож',
#  ',',
#  'запачка',
#  'саж',
#  'лиц',
#  'чибисов',
#  'выража',
#  'заговорщицк',
#  'подобострастн',
#  '.',
#  '—',
#  'я',
#  'теперич',
#  ',',
#  'товарищ',
#  'лейтенант',
#  ',',
#  'тепл',
#  'нагон',
#  '!',
#  'накал',
#  ',',
#  'ровн',
#  'в',
#  'баньк',
#  'будет',
#  '.',
#  'иззяб',
#  'я',
#  'сам',
#  'за',
#  'войну-т',
#  '!',
#  'ох',
#  'как',
#  'иззяб',
#  ',',
#  'кажн',
#  'косточк',
#  'лом',
#  '—',
#  'слов',
#  'нет',
#  '!',
#  '..',
#  'кузнец',
#  'сел',
#  'прот',
#  'раскрыт',
#  'дверц',
#  'печк',
#  '.',
#  'ем',
#  'неприятн',
#  'был',
#  'преувеличен',
#  'нарочит',
#  'суетлив',
#  'дневальн',
#  ',',
#  'этот',
#  'явн',
#  'намек',
#  'на',
#  'сво',
#  'прошл',
#  '.',
#  'чибис',
#  'был',
#  'из',
#  'ег',
#  'взвод',
#  '.',
#  'и',
#  'то',
#  ',',
#  'что',
#  'он',
#  ',',
#  'со',
#  'сво',
#  'неумерен',
#  'старан',
#  ',',
#  'всегд',
#  'безотказн',
#  ',',
#  'прож',
#  'нескольк',
#  'месяц',
#  'в',
#  'немецк',
#  'плен',
#  ',',
#  'а',
#  'с',
#  'перв',
#  'дня',
#  'появлен',
#  'во',
#  'взвод',
#  'постоя',
#  'гот',
#  'был',
#  'услуж',
#  'кажд',
#  ',',
#  'вызыва',
#  'к',
#  'нем',
#  'насторожен',
#  'жалост',
#  '.',
#  'чибис',
#  'мягк',
#  ',',
#  'по-баб',
#  'опуст',
#  'на',
#  'нар',
#  ',',
#  'непроспа',
#  'глаз',
#  'ег',
#  'морга',
#  '.',
#  '—',
#  'в',
#  'сталинград',
#  ',',
#  'знач',
#  ',',
#  'ед',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '?',
#  'по',
#  'сводкам-т',
#  'как',
#  'мясорубк',
#  'там',
#  '!',
#  'не',
#  'боязн',
#  'вам',
#  ',',
#  'товарищ',
#  'лейтенант',
#  '?',
#  'нич',
#  '?',
#  '—',
#  'приед',
#  '—',
#  'увид',
#  ',',
#  'что',
#  'за',
#  'мясорубк',
#  ',',
#  '—',
#  'вял',
#  'отозва',
#  'кузнец',
#  ',',
#  'всматрив',
#  'в',
#  'огон',
#  '.',
#  '—',
#  'а',
#  'вы',
#  'что',
#  ',',
#  'бо',
#  '?',
#  'поч',
#  'спрос',
#  '?',
#  '—',
#  'да',
#  ',',
#  'можн',
#  'сказа',
#  ',',
#  'тог',
#  'страх',
#  'нет',
#  ',',
#  'что',
#  ...]

# %%
len(words)
# Out:
# 136251

# %%
len(tokenized_filtered)
# Out:
# 108042

# %% [markdown]
# Косинусное сходстово "Последние залпы и Простите нас!"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Forgive_us!.txt", encoding="utf-8") as file:
    text_1 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])# числитель DF

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2) #Знаменатель IDF

    if not deno:
        return 0.0
    else:
        return float(numer) / deno # Cos

def generate_vectors(sent):
    w = word.findall(sent) #поиск всех слов в предложении
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_1)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.8790189367386265

# %% [markdown]
# Косинусное сходство " Последние залпы и Непротивление"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Neprotivlenie.txt", encoding="utf-8") as file:
    text_2 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2)

    if not deno:
        return 0.0
    else:
        return float(numer) / deno

def generate_vectors(sent):
    w = word.findall(sent)
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_2)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово", cos)
# Out:
# Косинусное сходстово 0.9371650617841418

# %% [markdown]
# Косинусное сходство "Последние залпы и Непротивление"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Neprotivlenie.txt", encoding="utf-8") as file:
    text_3 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2)

    if not deno:
        return 0.0
    else:
        return float(numer) / deno

def generate_vectors(sent):
    w = word.findall(sent)
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_3)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.9371650617841418

# %% [markdown]
# Косинусное сходство "Последние залпы и Родственники"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Relatives.txt", encoding="utf-8") as file:
    text_4 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2)

    if not deno:
        return 0.0
    else:
        return float(numer) / deno

def generate_vectors(sent):
    w = word.findall(sent)
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_4)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.923255620137849

# %% [markdown]
# Косинусное сходство "Последние залпы и Тишина"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Silence.txt", encoding="utf-8") as file:
    text_5 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2)

    if not deno:
        return 0.0
    else:
        return float(numer) / deno

def generate_vectors(sent):
    w = word.findall(sent)
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_5)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.9373927937035448

# %% [markdown]
# Косинусное сходство "Последние залпы и Горячий снег"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Warm_snow.txt", encoding="utf-8") as file:
    text_1 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter]) # числитель DF

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2) #Знаменатель IDF

    if not deno:
        return 0.0
    else:
        return float(numer) / deno # Cos

def generate_vectors(sent):
    w = word.findall(sent) #поиск всех слов в предложении
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_1)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.9450087598200215
